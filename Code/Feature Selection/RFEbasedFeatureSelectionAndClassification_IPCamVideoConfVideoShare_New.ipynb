# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import RFE
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from matplotlib import pyplot

# %%
fnamesIPcam = ["D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/d3dtraffic_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/d3dtraffic_2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/d3dtraffic_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_6_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_7_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/netatmocam1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/netatmocam2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/netatmocam3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_6_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_7_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_8_Flow.csv",
           ]
fnamesConf = [
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet4_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet6_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet7_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet8_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet9_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet10_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet11_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet12_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams11_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams12_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams21_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams22_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_2_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_6_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_7_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_8_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_9_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_10_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_11_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_12_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_13_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_14_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_15_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom5_Flow.csv",]
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom_6_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom_7_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom_8_Flow.csv",
         # ]
fnamesShare = [
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_6_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_7_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_8_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_9_Flow.csv",
         ]

# %%
dfList = list()
for fname in fnamesIPcam: 
    data = pd.read_csv(fname)
    print('file:', fname, ' data size: ',data.shape)
    dfList.append(data)
############## combine the data frames
ipcamDF = pd.concat(dfList)
print(ipcamDF.shape)
# Out:
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_1_Flow.csv  data size:  (125, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_2_Flow.csv  data size:  (157, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_3_Flow.csv  data size:  (95, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_4_Flow.csv  data size:  (18, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_1_Flow.csv  data size:  (45, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_2_Flow.csv  data size:  (45, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_3_Flow.csv  data size:  (143, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_4_Flow.csv  data size:  (188, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/d3dtraffic_1_Flow.csv  data size:  (503, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/d3dtraffic_2_Flow.csv  data size:  (665, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/d3dtraffic_3_Flow.csv  data size:  (565, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_1_Flow.csv  data size:  (234, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_2_Flow.csv  data size:  (336, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_3_Flow.csv  data size:  (479, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_4_Flow.csv  data size:  (605, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_5_Flow.csv  data size:  (563, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_6_Flow.csv  data size:  (339, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_7_Flow.csv  data size:  (30, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/netatmocam1_Flow.csv  data size:  (432, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/netatmocam2_Flow.csv  data size:  (158, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/netatmocam3_Flow.csv  data size:  (353, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_1_Flow.csv  data size:  (249, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_2_Flow.csv  data size:  (1678, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_3_Flow.csv  data size:  (347, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_4_Flow.csv  data size:  (425, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_5_Flow.csv  data size:  (264, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_6_Flow.csv  data size:  (288, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_7_Flow.csv  data size:  (280, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_8_Flow.csv  data size:  (391, 84)
# (10000, 84)

# %%
#see unique labels
print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam_AlarmClock', 'IPCam_Canary', 'IPCam_D3D', 'IPCam_Ezviz', 'IPCam_Netatmo', 'IPCam_V380']

# %%
ipcamDF['Label'].replace('IPCam_AlarmClock','IPCam',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam', 'IPCam_Canary', 'IPCam_D3D', 'IPCam_Ezviz', 'IPCam_Netatmo', 'IPCam_V380']

# %%
ipcamDF['Label'].replace('IPCam_Canary','IPCam',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam', 'IPCam_D3D', 'IPCam_Ezviz', 'IPCam_Netatmo', 'IPCam_V380']

# %%
ipcamDF['Label'].replace('IPCam_D3D','IPCam',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam', 'IPCam_Ezviz', 'IPCam_Netatmo', 'IPCam_V380']

# %%
ipcamDF['Label'].replace('IPCam_Ezviz','IPCam',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam', 'IPCam_Netatmo', 'IPCam_V380']

# %%
ipcamDF['Label'].replace('IPCam_Netatmo','IPCam',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam', 'IPCam_V380']

# %%
ipcamDF['Label'].replace('IPCam_V380','IPCam',inplace=True)
uniqueLabels = list(ipcamDF['Label'].unique())
print(uniqueLabels)
#print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam']

# %%
###################################\
dfList = list()
for fname in fnamesShare: 
    data = pd.read_csv(fname)
    print('file:', fname, ' data size: ',data.shape)
    dfList.append(data)
############## combine the data frames
shareDF = pd.concat(dfList)
print(shareDF.shape)
# Out:
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon1_Flow.csv  data size:  (870, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon2_Flow.csv  data size:  (516, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon3_Flow.csv  data size:  (921, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon4_Flow.csv  data size:  (467, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon5_Flow.csv  data size:  (800, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_1_Flow.csv  data size:  (1420, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_2_Flow.csv  data size:  (52, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_3_Flow.csv  data size:  (37, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_4_Flow.csv  data size:  (41, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_5_Flow.csv  data size:  (337, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_6_Flow.csv  data size:  (159, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_7_Flow.csv  data size:  (337, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_8_Flow.csv  data size:  (1729, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_9_Flow.csv  data size:  (194, 84)
# (7880, 84)

# %%
print(list(shareDF['Label'].unique()))
# Out:
# ['VShare_Amazon', 'VShare_YouTube']

# %%
shareDF['Label'].replace('VShare_Amazon','VShare',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(shareDF['Label'].unique()))
# Out:
# ['VShare', 'VShare_YouTube']

# %%
shareDF['Label'].replace('VShare_YouTube','VShare',inplace=True)
uniqueLabels = list(shareDF['Label'].unique())
print(uniqueLabels)
# Out:
# ['VShare']

# %%
###################################\
dfList = list()
for fname in fnamesConf: 
    data = pd.read_csv(fname)
    print('file:', fname, ' data size: ',data.shape)
    dfList.append(data)
############## combine the data frames
confDF = pd.concat(dfList)
print(confDF.shape)
# Out:
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet1_Flow.csv  data size:  (2620, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet2_Flow.csv  data size:  (3350, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet3_Flow.csv  data size:  (3207, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet4_Flow.csv  data size:  (6585, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet6_Flow.csv  data size:  (4937, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams1_Flow.csv  data size:  (1898, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams2_Flow.csv  data size:  (382, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams11_Flow.csv  data size:  (1898, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams12_Flow.csv  data size:  (1898, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams21_Flow.csv  data size:  (382, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams22_Flow.csv  data size:  (382, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_1_Flow.csv  data size:  (186, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_2_Flow.csv  data size:  (285, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_4_Flow.csv  data size:  (271, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_5_Flow.csv  data size:  (55, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_6_Flow.csv  data size:  (417, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom1_Flow.csv  data size:  (237, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom2_Flow.csv  data size:  (251, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom3_Flow.csv  data size:  (180, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom4_Flow.csv  data size:  (312, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom5_Flow.csv  data size:  (108, 84)
# (29841, 84)

# %%
print(list(confDF['Label'].unique()))
# Out:
# ['VConf_GMeet', 'VConf_Teams', 'VConf_Skype', 'VConf_Zoom']

# %%
confDF['Label'].replace('VConf_GMeet','VConf',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(confDF['Label'].unique()))
# Out:
# ['VConf', 'VConf_Teams', 'VConf_Skype', 'VConf_Zoom']

# %%
confDF['Label'].replace('VConf_Teams','VConf',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(confDF['Label'].unique()))
# Out:
# ['VConf', 'VConf_Skype', 'VConf_Zoom']

# %%
confDF['Label'].replace('VConf_Skype','VConf',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(confDF['Label'].unique()))
# Out:
# ['VConf', 'VConf_Zoom']

# %%
confDF['Label'].replace('VConf_Zoom','VConf',inplace=True)
uniqueLabels = list(confDF['Label'].unique())
print(uniqueLabels)
#print(list(confDF['Label'].unique()))
# Out:
# ['VConf']

# %%
print(list(confDF['Label'].unique()))
print(list(shareDF['Label'].unique()))
print(list(ipcamDF['Label'].unique()))
# Out:
# ['VConf']
# ['VShare']
# ['IPCam']

# %%
######### creating master DF
dfListAll = [ipcamDF,shareDF, confDF]
masterDF = pd.concat(dfListAll)
print(masterDF.shape)
# Out:
# (47721, 84)

# %%
#see unique labels
masterDF['Label'].unique()
masterDF['Label'].replace('VConf_Gmeet','VConf_GMeet',inplace=True)
uniqueLabels = list(masterDF['Label'].unique())
print(uniqueLabels)
# Out:
# ['IPCam', 'VShare', 'VConf']

# %%
#discard all those columns that helps in uniquely identifying a flow
masterPruned = masterDF.iloc[:,np.arange(7,84)]
print('pruneddata size: ', masterPruned.shape)
ftList = list(masterPruned.columns)
print(ftList)
# Out:
# pruneddata size:  (47721, 77)
# ['Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow Pkts/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std', 'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt', 'CWE Flag Count', 'ECE Flag Cnt', 'Down/Up Ratio', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg', 'Fwd Byts/b Avg', 'Fwd Pkts/b Avg', 'Fwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Pkts/b Avg', 'Bwd Blk Rate Avg', 'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts', 'Subflow Bwd Byts', 'Init Fwd Win Byts', 'Init Bwd Win Byts', 'Fwd Act Data Pkts', 'Fwd Seg Size Min', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'Label']

# %%
#discard those flows that has 0 flow duration
masterSelected = masterPruned.drop(masterPruned[masterPruned['Flow Duration']==0].index)
masterSelected.shape
# Out:
# (35293, 77)

# %%
#identify those columns that has non-numeric values
typesList = masterSelected.dtypes
ftCount = len(ftList)
nonNumericFtList = list()
for fi in range(ftCount):
    if ftList[fi] != 'Label' and typesList[fi] != 'int64' and typesList[fi] != 'float64':
        print(ftList[fi], '  ', typesList[fi])
        nonNumericFtList.append(ftList[fi])
print(nonNumericFtList)
# Out:
# []

# %%
#pyplot.boxplot(results, labels=names, showmeans=True)
#pyplot.scatter(fpackets,fbytes)
#pyplot.show()

# %%
for ft in nonNumericFtList:
    masterSelected[ft] = pd.to_numeric(masterSelected[ft], errors='coerce')

# %%
print(nonNumericFtList)
for ft in nonNumericFtList:
    countNaN = masterSelected[ft].isna().sum()
    print('converted to numeric ft: ', ft, '  countNaN: ', countNaN)
# Out:
# []

# %%
number_inf = masterSelected[masterSelected == np.inf].count().sum()
print('count inf: ',number_inf)
# Out:
# count inf:  0

# %%
typesList = masterSelected.dtypes
ftCount = len(ftList)
nonNumericFtList = list()
for fi in range(ftCount):
    if ftList[fi] != 'Label' and typesList[fi] != 'int64' and typesList[fi] != 'float64':
        print(ftList[fi], '  ', typesList[fi])
        nonNumericFtList.append(ftList[fi])
print(nonNumericFtList)
# Out:
# []

# %%
#identify those columns that has 0 std
count = 0
staticFtList = list()
for ft in ftList:
    if ft == 'Label':
        continue
    #print('ft : ', ft)
    ftMin = masterSelected[ft].min()
    ftMax = masterSelected[ft].max()
    #std = masterPruned[ft].std()
    
    if ftMin == ftMax:
        count += 1
        print('count: ', count, ' ft: ', ft, ' ftmin: ', ftMin, ' ftMax: ', ftMax)
        staticFtList.append(ft)
print(staticFtList)
# Out:
# count:  1  ft:  Fwd PSH Flags  ftmin:  0  ftMax:  0
# count:  2  ft:  Fwd URG Flags  ftmin:  0  ftMax:  0
# count:  3  ft:  Bwd URG Flags  ftmin:  0  ftMax:  0
# count:  4  ft:  URG Flag Cnt  ftmin:  0  ftMax:  0
# count:  5  ft:  CWE Flag Count  ftmin:  0  ftMax:  0
# count:  6  ft:  ECE Flag Cnt  ftmin:  0  ftMax:  0
# count:  7  ft:  Fwd Byts/b Avg  ftmin:  0  ftMax:  0
# count:  8  ft:  Fwd Pkts/b Avg  ftmin:  0  ftMax:  0
# count:  9  ft:  Fwd Blk Rate Avg  ftmin:  0  ftMax:  0
# count:  10  ft:  Bwd Byts/b Avg  ftmin:  0  ftMax:  0
# count:  11  ft:  Bwd Pkts/b Avg  ftmin:  0  ftMax:  0
# count:  12  ft:  Bwd Blk Rate Avg  ftmin:  0  ftMax:  0
# count:  13  ft:  Init Fwd Win Byts  ftmin:  -1  ftMax:  -1
# count:  14  ft:  Fwd Seg Size Min  ftmin:  0  ftMax:  0
# ['Fwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'URG Flag Cnt', 'CWE Flag Count', 'ECE Flag Cnt', 'Fwd Byts/b Avg', 'Fwd Pkts/b Avg', 'Fwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Pkts/b Avg', 'Bwd Blk Rate Avg', 'Init Fwd Win Byts', 'Fwd Seg Size Min']

# %%
#remove those columns that have 0 std
print('before droping column: ', masterSelected.shape)
for ft in staticFtList:
    masterSelected.drop([ft], axis=1,inplace=True)
print('after droping column: ', masterSelected.shape)
# Out:
# before droping column:  (35293, 77)
# after droping column:  (35293, 63)

# %%
xCount = masterSelected.shape[1]
print(xCount)
finalFtList = list(masterSelected.columns)
print(finalFtList)
# Out:
# 63
# ['Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow Pkts/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Bwd PSH Flags', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std', 'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'Down/Up Ratio', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg', 'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts', 'Subflow Bwd Byts', 'Init Bwd Win Byts', 'Fwd Act Data Pkts', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'Label']

# %%
#report intermediate data frame to a csv
#masterSelected.to_csv('../reports_db/CICFlowMeter_VideoConferencingOutput/ProcessedNPrunnedAllConf.csv', index = False)

# %%
#classification with all the features
masterDS = masterSelected.values
X = masterDS[:,:-1]
Y = masterDS[:,-1]
print("Xshape: ", X.shape)
print("Yshape: ", Y.shape)
# Out:
# Xshape:  (35293, 62)
# Yshape:  (35293,)

# %%
# feature selection using ANNOVA F-score
topKval = 10
rfe = RFE(estimator=DecisionTreeClassifier(), n_features_to_select=topKval)
# fit RFE
rfe.fit(X, Y)
# summarize all features

# transform train input data
XNew = rfe.transform(X)
# transform test input data
print('XNew.shape', XNew.shape)
#print('XNew', XNew)
# Out:
# XNew.shape (35293, 10)

# %%
ftSelected = list()#features[0:-1]
for fi in range(xCount-1):
    ft  = finalFtList[fi]
    
    if ft != 'Label' and rfe.support_[fi]:
        #print('i = ', fi, ' ftName: ', ftList[fi], ' FS.support_: ', FS.get_support()[fi], ' FS.scores: = ', FS.scores_[fi])
        #scores.append(ref.scores_[fi])
        ftSelected.append(ft)
        print('Column: %d, ColName: %s, Selected %s, Rank: %.3f' % (fi, finalFtList[fi], rfe.support_[fi], rfe.ranking_[fi]))
print(ftSelected)
# Out:
# Column: 0, ColName: Flow Duration, Selected True, Rank: 1.000
# Column: 5, ColName: Fwd Pkt Len Max, Selected True, Rank: 1.000
# Column: 9, ColName: Bwd Pkt Len Max, Selected True, Rank: 1.000
# Column: 14, ColName: Flow Pkts/s, Selected True, Rank: 1.000
# Column: 18, ColName: Flow IAT Min, Selected True, Rank: 1.000
# Column: 28, ColName: Bwd IAT Min, Selected True, Rank: 1.000
# Column: 31, ColName: Bwd Header Len, Selected True, Rank: 1.000
# Column: 32, ColName: Fwd Pkts/s, Selected True, Rank: 1.000
# Column: 38, ColName: Pkt Len Var, Selected True, Rank: 1.000
# Column: 52, ColName: Init Bwd Win Byts, Selected True, Rank: 1.000
# ['Flow Duration', 'Fwd Pkt Len Max', 'Bwd Pkt Len Max', 'Flow Pkts/s', 'Flow IAT Min', 'Bwd IAT Min', 'Bwd Header Len', 'Fwd Pkts/s', 'Pkt Len Var', 'Init Bwd Win Byts']

# %%
clf = DecisionTreeClassifier(random_state=0)
print('classification with top 10 selected features:')
scores = cross_val_score(clf, XNew, Y, cv=10)
print(scores)
print('mean score: ', scores.mean(), 'min score: ', scores.min(), 'max score: ', scores.max(), ' std score: ', scores.std())
# Out:
# classification with top 10 selected features:
# [0.87365439 0.95467422 0.94390935 0.94559365 0.95041088 0.91697365
#  0.91952394 0.96911306 0.95409464 0.76678946]
# mean score:  0.9194737251923961 min score:  0.7667894587701899 max score:  0.9691130631907056  std score:  0.05705817580296539

# %%
#performance with to k  features using decision tree
X_train, X_test, Y_train, Y_test = train_test_split(XNew, Y, test_size=0.33, random_state=1)
model = DecisionTreeClassifier(random_state=0)
clf = model.fit(X_train,Y_train)
yhat = model.predict(X_test)

# %%
from sklearn.tree import export_text
from sklearn import tree
#r = export_text(decision_tree, feature_names=finalFtList)
#print(r)
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_9 <= 260.50
# |   |--- feature_4 <= 10.50
# |   |   |--- feature_0 <= 117893032.00
# |   |   |   |--- feature_7 <= 0.10
# |   |   |   |   |--- feature_8 <= 155281.81
# |   |   |   |   |   |--- feature_8 <= 11.33
# |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |--- feature_8 >  11.33
# |   |   |   |   |   |   |--- feature_7 <= 0.09
# |   |   |   |   |   |   |   |--- feature_8 <= 44.29
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |--- feature_8 >  44.29
# |   |   |   |   |   |   |   |   |--- feature_8 <= 108568.17
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_8 >  108568.17
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_7 >  0.09
# |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |--- feature_8 >  155281.81
# |   |   |   |   |   |--- feature_3 <= 0.30
# |   |   |   |   |   |   |--- feature_2 <= 2016.50
# |   |   |   |   |   |   |   |--- feature_9 <= 236.00
# |   |   |   |   |   |   |   |   |--- feature_8 <= 296940.12
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 96207384.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 290779.73
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  290779.73
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  96207384.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_8 >  296940.12
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_9 >  236.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.07
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.07
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_2 >  2016.50
# |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |--- feature_3 >  0.30
# |   |   |   |   |   |   |--- feature_0 <= 64384122.00
# |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_0 >  64384122.00
# |   |   |   |   |   |   |   |--- feature_3 <= 0.33
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1350.50
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_1 >  1350.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_3 >  0.33
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |--- feature_7 >  0.10
# |   |   |   |   |--- feature_9 <= 44.00
# |   |   |   |   |   |--- feature_3 <= 703.64
# |   |   |   |   |   |   |--- feature_1 <= 1300.00
# |   |   |   |   |   |   |   |--- feature_1 <= 317.00
# |   |   |   |   |   |   |   |   |--- feature_8 <= 478.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 259.85
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 19.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  19.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  259.85
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 15.07
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  15.07
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_8 >  478.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_1 >  317.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2.37
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 23569.16
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 456.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  456.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  23569.16
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 564.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  564.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_3 >  2.37
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 56.12
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 2362447.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  2362447.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  56.12
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 96392.99
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  96392.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |--- feature_1 >  1300.00
# |   |   |   |   |   |   |   |--- feature_2 <= 3.50
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_2 >  3.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 13.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 66594338.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  66594338.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_9 >  13.50
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |--- feature_3 >  703.64
# |   |   |   |   |   |   |--- feature_8 <= 57.60
# |   |   |   |   |   |   |   |--- feature_7 <= 84126.98
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_7 >  84126.98
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_8 >  57.60
# |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |--- feature_9 >  44.00
# |   |   |   |   |   |--- feature_8 <= 487955.47
# |   |   |   |   |   |   |--- feature_1 <= 12.50
# |   |   |   |   |   |   |   |--- feature_2 <= 709.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.70
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 168.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  168.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.70
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 26.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  26.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_2 >  709.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 16467.00
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_0 >  16467.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_1 >  12.50
# |   |   |   |   |   |   |   |--- feature_6 <= 202.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1450.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 48.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  48.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 478423.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  478423.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_1 >  1450.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_6 >  202.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 59.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_2 >  59.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 51.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  51.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 348.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  348.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |--- feature_8 >  487955.47
# |   |   |   |   |   |   |--- feature_2 <= 1885.50
# |   |   |   |   |   |   |   |--- feature_8 <= 492371.78
# |   |   |   |   |   |   |   |   |--- feature_9 <= 133.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_9 >  133.50
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_8 >  492371.78
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1450.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 497251.94
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 181.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  181.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  497251.94
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_1 >  1450.00
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_2 >  1885.50
# |   |   |   |   |   |   |   |--- class: VShare
# |   |   |--- feature_0 >  117893032.00
# |   |   |   |--- feature_2 <= 765.50
# |   |   |   |   |--- feature_1 <= 87.00
# |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |--- feature_1 >  87.00
# |   |   |   |   |   |--- feature_9 <= 129.00
# |   |   |   |   |   |   |--- feature_1 <= 1239.00
# |   |   |   |   |   |   |   |--- feature_4 <= 7.50
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_4 >  7.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 54.01
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_7 >  54.01
# |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |--- feature_1 >  1239.00
# |   |   |   |   |   |   |   |--- feature_1 <= 1253.50
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_1 >  1253.50
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |--- feature_9 >  129.00
# |   |   |   |   |   |   |--- class: VShare
# |   |   |   |--- feature_2 >  765.50
# |   |   |   |   |--- feature_8 <= 420525.86
# |   |   |   |   |   |--- feature_3 <= 2.32
# |   |   |   |   |   |   |--- feature_6 <= 386.00
# |   |   |   |   |   |   |   |--- feature_8 <= 405976.17
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_8 >  405976.17
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.23
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.23
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 340.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  340.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_6 >  386.00
# |   |   |   |   |   |   |   |--- feature_6 <= 424.00
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_6 >  424.00
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |--- feature_3 >  2.32
# |   |   |   |   |   |   |--- feature_4 <= 3.00
# |   |   |   |   |   |   |   |--- feature_8 <= 9577.86
# |   |   |   |   |   |   |   |   |--- feature_4 <= 1.00
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_4 >  1.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_8 >  9577.86
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_4 >  3.00
# |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |--- feature_8 >  420525.86
# |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |--- class: VShare
# |   |--- feature_4 >  10.50
# |   |   |--- feature_8 <= 0.74
# |   |   |   |--- feature_9 <= 197.50
# |   |   |   |   |--- feature_7 <= 19.03
# |   |   |   |   |   |--- feature_5 <= 45150000.00
# |   |   |   |   |   |   |--- feature_3 <= 0.05
# |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |--- feature_3 >  0.05
# |   |   |   |   |   |   |   |--- feature_9 <= 70.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 467.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 868.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 84115.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  84115.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 15
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  868.00
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_2 >  467.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 7139012.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  1.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  7139012.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_9 >  70.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 112.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 290244.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  290244.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 297409.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  297409.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_9 >  112.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 47656.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 6612.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  6612.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  47656.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 82905272.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  82905272.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- feature_5 >  45150000.00
# |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |--- feature_7 >  19.03
# |   |   |   |   |   |--- feature_9 <= 64.50
# |   |   |   |   |   |   |--- feature_0 <= 584.50
# |   |   |   |   |   |   |   |--- feature_9 <= -0.50
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |--- feature_9 >  -0.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 61.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 4285.71
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  4285.71
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 209.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  209.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_5 >  61.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_0 >  584.50
# |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |--- feature_9 >  64.50
# |   |   |   |   |   |   |--- class: VConf
# |   |   |   |--- feature_9 >  197.50
# |   |   |   |   |--- feature_5 <= 418.00
# |   |   |   |   |   |--- feature_7 <= 101.64
# |   |   |   |   |   |   |--- feature_3 <= 13292.70
# |   |   |   |   |   |   |   |--- feature_6 <= 94.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 288.50
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_5 >  288.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 6476.25
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  6476.25
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_6 >  94.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 291554.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_0 >  291554.00
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_3 >  13292.70
# |   |   |   |   |   |   |   |--- feature_6 <= 46.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 245.00
# |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_9 >  245.00
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_6 >  46.00
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |--- feature_7 >  101.64
# |   |   |   |   |   |   |--- feature_9 <= 246.00
# |   |   |   |   |   |   |   |--- feature_4 <= 416.50
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |--- feature_4 >  416.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 1980.70
# |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_7 >  1980.70
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_9 >  246.00
# |   |   |   |   |   |   |   |--- feature_0 <= 27.50
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_0 >  27.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 2065.50
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_0 >  2065.50
# |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |--- feature_5 >  418.00
# |   |   |   |   |   |--- feature_6 <= 88.00
# |   |   |   |   |   |   |--- feature_3 <= 4.63
# |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_3 >  4.63
# |   |   |   |   |   |   |   |--- feature_9 <= 245.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 236.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 46.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  46.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 16.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  16.97
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_9 >  236.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 843.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 568.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  568.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  843.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 52093.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  52093.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_9 >  245.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 46.00
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_6 >  46.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 68.15
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  68.15
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |--- feature_6 >  88.00
# |   |   |   |   |   |   |--- feature_7 <= 1.47
# |   |   |   |   |   |   |   |--- feature_5 <= 191294.00
# |   |   |   |   |   |   |   |   |--- feature_4 <= 1006.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_4 >  1006.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 97442504.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  97442504.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_5 >  191294.00
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |--- feature_7 >  1.47
# |   |   |   |   |   |   |   |--- feature_9 <= 232.00
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_9 >  232.00
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |--- feature_8 >  0.74
# |   |   |   |--- feature_9 <= 128.00
# |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |--- feature_7 <= 0.01
# |   |   |   |   |   |   |--- feature_6 <= 70.00
# |   |   |   |   |   |   |   |--- feature_8 <= 19804.17
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |--- feature_8 >  19804.17
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_6 >  70.00
# |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |--- feature_7 >  0.01
# |   |   |   |   |   |   |--- feature_5 <= 283640.00
# |   |   |   |   |   |   |   |--- feature_2 <= 33.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 27.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 13.00
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  13.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_2 >  27.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 119.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  119.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_2 >  33.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 299379.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_0 >  299379.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 3.59
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 140.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  140.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  3.59
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |--- feature_5 >  283640.00
# |   |   |   |   |   |   |   |--- feature_7 <= 1.44
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_7 >  1.44
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |--- feature_1 <= 1435.00
# |   |   |   |   |   |   |--- feature_8 <= 510073.16
# |   |   |   |   |   |   |   |--- feature_4 <= 50802.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 30100000.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.18
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 42518.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  42518.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_5 >  30100000.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_4 >  50802.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 12.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_6 >  12.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 18.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 66.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  66.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  18.00
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |--- feature_8 >  510073.16
# |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |--- feature_1 >  1435.00
# |   |   |   |   |   |   |--- feature_0 <= 4898626.00
# |   |   |   |   |   |   |   |--- feature_8 <= 566602.28
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |--- feature_8 >  566602.28
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_0 >  4898626.00
# |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |--- feature_9 >  128.00
# |   |   |   |   |--- feature_0 <= 17879222.50
# |   |   |   |   |   |--- feature_9 <= 236.00
# |   |   |   |   |   |   |--- feature_2 <= 279.00
# |   |   |   |   |   |   |   |--- feature_6 <= 92.00
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_6 >  92.00
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |--- feature_2 >  279.00
# |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |--- feature_9 >  236.00
# |   |   |   |   |   |   |--- feature_6 <= 262.00
# |   |   |   |   |   |   |   |--- feature_8 <= 124771.07
# |   |   |   |   |   |   |   |   |--- feature_6 <= 204.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 7576070.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 260.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  260.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  7576070.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12571537.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  12571537.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_6 >  204.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 248.00
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  248.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_8 >  124771.07
# |   |   |   |   |   |   |   |   |--- feature_6 <= 168.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_6 >  168.00
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_6 >  262.00
# |   |   |   |   |   |   |   |--- feature_2 <= 1458.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 262.50
# |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_5 >  262.50
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_2 >  1458.00
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |--- feature_0 >  17879222.50
# |   |   |   |   |   |--- feature_6 <= 230.00
# |   |   |   |   |   |   |--- feature_6 <= 90.00
# |   |   |   |   |   |   |   |--- feature_5 <= 338.00
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_5 >  338.00
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_6 >  90.00
# |   |   |   |   |   |   |   |--- feature_4 <= 483.50
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_4 >  483.50
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |--- feature_6 >  230.00
# |   |   |   |   |   |   |--- feature_7 <= 0.72
# |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_7 >  0.72
# |   |   |   |   |   |   |   |--- class: VConf
# |--- feature_9 >  260.50
# |   |--- feature_5 <= 25.50
# |   |   |--- feature_3 <= 4.24
# |   |   |   |--- feature_9 <= 505.00
# |   |   |   |   |--- feature_1 <= 155.50
# |   |   |   |   |   |--- feature_6 <= 114.00
# |   |   |   |   |   |   |--- feature_0 <= 43424366.00
# |   |   |   |   |   |   |   |--- feature_1 <= 101.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 345.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 338.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  338.50
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_9 >  345.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 11264026.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  11264026.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_1 >  101.00
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_0 >  43424366.00
# |   |   |   |   |   |   |   |--- feature_3 <= 0.05
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_3 >  0.05
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |--- feature_6 >  114.00
# |   |   |   |   |   |   |--- feature_1 <= 13.50
# |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_1 >  13.50
# |   |   |   |   |   |   |   |--- feature_4 <= 3.00
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_4 >  3.00
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |--- feature_1 >  155.50
# |   |   |   |   |   |--- feature_4 <= 11.00
# |   |   |   |   |   |   |--- feature_2 <= 33.50
# |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_2 >  33.50
# |   |   |   |   |   |   |   |--- feature_7 <= 0.07
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_7 >  0.07
# |   |   |   |   |   |   |   |   |--- feature_3 <= 3.56
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 411.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.79
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.79
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  411.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 202.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  202.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_3 >  3.56
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |--- feature_4 >  11.00
# |   |   |   |   |   |   |--- feature_8 <= 293659.66
# |   |   |   |   |   |   |   |--- feature_9 <= 501.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 632.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 260207.70
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 47241106.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  47241106.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  260207.70
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_6 >  632.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1417.00
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1417.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_9 >  501.50
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_8 >  293659.66
# |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |--- feature_9 >  505.00
# |   |   |   |   |--- feature_1 <= 1450.00
# |   |   |   |   |   |--- feature_0 <= 59920288.00
# |   |   |   |   |   |   |--- feature_4 <= 1067039.50
# |   |   |   |   |   |   |   |--- feature_3 <= 3.43
# |   |   |   |   |   |   |   |   |--- feature_6 <= 36.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 235.25
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 685656.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  685656.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  235.25
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_6 >  36.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 4865043.50
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  4865043.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 403912.81
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  403912.81
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_3 >  3.43
# |   |   |   |   |   |   |   |   |--- feature_9 <= 513.00
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_9 >  513.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1435.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2.91
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  2.91
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1435.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 2050.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  2050.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_4 >  1067039.50
# |   |   |   |   |   |   |   |--- feature_6 <= 36.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 40020716.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 516.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 511.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 17
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  511.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  516.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 45277.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  45277.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_0 >  40020716.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 40035654.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 40028112.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  40028112.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  40035654.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 40050000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  40050000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_6 >  36.00
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |--- feature_0 >  59920288.00
# |   |   |   |   |   |   |--- feature_1 <= 114.00
# |   |   |   |   |   |   |   |--- feature_9 <= 508.50
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_9 >  508.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 12698.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.41
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.41
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 394.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  394.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_2 >  12698.00
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_1 >  114.00
# |   |   |   |   |   |   |   |--- feature_1 <= 1423.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 57.00
# |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_2 >  57.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 496.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 418686.92
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  418686.92
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  496.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 4619.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  4619.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_1 >  1423.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 60985688.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 524.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  524.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_0 >  60985688.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 16382.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 93460116.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  93460116.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  16382.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 732.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  732.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |--- feature_1 >  1450.00
# |   |   |   |   |   |--- feature_3 <= 0.61
# |   |   |   |   |   |   |--- feature_0 <= 113625600.00
# |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_0 >  113625600.00
# |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |--- feature_3 >  0.61
# |   |   |   |   |   |   |--- class: VShare
# |   |   |--- feature_3 >  4.24
# |   |   |   |--- feature_4 <= 11.50
# |   |   |   |   |--- feature_9 <= 1021.50
# |   |   |   |   |   |--- feature_9 <= 261.50
# |   |   |   |   |   |   |--- feature_1 <= 258.50
# |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_1 >  258.50
# |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |--- feature_9 >  261.50
# |   |   |   |   |   |   |--- feature_5 <= 20.00
# |   |   |   |   |   |   |   |--- feature_3 <= 198.03
# |   |   |   |   |   |   |   |   |--- feature_1 <= 19.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 501.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  501.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_1 >  19.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 238.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 4.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  4.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  238.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 141219.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  141219.07
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_3 >  198.03
# |   |   |   |   |   |   |   |   |--- feature_5 <= 5.50
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_5 >  5.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 394.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  394.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_5 >  20.00
# |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |--- feature_9 >  1021.50
# |   |   |   |   |   |--- feature_0 <= 3581766.50
# |   |   |   |   |   |   |--- feature_8 <= 448056.59
# |   |   |   |   |   |   |   |--- feature_1 <= 514.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 1080.49
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_3 >  1080.49
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1081.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  1081.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_1 >  514.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1450.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 174.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  174.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1435.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1435.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |--- feature_1 >  1450.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_8 >  448056.59
# |   |   |   |   |   |   |   |--- feature_7 <= 45.01
# |   |   |   |   |   |   |   |   |--- feature_8 <= 484054.53
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 479885.69
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  479885.69
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_8 >  484054.53
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_7 >  45.01
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |--- feature_0 >  3581766.50
# |   |   |   |   |   |   |--- feature_4 <= 1.00
# |   |   |   |   |   |   |   |--- feature_9 <= 16384.00
# |   |   |   |   |   |   |   |   |--- feature_8 <= 310375.62
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 3.58
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  3.58
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_8 >  310375.62
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 37.98
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  37.98
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 443813.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  443813.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_9 >  16384.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1450.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_1 >  1450.00
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_4 >  1.00
# |   |   |   |   |   |   |   |--- feature_1 <= 1438.00
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_1 >  1438.00
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |--- feature_4 >  11.50
# |   |   |   |   |--- feature_9 <= 1027.50
# |   |   |   |   |   |--- feature_9 <= 1011.50
# |   |   |   |   |   |   |--- feature_3 <= 13029.45
# |   |   |   |   |   |   |   |--- feature_6 <= 26.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 116070.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 15.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 263.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  263.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 13
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  15.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 696.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  696.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_0 >  116070.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 513.50
# ...
# |   |   |   |   |   |   |--- feature_9 >  5660.50
# |   |   |   |   |   |   |   |--- feature_4 <= 26.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 315.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 25.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  25.00
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_5 >  315.00
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_4 >  26.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 28041.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 68.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 144.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  144.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  68.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 7884.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  7884.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_9 >  28041.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 47.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  31.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  47.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- feature_1 >  1444.00
# |   |   |   |   |   |--- feature_8 <= 314107.33
# |   |   |   |   |   |   |--- feature_9 <= 397.50
# |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_9 >  397.50
# |   |   |   |   |   |   |   |--- feature_8 <= 136789.91
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.32
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.32
# |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |--- feature_8 >  136789.91
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |--- feature_8 >  314107.33
# |   |   |   |   |   |   |--- feature_9 <= 305.50
# |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |--- feature_9 >  305.50
# |   |   |   |   |   |   |   |--- feature_4 <= 9.50
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_4 >  9.50
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |--- feature_4 >  780.00
# |   |   |   |   |--- feature_4 <= 3020.00
# |   |   |   |   |   |--- feature_9 <= 1471.00
# |   |   |   |   |   |   |--- feature_9 <= 506.50
# |   |   |   |   |   |   |   |--- feature_9 <= 341.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 3.56
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 32.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  32.00
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_7 >  3.56
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 262.00
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  262.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_9 >  341.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.20
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 1357.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  1357.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.20
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 490.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 440.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  440.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  490.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 58.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  58.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |--- feature_9 >  506.50
# |   |   |   |   |   |   |   |--- feature_8 <= 177.61
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.02
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.02
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 4155.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 2240.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  2240.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  4155.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_8 >  177.61
# |   |   |   |   |   |   |   |   |--- feature_9 <= 1461.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 73.50
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  73.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 3.29
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  3.29
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_9 >  1461.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |--- feature_9 >  1471.00
# |   |   |   |   |   |   |--- feature_3 <= 0.13
# |   |   |   |   |   |   |   |--- feature_7 <= 0.00
# |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |--- feature_7 >  0.00
# |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_3 >  0.13
# |   |   |   |   |   |   |   |--- feature_9 <= 46436.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 529025.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 1726.44
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1689.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  1689.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  1726.44
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 2004.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  2004.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_5 >  529025.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 1390.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  1390.50
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |--- feature_9 >  46436.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 63892.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_9 >  63892.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 64767.50
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  64767.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |--- feature_4 >  3020.00
# |   |   |   |   |   |--- feature_7 <= 0.06
# |   |   |   |   |   |   |--- feature_5 <= 59752.50
# |   |   |   |   |   |   |   |--- feature_4 <= 49260.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 309.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 15392.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 15279.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  15279.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  15392.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_9 >  309.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 60024362.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 62.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  62.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  60024362.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 54557.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  54557.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_4 >  49260.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.02
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 59044.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 90218464.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  90218464.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  59044.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.02
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 2051.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 110241204.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  110241204.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  2051.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |--- feature_5 >  59752.50
# |   |   |   |   |   |   |   |--- feature_6 <= 158.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 8.24
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 119864304.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 263.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  263.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  119864304.00
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_3 >  8.24
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 213818.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 178712.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  178712.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  213818.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 62.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  62.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |--- feature_6 >  158.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 15716517.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 46209.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  46209.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 14890239.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  14890239.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |--- feature_0 >  15716517.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |--- feature_7 >  0.06
# |   |   |   |   |   |   |--- feature_2 <= 172.50
# |   |   |   |   |   |   |   |--- feature_6 <= 890.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 1.07
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 57.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  57.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 119.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  119.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_7 >  1.07
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 247.40
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  247.40
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 3087.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  3087.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_6 >  890.00
# |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |--- feature_2 >  172.50
# |   |   |   |   |   |   |   |--- feature_4 <= 33589.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 993.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 103350.80
# |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  103350.80
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |--- feature_9 >  993.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 5294.90
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 4136.22
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  4136.22
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  5294.90
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf
# |   |   |   |   |   |   |   |--- feature_4 >  33589.50
# |   |   |   |   |   |   |   |   |--- feature_5 <= 382035.00
# |   |   |   |   |   |   |   |   |   |--- class: VShare
# |   |   |   |   |   |   |   |   |--- feature_5 >  382035.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 75485356.00
# |   |   |   |   |   |   |   |   |   |   |--- class: IPCam
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  75485356.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf

# %%
print(clf.tree_.max_depth)
# Out:
# 31

# %%
comb_mat = metrics.confusion_matrix(Y_test, yhat,labels=uniqueLabels)
#[i][j] ==> knwon to be in group i and predicted as group j
print(comb_mat)
print('\n')
print('IPCam as IPCam = ',comb_mat[0][0],' percent = ', (comb_mat[0][0]/(comb_mat[0][0]+comb_mat[0][1]+comb_mat[0][2])))
print('IPCam as VShare = ',comb_mat[0][1],' percent = ', (comb_mat[0][1]/(comb_mat[0][0]+comb_mat[0][1]+comb_mat[0][2])))
print('IPCam as VConf = ',comb_mat[0][2],' percent = ', (comb_mat[0][2]/(comb_mat[0][0]+comb_mat[0][1]+comb_mat[0][2])))
print('\n')

print('VShare as IPCam = ',comb_mat[1][0],' percent = ', (comb_mat[1][0]/(comb_mat[1][0]+comb_mat[1][1]+comb_mat[1][2])))
print('VShare as VShare = ',comb_mat[1][1],' percent = ', (comb_mat[1][1]/(comb_mat[1][0]+comb_mat[1][1]+comb_mat[1][2])))
print('VShare as VConf = ',comb_mat[1][2],' percent = ', (comb_mat[1][2]/(comb_mat[1][0]+comb_mat[1][1]+comb_mat[1][2])))
print('\n')

print('VConf as IPCam = ',comb_mat[2][0],' percent = ', (comb_mat[2][0]/(comb_mat[2][0]+comb_mat[2][1]+comb_mat[2][2])))
print('VConf as VShare = ',comb_mat[2][1],' percent = ', (comb_mat[2][1]/(comb_mat[2][0]+comb_mat[2][1]+comb_mat[2][2])))
print('VConf as VConf = ',comb_mat[2][2],' percent = ', (comb_mat[2][2]/(comb_mat[2][0]+comb_mat[2][1]+comb_mat[2][2])))
print('\n')
# Out:
# [[1747   19   45]
#  [  18 1379  261]
#  [  47  187 7944]]
#
#
# IPCam as IPCam =  1747  percent =  0.9646604086140254
# IPCam as VShare =  19  percent =  0.010491441192711209
# IPCam as VConf =  45  percent =  0.02484815019326339
#
#
# VShare as IPCam =  18  percent =  0.010856453558504222
# VShare as VShare =  1379  percent =  0.8317249698431846
# VShare as VConf =  261  percent =  0.1574185765983112
#
#
# VConf as IPCam =  47  percent =  0.005747126436781609
# VConf as VShare =  187  percent =  0.022866226461237465
# VConf as VConf =  7944  percent =  0.971386647101981

# %%
#classification with unselected and uncorrelated features
corr = masterSelected.corr()
corr.shape
# Out:
# (62, 62)

# %%
corrThreshold = 0.65
unCorrUnSelFtList = list()
for ft1 in finalFtList:#baseft = 'Idle Max' for each of the selected features
    #print('ft1: ', ft1)
    isCorr = False
    for ft2 in ftSelected:# for each of the top 10 features
        if ft1 == 'Label' or ft2 == 'Label' or (ft1 == ft2):
            continue
        elif abs(corr[ft1][ft2]) > corrThreshold:
                isCorr = True
                print('ft1: ', ft1, 'ft2: ', ft2, '  corr: ', corr[ft1][ft2])
                break
    if not isCorr and ft1 not in unCorrUnSelFtList:
        #print('corr[{0}][{1}] = {2}: isPresentInRestFtlist: {3}'.format(baseft,ft,corr[baseft][ft], ft in restFtList))
        unCorrUnSelFtList.append(ft1)
        
    #elif abs(corr[ft1][ft] >= 0.6 and ft in unCorrUnSelFtList):
    #            unCorrUnSelFtList.remove(ft)
print(len(unCorrUnSelFtList))
print(unCorrUnSelFtList)

print(len(ftSelected))
print(ftSelected)
# Out:
# ft1:  Tot Bwd Pkts ft2:  Bwd Header Len   corr:  0.9356023825019839
# ft1:  TotLen Bwd Pkts ft2:  Bwd Header Len   corr:  0.9258529199187021
# ft1:  Fwd Pkt Len Mean ft2:  Fwd Pkt Len Max   corr:  0.7127070477489826
# ft1:  Fwd Pkt Len Std ft2:  Fwd Pkt Len Max   corr:  0.9171028368901895
# ft1:  Bwd Pkt Len Max ft2:  Pkt Len Var   corr:  0.8203394635142593
# ft1:  Bwd Pkt Len Mean ft2:  Bwd Pkt Len Max   corr:  0.8000676570388525
# ft1:  Bwd Pkt Len Std ft2:  Bwd Pkt Len Max   corr:  0.8654480872422861
# ft1:  Flow IAT Mean ft2:  Flow IAT Min   corr:  0.8696713174772769
# ft1:  Fwd IAT Tot ft2:  Flow Duration   corr:  0.9301274242854811
# ft1:  Bwd IAT Tot ft2:  Flow Duration   corr:  0.8570824496440947
# ft1:  Bwd IAT Mean ft2:  Bwd IAT Min   corr:  0.6778428103419295
# ft1:  Fwd Header Len ft2:  Bwd Header Len   corr:  0.6972497597089348
# ft1:  Bwd Pkts/s ft2:  Flow Pkts/s   corr:  0.9454690883035327
# ft1:  Pkt Len Max ft2:  Bwd Pkt Len Max   corr:  0.986593289545737
# ft1:  Pkt Len Mean ft2:  Bwd Pkt Len Max   corr:  0.6807630251554712
# ft1:  Pkt Len Std ft2:  Bwd Pkt Len Max   corr:  0.8484616676187658
# ft1:  Pkt Len Var ft2:  Bwd Pkt Len Max   corr:  0.8203394635142593
# ft1:  Pkt Size Avg ft2:  Bwd Pkt Len Max   corr:  0.6717961865941147
# ft1:  Fwd Seg Size Avg ft2:  Fwd Pkt Len Max   corr:  0.7127070477489826
# ft1:  Bwd Seg Size Avg ft2:  Bwd Pkt Len Max   corr:  0.8000676570388559
# ft1:  Subflow Bwd Pkts ft2:  Bwd Header Len   corr:  0.9356023825019839
# ft1:  Subflow Bwd Byts ft2:  Bwd Header Len   corr:  0.9258639460025644
# 41
# ['Flow Duration', 'Tot Fwd Pkts', 'TotLen Fwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min', 'Bwd Pkt Len Min', 'Flow Byts/s', 'Flow Pkts/s', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Bwd PSH Flags', 'Bwd Header Len', 'Fwd Pkts/s', 'Pkt Len Min', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'Down/Up Ratio', 'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Init Bwd Win Byts', 'Fwd Act Data Pkts', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'Label']
# 10
# ['Flow Duration', 'Fwd Pkt Len Max', 'Bwd Pkt Len Max', 'Flow Pkts/s', 'Flow IAT Min', 'Bwd IAT Min', 'Bwd Header Len', 'Fwd Pkts/s', 'Pkt Len Var', 'Init Bwd Win Byts']

# %%
for ft1 in ftSelected:
    for ft2 in unCorrUnSelFtList:
        if ft1 != 'Label' or ft2 == 'Label':
            continue
        if abs(corr[ft][ft2]) >= corrThreshold:
            print('ft: ',ft, ' ft2: ',ft2, corr[ft][ft2])

# %%
#slice master data frame to only uncorrelated and unselected features
masterUnSelected = masterSelected[unCorrUnSelFtList]
print(masterUnSelected.shape)
# Out:
# (35293, 41)

# %%
#### classification with unselected columns
masterUnSelDS = masterUnSelected.values
Xnotsel = masterUnSelDS[:,:-1]
Y = masterUnSelDS[:,-1]
print("Xshape: ", Xnotsel.shape)
print("Yshape: ", Y.shape)
# Out:
# Xshape:  (35293, 40)
# Yshape:  (35293,)

# %%
#find cross validation score with uncorrelated and unselecte feature data frame
clf = DecisionTreeClassifier(random_state=0)
print('classification with rest (not top 10) features:')
scores = cross_val_score(clf, Xnotsel, Y, cv=10)
print(scores)
print('mean score: ', scores.mean(), 'min score: ', scores.min(), 'max score: ', scores.max(), ' std score: ', scores.std())
# Out:
# classification with rest (not top 10) features:
# [0.88895184 0.94730878 0.95155807 0.94757722 0.95352791 0.91612355
#  0.9334089  0.96429583 0.95862851 0.78690847]
# mean score:  0.9248289085095811 min score:  0.7869084726551431 max score:  0.9642958345140267  std score:  0.05071446784262303

# %%
#classification with with uncorrelated and unselecte feature data frame
X_train, X_test, Y_train, Y_test = train_test_split(Xnotsel, Y, test_size=0.33, random_state=1)
model = DecisionTreeClassifier(random_state=0)
model.fit(X_train,Y_train)
yhat = model.predict(X_test)

# %%
comb_mat = metrics.confusion_matrix(Y_test, yhat,labels=uniqueLabels)
#[i][j] ==> knwon to be in group i and predicted as group j
print(comb_mat)
print('\n')
print('IPCam as IPCam = ',comb_mat[0][0],' percent = ', (comb_mat[0][0]/(comb_mat[0][0]+comb_mat[0][1]+comb_mat[0][2])))
print('IPCam as VShare = ',comb_mat[0][1],' percent = ', (comb_mat[0][1]/(comb_mat[0][0]+comb_mat[0][1]+comb_mat[0][2])))
print('IPCam as VConf = ',comb_mat[0][2],' percent = ', (comb_mat[0][2]/(comb_mat[0][0]+comb_mat[0][1]+comb_mat[0][2])))
print('\n')

print('VShare as IPCam = ',comb_mat[1][0],' percent = ', (comb_mat[1][0]/(comb_mat[1][0]+comb_mat[1][1]+comb_mat[1][2])))
print('VShare as VShare = ',comb_mat[1][1],' percent = ', (comb_mat[1][1]/(comb_mat[1][0]+comb_mat[1][1]+comb_mat[1][2])))
print('VShare as VConf = ',comb_mat[1][2],' percent = ', (comb_mat[1][2]/(comb_mat[1][0]+comb_mat[1][1]+comb_mat[1][2])))
print('\n')

print('VConf as IPCam = ',comb_mat[2][0],' percent = ', (comb_mat[2][0]/(comb_mat[2][0]+comb_mat[2][1]+comb_mat[2][2])))
print('VConf as VShare = ',comb_mat[2][1],' percent = ', (comb_mat[2][1]/(comb_mat[2][0]+comb_mat[2][1]+comb_mat[2][2])))
print('VConf as VConf = ',comb_mat[2][2],' percent = ', (comb_mat[2][2]/(comb_mat[2][0]+comb_mat[2][1]+comb_mat[2][2])))
print('\n')
# Out:
# [[1749   21   41]
#  [  15 1409  234]
#  [  44  168 7966]]
#
#
# IPCam as IPCam =  1749  percent =  0.9657647708448371
# IPCam as VShare =  21  percent =  0.011595803423522915
# IPCam as VConf =  41  percent =  0.02263942573163998
#
#
# VShare as IPCam =  15  percent =  0.009047044632086852
# VShare as VShare =  1409  percent =  0.8498190591073582
# VShare as VConf =  234  percent =  0.1411338962605549
#
#
# VConf as IPCam =  44  percent =  0.005380288579114698
# VConf as VShare =  168  percent =  0.020542920029347028
# VConf as VConf =  7966  percent =  0.9740767913915382
