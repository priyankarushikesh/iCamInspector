# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.feature_selection import RFE
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from matplotlib import pyplot

# %%
fnames = ["D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet6_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet7_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet8_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet9_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet10_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet11_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet12_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams11_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams12_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams21_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams22_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_2_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_3_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_6_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_7_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_8_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_9_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_10_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_11_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_12_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_13_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_14_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_15_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom5_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom_6_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom_7_Flow.csv",
          #"D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom_8_Flow.csv",
         ]

# %%
dfList = list()
for fname in fnames: 
    data = pd.read_csv(fname)
    print('file:', fname, ' data size: ',data.shape)
    dfList.append(data)
############## combine the data frames
masterDF = pd.concat(dfList)
print(masterDF.shape)
# Out:
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet1_Flow.csv  data size:  (2620, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet2_Flow.csv  data size:  (3350, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet3_Flow.csv  data size:  (3207, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet4_Flow.csv  data size:  (6585, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet5_Flow.csv  data size:  (331, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet6_Flow.csv  data size:  (4937, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet7_Flow.csv  data size:  (1436, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet8_Flow.csv  data size:  (569, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet9_Flow.csv  data size:  (2833, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet10_Flow.csv  data size:  (2157, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet11_Flow.csv  data size:  (3129, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams1_Flow.csv  data size:  (1898, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams2_Flow.csv  data size:  (382, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams11_Flow.csv  data size:  (1898, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams12_Flow.csv  data size:  (1898, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams21_Flow.csv  data size:  (382, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams22_Flow.csv  data size:  (382, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_1_Flow.csv  data size:  (186, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_2_Flow.csv  data size:  (285, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_5_Flow.csv  data size:  (55, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_6_Flow.csv  data size:  (417, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom1_Flow.csv  data size:  (237, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom2_Flow.csv  data size:  (251, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom3_Flow.csv  data size:  (180, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom4_Flow.csv  data size:  (312, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom5_Flow.csv  data size:  (108, 84)
# (40025, 84)

# %%
#see unique labels
masterDF['Label'].unique()
masterDF['Label'].replace('VConf_Gmeet','VConf_GMeet',inplace=True)
uniqueLabels = list(masterDF['Label'].unique())
print(uniqueLabels)
# Out:
# ['VConf_GMeet', 'VConf_Teams', 'VConf_Skype', 'VConf_Zoom']

# %%
#discard all those columns that helps in uniquely identifying a flow
masterPruned = masterDF.iloc[:,np.arange(7,84)]
print('pruneddata size: ', masterPruned.shape)
ftList = list(masterPruned.columns)
print(ftList)
# Out:
# pruneddata size:  (40025, 77)
# ['Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow Pkts/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std', 'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt', 'CWE Flag Count', 'ECE Flag Cnt', 'Down/Up Ratio', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg', 'Fwd Byts/b Avg', 'Fwd Pkts/b Avg', 'Fwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Pkts/b Avg', 'Bwd Blk Rate Avg', 'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts', 'Subflow Bwd Byts', 'Init Fwd Win Byts', 'Init Bwd Win Byts', 'Fwd Act Data Pkts', 'Fwd Seg Size Min', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'Label']

# %%
#discard those flows that has 0 flow duration
masterSelected = masterPruned.drop(masterPruned[masterPruned['Flow Duration']==0].index)
masterSelected.shape
# Out:
# (38857, 77)

# %%
#identify those columns that has non-numeric values
typesList = masterSelected.dtypes
ftCount = len(ftList)
nonNumericFtList = list()
for fi in range(ftCount):
    if ftList[fi] != 'Label' and typesList[fi] != 'int64' and typesList[fi] != 'float64':
        print(ftList[fi], '  ', typesList[fi])
        nonNumericFtList.append(ftList[fi])
print(nonNumericFtList)
# Out:
# []

# %%
#pyplot.boxplot(results, labels=names, showmeans=True)
#pyplot.scatter(fpackets,fbytes)
#pyplot.show()

# %%
for ft in nonNumericFtList:
    masterSelected[ft] = pd.to_numeric(masterSelected[ft], errors='coerce')

# %%
print(nonNumericFtList)
for ft in nonNumericFtList:
    countNaN = masterSelected[ft].isna().sum()
    print('converted to numeric ft: ', ft, '  countNaN: ', countNaN)
# Out:
# []

# %%
number_inf = masterSelected[masterSelected == np.inf].count().sum()
print('count inf: ',number_inf)
# Out:
# count inf:  0

# %%
typesList = masterSelected.dtypes
ftCount = len(ftList)
nonNumericFtList = list()
for fi in range(ftCount):
    if ftList[fi] != 'Label' and typesList[fi] != 'int64' and typesList[fi] != 'float64':
        print(ftList[fi], '  ', typesList[fi])
        nonNumericFtList.append(ftList[fi])
print(nonNumericFtList)
# Out:
# []

# %%
#identify those columns that has 0 std
count = 0
staticFtList = list()
for ft in ftList:
    if ft == 'Label':
        continue
    #print('ft : ', ft)
    ftMin = masterSelected[ft].min()
    ftMax = masterSelected[ft].max()
    #std = masterPruned[ft].std()
    
    if ftMin == ftMax:
        count += 1
        print('count: ', count, ' ft: ', ft, ' ftmin: ', ftMin, ' ftMax: ', ftMax)
        staticFtList.append(ft)
print(staticFtList)
# Out:
# count:  1  ft:  Fwd PSH Flags  ftmin:  0  ftMax:  0
# count:  2  ft:  Fwd URG Flags  ftmin:  0  ftMax:  0
# count:  3  ft:  Bwd URG Flags  ftmin:  0  ftMax:  0
# count:  4  ft:  URG Flag Cnt  ftmin:  0  ftMax:  0
# count:  5  ft:  CWE Flag Count  ftmin:  0  ftMax:  0
# count:  6  ft:  ECE Flag Cnt  ftmin:  0  ftMax:  0
# count:  7  ft:  Fwd Byts/b Avg  ftmin:  0  ftMax:  0
# count:  8  ft:  Fwd Pkts/b Avg  ftmin:  0  ftMax:  0
# count:  9  ft:  Fwd Blk Rate Avg  ftmin:  0  ftMax:  0
# count:  10  ft:  Bwd Byts/b Avg  ftmin:  0  ftMax:  0
# count:  11  ft:  Bwd Pkts/b Avg  ftmin:  0  ftMax:  0
# count:  12  ft:  Bwd Blk Rate Avg  ftmin:  0  ftMax:  0
# count:  13  ft:  Init Fwd Win Byts  ftmin:  -1  ftMax:  -1
# count:  14  ft:  Fwd Seg Size Min  ftmin:  0  ftMax:  0
# ['Fwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'URG Flag Cnt', 'CWE Flag Count', 'ECE Flag Cnt', 'Fwd Byts/b Avg', 'Fwd Pkts/b Avg', 'Fwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Pkts/b Avg', 'Bwd Blk Rate Avg', 'Init Fwd Win Byts', 'Fwd Seg Size Min']

# %%
#remove those columns that have 0 std
print('before droping column: ', masterSelected.shape)
for ft in staticFtList:
    masterSelected.drop([ft], axis=1,inplace=True)
print('after droping column: ', masterSelected.shape)
# Out:
# before droping column:  (38857, 77)
# after droping column:  (38857, 63)

# %%
xCount = masterSelected.shape[1]
print(xCount)
finalFtList = list(masterSelected.columns)
print(finalFtList)
# Out:
# 63
# ['Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow Pkts/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Bwd PSH Flags', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std', 'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'Down/Up Ratio', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg', 'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts', 'Subflow Bwd Byts', 'Init Bwd Win Byts', 'Fwd Act Data Pkts', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'Label']

# %%
#report intermediate data frame to a csv
#masterSelected.to_csv('../reports_db/CICFlowMeter_VideoConferencingOutput/ProcessedNPrunnedAllConf.csv', index = False)

# %%
#classification with all the features
masterDS = masterSelected.values
X = masterDS[:,:-1]
Y = masterDS[:,-1]
print("Xshape: ", X.shape)
print("Yshape: ", Y.shape)
# Out:
# Xshape:  (38857, 62)
# Yshape:  (38857,)

# %%
# feature selection using ANNOVA F-score
topKval = 10
rfe = RFE(estimator=DecisionTreeClassifier(), n_features_to_select=topKval)
# fit RFE
rfe.fit(X, Y)
# summarize all features

# transform train input data
XNew = rfe.transform(X)
# transform test input data
print('XNew.shape', XNew.shape)
#print('XNew', XNew)
# Out:
# XNew.shape (38857, 10)

# %%
ftSelected = list()#features[0:-1]
for fi in range(xCount-1):
    ft  = finalFtList[fi]
    
    if ft != 'Label' and rfe.support_[fi]:
        #print('i = ', fi, ' ftName: ', ftList[fi], ' FS.support_: ', FS.get_support()[fi], ' FS.scores: = ', FS.scores_[fi])
        #scores.append(ref.scores_[fi])
        ftSelected.append(ft)
        print('Column: %d, ColName: %s, Selected %s, Rank: %.3f' % (fi, finalFtList[fi], rfe.support_[fi], rfe.ranking_[fi]))
print(ftSelected)
# Out:
# Column: 0, ColName: Flow Duration, Selected True, Rank: 1.000
# Column: 1, ColName: Tot Fwd Pkts, Selected True, Rank: 1.000
# Column: 5, ColName: Fwd Pkt Len Max, Selected True, Rank: 1.000
# Column: 15, ColName: Flow IAT Mean, Selected True, Rank: 1.000
# Column: 18, ColName: Flow IAT Min, Selected True, Rank: 1.000
# Column: 23, ColName: Fwd IAT Min, Selected True, Rank: 1.000
# Column: 24, ColName: Bwd IAT Tot, Selected True, Rank: 1.000
# Column: 28, ColName: Bwd IAT Min, Selected True, Rank: 1.000
# Column: 31, ColName: Bwd Header Len, Selected True, Rank: 1.000
# Column: 52, ColName: Init Bwd Win Byts, Selected True, Rank: 1.000
# ['Flow Duration', 'Tot Fwd Pkts', 'Fwd Pkt Len Max', 'Flow IAT Mean', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Min', 'Bwd Header Len', 'Init Bwd Win Byts']

# %%
clf = DecisionTreeClassifier(random_state=0)
print('classification with top 10 selected features:')
scores = cross_val_score(clf, XNew, Y, cv=10)
print(scores)
print('mean score: ', scores.mean(), 'min score: ', scores.min(), 'max score: ', scores.max(), ' std score: ', scores.std())
# Out:
# classification with top 10 selected features:
# [0.96448791 0.95213587 0.97272259 0.97014925 0.96731858 0.96011323
#  0.97555327 0.92947233 0.96396396 0.97400257]
# mean score:  0.96299195673874 min score:  0.9294723294723295 max score:  0.9755532681420483  std score:  0.013025136571229294

# %%
#performance with to k  features using decision tree
X_train, X_test, Y_train, Y_test = train_test_split(XNew, Y, test_size=0.33, random_state=1)
model = DecisionTreeClassifier(random_state=0)
clf = model.fit(X_train,Y_train)
ypred = model.predict(X_test)

# %%
from sklearn.tree import export_text
from sklearn import tree

text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_7 <= 15.50
# |   |--- feature_1 <= 4.50
# |   |   |--- feature_8 <= 122.00
# |   |   |   |--- feature_5 <= 5131795.50
# |   |   |   |   |--- feature_9 <= 509.50
# |   |   |   |   |   |--- feature_0 <= 29756214.00
# |   |   |   |   |   |   |--- feature_3 <= 219809.00
# |   |   |   |   |   |   |   |--- feature_8 <= 14.00
# |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |--- feature_8 >  14.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 504.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 52.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  52.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 135.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  135.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- feature_9 >  504.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 334.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 508.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  508.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  334.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |--- feature_3 >  219809.00
# |   |   |   |   |   |   |   |--- feature_5 <= 504632.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 22850000.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 65.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  65.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 1840095.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  1840095.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_3 >  22850000.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |--- feature_5 >  504632.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 277.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |--- feature_2 >  277.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 1053431.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 3014736.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  3014736.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  1053431.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 1094646.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  1094646.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |--- feature_0 >  29756214.00
# |   |   |   |   |   |   |--- feature_0 <= 40042940.00
# |   |   |   |   |   |   |   |--- feature_0 <= 35166988.00
# |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |--- feature_0 >  35166988.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 40024464.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 40023052.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 40010206.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  40010206.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  40023052.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |--- feature_0 >  40024464.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 40030890.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  40030890.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 40031034.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  40031034.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- feature_0 >  40042940.00
# |   |   |   |   |   |   |   |--- feature_0 <= 56402930.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 505.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |   |--- feature_9 >  505.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |--- feature_0 >  56402930.00
# |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |--- feature_9 >  509.50
# |   |   |   |   |   |--- feature_9 <= 1019.50
# |   |   |   |   |   |   |--- feature_0 <= 1261.50
# |   |   |   |   |   |   |   |--- feature_2 <= 15.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 511.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 164.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 132.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  132.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  164.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |--- feature_9 >  511.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 118.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 514.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  514.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  118.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 220.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  220.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- feature_2 >  15.50
# |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |--- feature_0 >  1261.50
# |   |   |   |   |   |   |   |--- feature_3 <= 36900000.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 768.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 3877950.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 9859939.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  9859939.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  3877950.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 5605216.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  5605216.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |--- feature_9 >  768.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |--- feature_3 >  36900000.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 52499436.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 40013648.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 40007656.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  40007656.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  40013648.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 40021786.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  40021786.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_0 >  52499436.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 75000000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  75000000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |--- feature_9 >  1019.50
# |   |   |   |   |   |   |--- feature_4 <= 17.50
# |   |   |   |   |   |   |   |--- feature_3 <= 38542.42
# |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |--- feature_3 >  38542.42
# |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |--- feature_4 >  17.50
# |   |   |   |   |   |   |   |--- feature_5 <= 2015868.00
# |   |   |   |   |   |   |   |   |--- feature_8 <= 26.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 21460.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 5085.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  5085.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  21460.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |--- feature_8 >  26.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 8326.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1864.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  1864.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  8326.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 1012483.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  1012483.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- feature_5 >  2015868.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 3759628.38
# |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |--- feature_3 >  3759628.38
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |--- feature_5 >  5131795.50
# |   |   |   |   |--- feature_0 <= 110125936.00
# |   |   |   |   |   |--- feature_0 <= 101704352.00
# |   |   |   |   |   |   |--- feature_3 <= 25200000.00
# |   |   |   |   |   |   |   |--- feature_4 <= 20228.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 15193488.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |--- feature_0 >  15193488.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 140.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  140.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |--- feature_4 >  20228.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 8612372.25
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |   |--- feature_3 >  8612372.25
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |--- feature_3 >  25200000.00
# |   |   |   |   |   |   |   |--- feature_0 <= 90030032.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 516.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |--- feature_9 >  516.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 42550000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  42550000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |--- feature_0 >  90030032.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 90031136.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |--- feature_0 >  90031136.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |--- feature_0 >  101704352.00
# |   |   |   |   |   |   |--- feature_0 <= 110116076.00
# |   |   |   |   |   |   |   |--- feature_9 <= 506.00
# |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |--- feature_9 >  506.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 110106812.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 55050000.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  55050000.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 515.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  515.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_0 >  110106812.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 110115380.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 110107096.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  110107096.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  110115380.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |--- feature_0 >  110116076.00
# |   |   |   |   |   |   |   |--- feature_9 <= 512.50
# |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |--- feature_9 >  512.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 110120244.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 110118912.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 513.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  513.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  110118912.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 513.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  513.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |--- feature_0 >  110120244.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 55050000.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  55050000.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 110124240.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  110124240.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |--- feature_0 >  110125936.00
# |   |   |   |   |   |--- feature_0 <= 110568028.00
# |   |   |   |   |   |   |--- feature_0 <= 110134856.00
# |   |   |   |   |   |   |   |--- feature_0 <= 110129144.00
# |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |--- feature_0 >  110129144.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 513.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |--- feature_9 >  513.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 110130840.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  110130840.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 110133020.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  110133020.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |--- feature_0 >  110134856.00
# |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |--- feature_0 >  110568028.00
# |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |--- feature_8 >  122.00
# |   |   |   |--- feature_4 <= 4.50
# |   |   |   |   |--- feature_6 <= 5591.50
# |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |--- feature_6 >  5591.50
# |   |   |   |   |   |--- feature_9 <= 506.50
# |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |--- feature_9 >  506.50
# |   |   |   |   |   |   |--- feature_9 <= 770.00
# |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |--- feature_9 >  770.00
# |   |   |   |   |   |   |   |--- feature_6 <= 875722.00
# |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |--- feature_6 >  875722.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 912079.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |--- feature_6 >  912079.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |--- feature_4 >  4.50
# |   |   |   |   |--- class: VConf_Skype
# |   |--- feature_1 >  4.50
# |   |   |--- feature_7 <= 1.00
# |   |   |   |--- feature_2 <= 89.50
# |   |   |   |   |--- feature_9 <= 11303.00
# |   |   |   |   |   |--- feature_1 <= 299.50
# |   |   |   |   |   |   |--- feature_6 <= 114000000.00
# |   |   |   |   |   |   |   |--- feature_5 <= 13.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 1119820.18
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |--- feature_3 >  1119820.18
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |--- feature_5 >  13.50
# |   |   |   |   |   |   |   |   |--- feature_8 <= 5154.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 8313134.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 1448368.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  1448368.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  8313134.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_8 >  5154.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 15314.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  15314.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |--- feature_6 >  114000000.00
# |   |   |   |   |   |   |   |--- feature_5 <= 1624.50
# |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |--- feature_5 >  1624.50
# |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |--- feature_1 >  299.50
# |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |--- feature_9 >  11303.00
# |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |--- feature_2 >  89.50
# |   |   |   |   |--- feature_2 <= 1201.00
# |   |   |   |   |   |--- feature_6 <= 353726.50
# |   |   |   |   |   |   |--- feature_2 <= 97.50
# |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |--- feature_2 >  97.50
# |   |   |   |   |   |   |   |--- feature_1 <= 162.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 1916402.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 9217.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 294.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  294.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  9217.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |--- feature_4 >  1916402.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |--- feature_1 >  162.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 82589.19
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |--- feature_3 >  82589.19
# |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |--- feature_6 >  353726.50
# |   |   |   |   |   |   |--- feature_1 <= 12.50
# |   |   |   |   |   |   |   |--- feature_3 <= 6010702.00
# |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |--- feature_3 >  6010702.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 219237.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 6313734.25
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 73250000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  73250000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  6313734.25
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |--- feature_5 >  219237.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |--- feature_1 >  12.50
# |   |   |   |   |   |   |   |--- feature_9 <= 215.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 91600000.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 73987272.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  73987272.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |--- feature_6 >  91600000.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |--- feature_9 >  215.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 668.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |--- feature_2 >  668.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |--- feature_2 >  1201.00
# |   |   |   |   |   |--- feature_4 <= 1.00
# |   |   |   |   |   |   |--- feature_9 <= 9216.00
# |   |   |   |   |   |   |   |--- feature_2 <= 1253.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= -0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 119907672.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  119907672.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1224.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1224.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |--- feature_9 >  -0.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |--- feature_2 >  1253.00
# |   |   |   |   |   |   |   |   |--- feature_2 <= 1343.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |--- feature_2 >  1343.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 13.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 199175.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  199175.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  13.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 3573255.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  3573255.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- feature_9 >  9216.00
# |   |   |   |   |   |   |   |--- feature_8 <= 264.00
# |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |--- feature_8 >  264.00
# |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |--- feature_4 >  1.00
# |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |--- feature_7 >  1.00
# |   |   |   |--- class: VConf_Skype
# |--- feature_7 >  15.50
# |   |--- feature_4 <= 6218378.50
# |   |   |--- feature_0 <= 74.50
# |   |   |   |--- feature_9 <= 23834.50
# |   |   |   |   |--- feature_8 <= 46.00
# |   |   |   |   |   |--- feature_9 <= 511.50
# |   |   |   |   |   |   |--- feature_4 <= 53.00
# |   |   |   |   |   |   |   |--- feature_9 <= 250.50
# |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |--- feature_9 >  250.50
# |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |--- feature_4 >  53.00
# |   |   |   |   |   |   |   |--- feature_3 <= 60.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 59.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 510.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 508.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  508.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  510.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |--- feature_7 >  59.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |--- feature_3 >  60.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 67.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 508.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 64.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  64.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  508.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |--- feature_6 >  67.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |--- feature_9 >  511.50
# |   |   |   |   |   |   |--- feature_9 <= 512.50
# |   |   |   |   |   |   |   |--- feature_6 <= 57.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 31.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |--- feature_3 >  31.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 55.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 53.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  53.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  55.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |--- feature_6 >  57.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 67.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 64.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 60.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  60.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  64.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 65.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  65.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_6 >  67.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |--- feature_9 >  512.50
# |   |   |   |   |   |   |   |--- feature_9 <= 2587.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 1021.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 516.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  67.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  516.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 51.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  51.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_9 >  1021.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 52.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  52.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 2058.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  2058.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |--- feature_9 >  2587.50
# |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |--- feature_8 >  46.00
# |   |   |   |   |   |--- feature_8 <= 58.00
# |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |--- feature_8 >  58.00
# |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |--- feature_9 >  23834.50
# |   |   |   |   |--- class: VConf_GMeet
# |   |   |--- feature_0 >  74.50
# |   |   |   |--- feature_9 <= 233.00
# |   |   |   |   |--- feature_8 <= 484.00
# |   |   |   |   |   |--- feature_0 <= 5147.00
# |   |   |   |   |   |   |--- feature_8 <= 56.00
# |   |   |   |   |   |   |   |--- feature_9 <= 42.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 79.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  79.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 88.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  88.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 26.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 106.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  106.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  26.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 172.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  172.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_9 >  42.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 68.08
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |   |--- feature_3 >  68.08
# |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |--- feature_8 >  56.00
# |   |   |   |   |   |   |   |--- feature_8 <= 76.00
# |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |--- feature_8 >  76.00
# |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |--- feature_0 >  5147.00
# |   |   |   |   |   |   |--- feature_9 <= 3.00
# |   |   |   |   |   |   |   |--- feature_4 <= 30.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 6291.50
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 3374.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  3374.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |--- feature_6 >  6291.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 3549.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  3549.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 92.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  92.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |--- feature_4 >  30.00
# |   |   |   |   |   |   |   |   |--- feature_6 <= 1867105.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= -0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  -0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 10368.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  10368.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |--- feature_6 >  1867105.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 298077.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 16400000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  16400000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  298077.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 50.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  50.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |--- feature_9 >  3.00
# |   |   |   |   |   |   |   |--- feature_9 <= 12.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 13196.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |--- feature_7 >  13196.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |--- feature_9 >  12.50
# |   |   |   |   |   |   |   |   |--- feature_6 <= 26950000.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 1052496.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 132.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  132.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  1052496.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 1141738.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  1141738.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_6 >  26950000.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 90198184.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 25.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  25.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  90198184.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 3130.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  3130.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- feature_8 >  484.00
# |   |   |   |   |   |--- feature_5 <= 24.50
# |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |--- feature_5 >  24.50
# |   |   |   |   |   |   |--- feature_0 <= 119999844.00
# |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |--- feature_0 >  119999844.00
# |   |   |   |   |   |   |   |--- feature_7 <= 140.50
# |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |--- feature_7 >  140.50
# |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |--- feature_9 >  233.00
# |   |   |   |   |--- feature_5 <= 15885.50
# |   |   |   |   |   |--- feature_3 <= 156.50
# |   |   |   |   |   |   |--- feature_9 <= 511.50
# |   |   |   |   |   |   |   |--- feature_9 <= 504.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 69.75
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |   |--- feature_3 >  69.75
# |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |--- feature_9 >  504.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 134.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 95.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 508.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  508.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  95.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |--- feature_7 >  134.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 149.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 80.75
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  80.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  149.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 509.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  509.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_9 >  511.50
# |   |   |   |   |   |   |   |--- feature_9 <= 1024.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 514.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 148.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 512.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  512.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  148.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 512.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  512.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_9 >  514.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 92.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 81.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  81.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  92.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 110.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  110.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- feature_9 >  1024.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 19688.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 5158.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1026.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  1026.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  5158.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 136.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  136.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |--- feature_9 >  19688.50
# |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |--- feature_3 >  156.50
# |   |   |   |   |   |   |--- feature_9 <= 64887.50
# |   |   |   |   |   |   |   |--- feature_3 <= 4177439.75
# |   |   |   |   |   |   |   |   |--- feature_9 <= 509.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 5754.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 148.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  148.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 19
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  5754.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 11.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  11.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |--- feature_9 >  509.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 511.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 510.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  510.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  511.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 22.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  22.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 18
# |   |   |   |   |   |   |   |--- feature_3 >  4177439.75
# |   |   |   |   |   |   |   |   |--- feature_4 <= 21.50
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 99950000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  99950000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 85.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  85.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_4 >  21.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 258.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  258.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |--- feature_9 >  64887.50
# |   |   |   |   |   |   |   |--- feature_7 <= 136582.00
# |   |   |   |   |   |   |   |   |--- feature_5 <= 10498.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 1999.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  1999.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 50954.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  50954.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |   |--- feature_5 >  10498.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |--- feature_7 >  136582.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 1492576.00
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 75.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 6851.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  6851.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  75.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |--- feature_0 >  1492576.00
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 1824733.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  1824733.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |--- feature_5 >  15885.50
# |   |   |   |   |   |--- feature_2 <= 108.00
# |   |   |   |   |   |   |--- feature_1 <= 19.50
# |   |   |   |   |   |   |   |--- feature_0 <= 356773.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 51673.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 152653.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 15945.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  15945.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  152653.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 71020.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  71020.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |   |--- feature_7 >  51673.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 47367.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  47367.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |--- feature_0 >  356773.00
# |   |   |   |   |   |   |   |   |--- feature_4 <= 96759.50
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 31279.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 2654.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  2654.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  31279.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 46.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  46.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 14
# |   |   |   |   |   |   |   |   |--- feature_4 >  96759.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 20424.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 512.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  512.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  20424.50
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |--- feature_1 >  19.50
# |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |--- feature_2 >  108.00
# |   |   |   |   |   |   |--- feature_6 <= 99250000.00
# |   |   |   |   |   |   |   |--- feature_4 <= 205587.00
# |   |   |   |   |   |   |   |   |--- feature_1 <= 27.00
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 93600000.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 62.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  62.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  93600000.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 777.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Zoom
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  777.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |   |--- feature_1 >  27.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |   |--- feature_4 >  205587.00
# |   |   |   |   |   |   |   |   |--- feature_4 <= 206673.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 207550.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 83065636.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  83065636.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  207550.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 16650000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  16650000.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_4 >  206673.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 210074.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 208690.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  208690.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  210074.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 222277.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  222277.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_6 >  99250000.00
# |   |   |   |   |   |   |   |--- feature_4 <= 1575.00
# |   |   |   |   |   |   |   |   |--- feature_7 <= 29821.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |--- feature_7 >  29821.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |--- feature_4 >  1575.00
# |   |   |   |   |   |   |   |   |--- feature_8 <= 130.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 122.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  122.00
# |   |   |   |   |   |   |   |   |   |   |--- class: VConf_GMeet
# |   |   |   |   |   |   |   |   |--- feature_8 >  130.00
# |   |   |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |--- feature_4 >  6218378.50
# |   |   |--- feature_3 <= 47650000.00
# |   |   |   |--- feature_8 <= 160.00
# |   |   |   |   |--- feature_0 <= 100982452.00
# |   |   |   |   |   |--- feature_0 <= 100911156.00
# |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |--- feature_0 >  100911156.00
# |   |   |   |   |   |   |--- feature_9 <= 2050.50
# |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |   |--- feature_9 >  2050.50
# |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |--- feature_0 >  100982452.00
# |   |   |   |   |   |--- feature_9 <= 2048.50
# |   |   |   |   |   |   |--- feature_6 <= 93500000.00
# |   |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |   |   |   |--- feature_6 >  93500000.00
# |   |   |   |   |   |   |   |--- class: VConf_Skype
# |   |   |   |   |   |--- feature_9 >  2048.50
# |   |   |   |   |   |   |--- class: VConf_Teams
# |   |   |   |--- feature_8 >  160.00
# |   |   |   |   |--- class: VConf_GMeet
# |   |   |--- feature_3 >  47650000.00
# |   |   |   |--- class: VConf_Skype

# %%
print(clf.tree_.max_depth)
# Out:
# 29

# %%
conf_mat = metrics.confusion_matrix(Y_test, ypred,labels=uniqueLabels)
#[i][j] ==> knwon to be in group i and predicted as group j
print(conf_mat)
print('Meet as Meet = ',conf_mat[0][0],' percent = ', (conf_mat[0][0]/(conf_mat[0][0]+conf_mat[0][1]+conf_mat[0][2]+conf_mat[0][3])))
print('Meet as Team = ',conf_mat[0][1],' percent = ', (conf_mat[0][1]/(conf_mat[0][0]+conf_mat[0][1]+conf_mat[0][2]+conf_mat[0][3])))
print('Meet as Skype = ',conf_mat[0][2],' percent = ', (conf_mat[0][2]/(conf_mat[0][0]+conf_mat[0][1]+conf_mat[0][2]+conf_mat[0][3])))
print('Meet as Zoom = ',conf_mat[0][3],' percent = ', (conf_mat[0][3]/(conf_mat[0][0]+conf_mat[0][1]+conf_mat[0][2]+conf_mat[0][3])))
print('\n')

print('Team as Meet = ',conf_mat[1][0],' percent = ', (conf_mat[1][0]/(conf_mat[1][0]+conf_mat[1][1]+conf_mat[1][2]+conf_mat[1][3])))
print('Team as Team = ',conf_mat[1][1],' percent = ', (conf_mat[1][1]/(conf_mat[1][0]+conf_mat[1][1]+conf_mat[1][2]+conf_mat[1][3])))
print('Team as Skype =',conf_mat[1][2],' percent = ', (conf_mat[1][2]/(conf_mat[1][0]+conf_mat[1][1]+conf_mat[1][2]+conf_mat[1][3])))
print('Team as Zoom = ',conf_mat[1][3],' percent = ', (conf_mat[1][3]/(conf_mat[1][0]+conf_mat[1][1]+conf_mat[1][2]+conf_mat[1][3])))
print('\n')

print('Skype as Meet = ',conf_mat[2][0],' percent = ', (conf_mat[2][0]/(conf_mat[2][0]+conf_mat[2][1]+conf_mat[2][2]+conf_mat[2][3])))
print('Skype as Team = ',conf_mat[2][1],' percent = ', (conf_mat[2][1]/(conf_mat[2][0]+conf_mat[2][1]+conf_mat[2][2]+conf_mat[2][3])))
print('Skype as Skype = ',conf_mat[2][2],' percent = ', (conf_mat[2][2]/(conf_mat[2][0]+conf_mat[2][1]+conf_mat[2][2]+conf_mat[2][3])))
print('Skype as Zoom = ',conf_mat[2][3],' percent = ', (conf_mat[2][3]/(conf_mat[2][0]+conf_mat[2][1]+conf_mat[2][2]+conf_mat[2][3])))
print('\n')

print('Zoom as Meet = ',conf_mat[3][0],' percent = ', (conf_mat[3][0]/(conf_mat[3][0]+conf_mat[3][1]+conf_mat[3][2]+conf_mat[3][3])))
print('Zoom as Team = ',conf_mat[3][1],' percent = ', (conf_mat[3][1]/(conf_mat[3][0]+conf_mat[3][1]+conf_mat[3][2]+conf_mat[3][3])))
print('Zoom as Skype = ',conf_mat[3][2],' percent = ', (conf_mat[3][2]/(conf_mat[3][0]+conf_mat[3][1]+conf_mat[3][2]+conf_mat[3][3])))
print('Zoom as Zoom = ',conf_mat[3][3],' percent = ', (conf_mat[3][3]/(conf_mat[3][0]+conf_mat[3][1]+conf_mat[3][2]+conf_mat[3][3])))
# Out:
# [[9882  129   53   48]
#  [  69 2060    0    6]
#  [  56    7  202    5]
#  [  42   33    1  230]]
# Meet as Meet =  9882  percent =  0.977254746835443
# Meet as Team =  129  percent =  0.012757120253164557
# Meet as Skype =  53  percent =  0.0052412974683544306
# Meet as Zoom =  48  percent =  0.004746835443037975
#
#
# Team as Meet =  69  percent =  0.03231850117096019
# Team as Team =  2060  percent =  0.9648711943793911
# Team as Skype = 0  percent =  0.0
# Team as Zoom =  6  percent =  0.002810304449648712
#
#
# Skype as Meet =  56  percent =  0.2074074074074074
# Skype as Team =  7  percent =  0.025925925925925925
# Skype as Skype =  202  percent =  0.7481481481481481
# Skype as Zoom =  5  percent =  0.018518518518518517
#
#
# Zoom as Meet =  42  percent =  0.13725490196078433
# Zoom as Team =  33  percent =  0.10784313725490197
# Zoom as Skype =  1  percent =  0.0032679738562091504
# Zoom as Zoom =  230  percent =  0.7516339869281046

# %%
#classification with unselected and uncorrelated features
corr = masterSelected.corr()
corr.shape
# Out:
# (62, 62)

# %%
corrThreshold = 0.65
unCorrUnSelFtList = list()
for ft1 in finalFtList:#baseft = 'Idle Max' for each of the selected features
    #print('ft1: ', ft1)
    isCorr = False
    for ft2 in ftSelected:# for each of the top 10 features
        if ft1 == 'Label' or ft2 == 'Label' or (ft1 == ft2):
            continue
        elif abs(corr[ft1][ft2]) > corrThreshold:
                isCorr = True
                print('ft1: ', ft1, 'ft2: ', ft2, '  corr: ', corr[ft1][ft2])
                break
    if not isCorr and ft1 not in unCorrUnSelFtList:
        #print('corr[{0}][{1}] = {2}: isPresentInRestFtlist: {3}'.format(baseft,ft,corr[baseft][ft], ft in restFtList))
        unCorrUnSelFtList.append(ft1)
        
    #elif abs(corr[ft1][ft] >= 0.6 and ft in unCorrUnSelFtList):
    #            unCorrUnSelFtList.remove(ft)
print(len(unCorrUnSelFtList))
print(unCorrUnSelFtList)

print(len(ftSelected))
print(ftSelected)
# Out:
# ft1:  Tot Bwd Pkts ft2:  Bwd Header Len   corr:  0.9585051568470234
# ft1:  TotLen Fwd Pkts ft2:  Tot Fwd Pkts   corr:  0.8951895005636135
# ft1:  TotLen Bwd Pkts ft2:  Bwd Header Len   corr:  0.9884477052244914
# ft1:  Fwd Pkt Len Mean ft2:  Fwd Pkt Len Max   corr:  0.7405867998501936
# ft1:  Fwd Pkt Len Std ft2:  Fwd Pkt Len Max   corr:  0.9290599298552231
# ft1:  Flow Pkts/s ft2:  Bwd Pkts/s   corr:  0.9710009949120345
# ft1:  Flow IAT Mean ft2:  Flow IAT Min   corr:  0.8713047350407235
# ft1:  Flow IAT Max ft2:  Flow Duration   corr:  0.6577915432927807
# ft1:  Flow IAT Min ft2:  Flow IAT Mean   corr:  0.8713047350407235
# ft1:  Fwd IAT Tot ft2:  Flow Duration   corr:  0.9138763611697057
# ft1:  Fwd IAT Mean ft2:  Fwd IAT Min   corr:  0.865890671629761
# ft1:  Bwd IAT Tot ft2:  Flow Duration   corr:  0.8280506065369702
# ft1:  Fwd Header Len ft2:  Tot Fwd Pkts   corr:  0.9521652069702861
# ft1:  Pkt Len Max ft2:  Fwd Pkt Len Max   corr:  0.6539292044882057
# ft1:  Pkt Len Std ft2:  Fwd Pkt Len Max   corr:  0.6553015079642859
# ft1:  Fwd Seg Size Avg ft2:  Fwd Pkt Len Max   corr:  0.7405867998501936
# ft1:  Subflow Fwd Pkts ft2:  Tot Fwd Pkts   corr:  1.0
# ft1:  Subflow Fwd Byts ft2:  Tot Fwd Pkts   corr:  0.8951864557962291
# ft1:  Subflow Bwd Pkts ft2:  Bwd Header Len   corr:  0.9585051568470234
# ft1:  Subflow Bwd Byts ft2:  Bwd Header Len   corr:  0.9884477193348556
# ft1:  Fwd Act Data Pkts ft2:  Tot Fwd Pkts   corr:  0.9740474274508382
# ft1:  Idle Mean ft2:  Flow IAT Mean   corr:  0.6811299953542705
# ft1:  Idle Max ft2:  Flow Duration   corr:  0.6558410564740517
# ft1:  Idle Min ft2:  Flow IAT Mean   corr:  0.6843574693618035
# 39
# ['Flow Duration', 'Tot Fwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min', 'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow IAT Std', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Bwd PSH Flags', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Min', 'Pkt Len Mean', 'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'Down/Up Ratio', 'Pkt Size Avg', 'Bwd Seg Size Avg', 'Init Bwd Win Byts', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Std', 'Label']
# 10
# ['Flow Duration', 'Tot Fwd Pkts', 'Fwd Pkt Len Max', 'Flow IAT Mean', 'Flow IAT Min', 'Fwd IAT Min', 'Bwd IAT Min', 'Bwd Header Len', 'Bwd Pkts/s', 'Init Bwd Win Byts']

# %%
for ft1 in ftSelected:
    for ft2 in unCorrUnSelFtList:
        if ft1 != 'Label' or ft2 == 'Label':
            continue
        if abs(corr[ft][ft2]) >= corrThreshold:
            print('ft: ',ft, ' ft2: ',ft2, corr[ft][ft2])

# %%
#slice master data frame to only uncorrelated and unselected features
masterUnSelected = masterSelected[unCorrUnSelFtList]
print(masterUnSelected.shape)
# Out:
# (38857, 39)

# %%
#### classification with unselected columns
masterUnSelDS = masterUnSelected.values
Xnotsel = masterUnSelDS[:,:-1]
Y = masterUnSelDS[:,-1]
print("Xshape: ", Xnotsel.shape)
print("Yshape: ", Y.shape)
# Out:
# Xshape:  (38857, 38)
# Yshape:  (38857,)

# %%
#find cross validation score with uncorrelated and unselecte feature data frame
clf = DecisionTreeClassifier(random_state=0)
print('classification with rest (not top 10) features:')
scores = cross_val_score(clf, Xnotsel, Y, cv=10)
print(scores)
print('mean score: ', scores.mean(), ' std score: ', scores.std())
# Out:
# classification with rest (not top 10) features:
# [0.97040659 0.95959856 0.9750386  0.97400926 0.96680391 0.96345857
#  0.97632527 0.93976834 0.96499356 0.97194337]
# mean score:  0.9662346038413974  std score:  0.01021686646954154

# %%
#classification with with uncorrelated and unselecte feature data frame
X_train, X_test, Y_train, Y_test = train_test_split(Xnotsel, Y, test_size=0.33, random_state=1)
model = DecisionTreeClassifier(random_state=0)
model.fit(X_train,Y_train)
yhat = model.predict(X_test)

# %%
conf_mat = metrics.confusion_matrix(Y_test, yhat,labels=uniqueLabels)
#[i][j] ==> knwon to be in group i and predicted as group j
print(conf_mat)
print('Meet as Meet = ',conf_mat[0][0],' percent = ', (conf_mat[0][0]/(conf_mat[0][0]+conf_mat[0][1]+conf_mat[0][2]+conf_mat[0][3])))
print('Meet as Team = ',conf_mat[0][1],' percent = ', (conf_mat[0][1]/(conf_mat[0][0]+conf_mat[0][1]+conf_mat[0][2]+conf_mat[0][3])))
print('Meet as Skype = ',conf_mat[0][2],' percent = ', (conf_mat[0][2]/(conf_mat[0][0]+conf_mat[0][1]+conf_mat[0][2]+conf_mat[0][3])))
print('Meet as Zoom = ',conf_mat[0][3],' percent = ', (conf_mat[0][3]/(conf_mat[0][0]+conf_mat[0][1]+conf_mat[0][2]+conf_mat[0][3])))
print('\n')

print('Team as Meet = ',conf_mat[1][0],' percent = ', (conf_mat[1][0]/(conf_mat[1][0]+conf_mat[1][1]+conf_mat[1][2]+conf_mat[1][3])))
print('Team as Team = ',conf_mat[1][1],' percent = ', (conf_mat[1][1]/(conf_mat[1][0]+conf_mat[1][1]+conf_mat[1][2]+conf_mat[1][3])))
print('Team as Skype =',conf_mat[1][2],' percent = ', (conf_mat[1][2]/(conf_mat[1][0]+conf_mat[1][1]+conf_mat[1][2]+conf_mat[1][3])))
print('Team as Zoom = ',conf_mat[1][3],' percent = ', (conf_mat[1][3]/(conf_mat[1][0]+conf_mat[1][1]+conf_mat[1][2]+conf_mat[1][3])))
print('\n')

print('Skype as Meet = ',conf_mat[2][0],' percent = ', (conf_mat[2][0]/(conf_mat[2][0]+conf_mat[2][1]+conf_mat[2][2]+conf_mat[2][3])))
print('Skype as Team = ',conf_mat[2][1],' percent = ', (conf_mat[2][1]/(conf_mat[2][0]+conf_mat[2][1]+conf_mat[2][2]+conf_mat[2][3])))
print('Skype as Skype = ',conf_mat[2][2],' percent = ', (conf_mat[2][2]/(conf_mat[2][0]+conf_mat[2][1]+conf_mat[2][2]+conf_mat[2][3])))
print('Skype as Zoom = ',conf_mat[2][3],' percent = ', (conf_mat[2][3]/(conf_mat[2][0]+conf_mat[2][1]+conf_mat[2][2]+conf_mat[2][3])))
print('\n')

print('Zoom as Meet = ',conf_mat[3][0],' percent = ', (conf_mat[3][0]/(conf_mat[3][0]+conf_mat[3][1]+conf_mat[3][2]+conf_mat[3][3])))
print('Zoom as Team = ',conf_mat[3][1],' percent = ', (conf_mat[3][1]/(conf_mat[3][0]+conf_mat[3][1]+conf_mat[3][2]+conf_mat[3][3])))
print('Zoom as Skype = ',conf_mat[3][2],' percent = ', (conf_mat[3][2]/(conf_mat[3][0]+conf_mat[3][1]+conf_mat[3][2]+conf_mat[3][3])))
print('Zoom as Zoom = ',conf_mat[3][3],' percent = ', (conf_mat[3][3]/(conf_mat[3][0]+conf_mat[3][1]+conf_mat[3][2]+conf_mat[3][3])))
# Out:
# [[9880  147   52   33]
#  [  66 2048    6   15]
#  [  45   13  203    9]
#  [  45   33    6  222]]
# Meet as Meet =  9880  percent =  0.9770569620253164
# Meet as Team =  147  percent =  0.014537183544303797
# Meet as Skype =  52  percent =  0.005142405063291139
# Meet as Zoom =  33  percent =  0.0032634493670886076
#
#
# Team as Meet =  66  percent =  0.030913348946135833
# Team as Team =  2048  percent =  0.9592505854800937
# Team as Skype = 6  percent =  0.002810304449648712
# Team as Zoom =  15  percent =  0.00702576112412178
#
#
# Skype as Meet =  45  percent =  0.16666666666666666
# Skype as Team =  13  percent =  0.04814814814814815
# Skype as Skype =  203  percent =  0.7518518518518519
# Skype as Zoom =  9  percent =  0.03333333333333333
#
#
# Zoom as Meet =  45  percent =  0.14705882352941177
# Zoom as Team =  33  percent =  0.10784313725490197
# Zoom as Skype =  6  percent =  0.0196078431372549
# Zoom as Zoom =  222  percent =  0.7254901960784313
