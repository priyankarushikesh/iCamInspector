# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from matplotlib import pyplot

# %%
fnamesIPcam = ["D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/d3dtraffic_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/d3dtraffic_2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/d3dtraffic_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_6_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_7_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/netatmocam1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/netatmocam2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/netatmocam3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_6_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_7_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_8_Flow.csv"]
fnamesConf = [
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet6_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet7_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet8_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet9_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet10_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet11_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet12_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams11_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams12_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams21_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams22_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_6_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_7_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_8_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_9_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_10_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_11_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_12_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_13_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_14_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_15_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom_6_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom_7_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom_8_Flow.csv",
          ]
fnamesShare = [
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_6_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_7_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_8_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_9_Flow.csv",
         ]
fnamesOther = [
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/Skype/New collection/Other data/csv/other1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/Skype/New collection/Other data/csv/other2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/Skype/New collection/Other data/csv/other3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/Skype/New collection/Other data/csv/other4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/Skype/New collection/Other data/csv/other3_Flow.csv",
         ]

# %%
dfList = list()
for fname in fnamesIPcam: 
    data = pd.read_csv(fname)
    print('file:', fname, ' data size: ',data.shape)
    dfList.append(data)
############## combine the data frames
ipcamDF = pd.concat(dfList)
print(ipcamDF.shape)
# Out:
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_1_Flow.csv  data size:  (125, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_2_Flow.csv  data size:  (157, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_3_Flow.csv  data size:  (95, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/alarmClockCam_4_Flow.csv  data size:  (18, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_1_Flow.csv  data size:  (45, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_2_Flow.csv  data size:  (45, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_3_Flow.csv  data size:  (143, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/canarycam_4_Flow.csv  data size:  (188, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/d3dtraffic_1_Flow.csv  data size:  (503, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/d3dtraffic_2_Flow.csv  data size:  (665, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/d3dtraffic_3_Flow.csv  data size:  (565, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_1_Flow.csv  data size:  (234, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_2_Flow.csv  data size:  (336, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_3_Flow.csv  data size:  (479, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_4_Flow.csv  data size:  (605, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_5_Flow.csv  data size:  (563, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_6_Flow.csv  data size:  (339, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/ezviz_7_Flow.csv  data size:  (30, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/netatmocam1_Flow.csv  data size:  (432, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/netatmocam2_Flow.csv  data size:  (158, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/netatmocam3_Flow.csv  data size:  (353, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_1_Flow.csv  data size:  (249, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_2_Flow.csv  data size:  (1678, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_3_Flow.csv  data size:  (347, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_4_Flow.csv  data size:  (425, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_5_Flow.csv  data size:  (264, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_6_Flow.csv  data size:  (288, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_7_Flow.csv  data size:  (280, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/IPCamera_filteredpcapcsv/v380Cam1_8_Flow.csv  data size:  (391, 84)
# (10000, 84)

# %%
#see unique labels
print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam_AlarmClock', 'IPCam_Canary', 'IPCam_D3D', 'IPCam_Ezviz', 'IPCam_Netatmo', 'IPCam_V380']

# %%
ipcamDF['Label'].replace('IPCam_AlarmClock','IPCam',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam', 'IPCam_Canary', 'IPCam_D3D', 'IPCam_Ezviz', 'IPCam_Netatmo', 'IPCam_V380']

# %%
ipcamDF['Label'].replace('IPCam_Canary','IPCam',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam', 'IPCam_D3D', 'IPCam_Ezviz', 'IPCam_Netatmo', 'IPCam_V380']

# %%
ipcamDF['Label'].replace('IPCam_D3D','IPCam',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam', 'IPCam_Ezviz', 'IPCam_Netatmo', 'IPCam_V380']

# %%
ipcamDF['Label'].replace('IPCam_Ezviz','IPCam',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam', 'IPCam_Netatmo', 'IPCam_V380']

# %%
ipcamDF['Label'].replace('IPCam_Netatmo','IPCam',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam', 'IPCam_V380']

# %%
ipcamDF['Label'].replace('IPCam_V380','IPCam',inplace=True)
uniqueLabels = list(ipcamDF['Label'].unique())
print(uniqueLabels)
#print(list(ipcamDF['Label'].unique()))
# Out:
# ['IPCam']

# %%
###################################\
dfList = list()
for fname in fnamesShare: 
    data = pd.read_csv(fname)
    print('file:', fname, ' data size: ',data.shape)
    dfList.append(data)
############## combine the data frames
shareDF = pd.concat(dfList)
print(shareDF.shape)
# Out:
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon1_Flow.csv  data size:  (870, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon2_Flow.csv  data size:  (516, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon3_Flow.csv  data size:  (921, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon4_Flow.csv  data size:  (467, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/amazon5_Flow.csv  data size:  (800, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_1_Flow.csv  data size:  (1420, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_2_Flow.csv  data size:  (52, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_3_Flow.csv  data size:  (37, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_4_Flow.csv  data size:  (41, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_5_Flow.csv  data size:  (337, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_6_Flow.csv  data size:  (159, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_7_Flow.csv  data size:  (337, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_8_Flow.csv  data size:  (1729, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoSharing_filteredpcapcsv/YouTube_9_Flow.csv  data size:  (194, 84)
# (7880, 84)

# %%
print(list(shareDF['Label'].unique()))
# Out:
# ['VShare_Amazon', 'VShare_YouTube']

# %%
shareDF['Label'].replace('VShare_Amazon','VShare',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(shareDF['Label'].unique()))
# Out:
# ['VShare', 'VShare_YouTube']

# %%
shareDF['Label'].replace('VShare_YouTube','VShare',inplace=True)
uniqueLabels = list(shareDF['Label'].unique())
print(uniqueLabels)
#print(list(shareDF['Label'].unique()))
# Out:
# ['VShare']

# %%
###################################\
dfList = list()
for fname in fnamesConf: 
    data = pd.read_csv(fname)
    print('file:', fname, ' data size: ',data.shape)
    dfList.append(data)
############## combine the data frames
confDF = pd.concat(dfList)
print(confDF.shape)
# Out:
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet1_Flow.csv  data size:  (2620, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet2_Flow.csv  data size:  (3350, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet3_Flow.csv  data size:  (3207, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet4_Flow.csv  data size:  (6585, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet5_Flow.csv  data size:  (331, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet6_Flow.csv  data size:  (4937, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet7_Flow.csv  data size:  (1436, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet8_Flow.csv  data size:  (569, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet9_Flow.csv  data size:  (2833, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet10_Flow.csv  data size:  (2157, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet11_Flow.csv  data size:  (3129, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/gmeet12_Flow.csv  data size:  (806, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams1_Flow.csv  data size:  (1898, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams2_Flow.csv  data size:  (382, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams11_Flow.csv  data size:  (1898, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams12_Flow.csv  data size:  (1898, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams21_Flow.csv  data size:  (382, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/MSTeams22_Flow.csv  data size:  (382, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_1_Flow.csv  data size:  (186, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_2_Flow.csv  data size:  (285, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_3_Flow.csv  data size:  (25, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_4_Flow.csv  data size:  (271, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_5_Flow.csv  data size:  (55, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_6_Flow.csv  data size:  (417, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_7_Flow.csv  data size:  (85, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_8_Flow.csv  data size:  (64, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_9_Flow.csv  data size:  (733, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_10_Flow.csv  data size:  (1098, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_11_Flow.csv  data size:  (1024, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_12_Flow.csv  data size:  (928, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_13_Flow.csv  data size:  (1277, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_14_Flow.csv  data size:  (1637, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/Skype_15_Flow.csv  data size:  (1028, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom1_Flow.csv  data size:  (237, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom2_Flow.csv  data size:  (251, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom3_Flow.csv  data size:  (180, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom4_Flow.csv  data size:  (312, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom5_Flow.csv  data size:  (108, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom_6_Flow.csv  data size:  (23, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom_7_Flow.csv  data size:  (12, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/filteredPcapCSV/VideoConferencing_filteredpcapcsv/zoom_8_Flow.csv  data size:  (15, 84)
# (49051, 84)

# %%
print(list(confDF['Label'].unique()))
# Out:
# ['VConf_GMeet', 'VConf_Teams', 'VConf_Skype', 'VConf_Zoom']

# %%
confDF['Label'].replace('VConf_GMeet','VConf',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(confDF['Label'].unique()))
# Out:
# ['VConf', 'VConf_Teams', 'VConf_Skype', 'VConf_Zoom']

# %%
confDF['Label'].replace('VConf_Teams','VConf',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(confDF['Label'].unique()))
# Out:
# ['VConf', 'VConf_Skype', 'VConf_Zoom']

# %%
confDF['Label'].replace('VConf_Skype','VConf',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(confDF['Label'].unique()))
# Out:
# ['VConf', 'VConf_Zoom']

# %%
confDF['Label'].replace('VConf_Zoom','VConf',inplace=True)
uniqueLabels = list(confDF['Label'].unique())
print(uniqueLabels)
# Out:
# ['VConf']

# %%
###################################\
dfList = list()
for fname in fnamesOther: 
    data = pd.read_csv(fname)
    print('file:', fname, ' data size: ',data.shape)
    dfList.append(data)
############## combine the data frames
otherDF = pd.concat(dfList)
print(otherDF.shape)
# Out:
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/Skype/New collection/Other data/csv/other1_Flow.csv  data size:  (12155, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/Skype/New collection/Other data/csv/other2_Flow.csv  data size:  (1795, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/Skype/New collection/Other data/csv/other3_Flow.csv  data size:  (11728, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/Skype/New collection/Other data/csv/other4_Flow.csv  data size:  (5358, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/Skype/New collection/Other data/csv/other3_Flow.csv  data size:  (11728, 84)
# (42764, 84)

# %%
print(list(otherDF['Label'].unique()))
# Out:
# ['Other', 'No Label']

# %%
otherDF['Label'].replace('No Label','Other',inplace=True)
#uniqueLabels = list(ipcamDF['Label'].unique())
#print(uniqueLabels)
print(list(otherDF['Label'].unique()))
# Out:
# ['Other']

# %%
print(list(otherDF['Label'].unique()))
# Out:
# ['Other']

# %%
print(list(confDF['Label'].unique()))
print(list(shareDF['Label'].unique()))
print(list(ipcamDF['Label'].unique()))
print(list(otherDF['Label'].unique()))
# Out:
# ['VConf']
# ['VShare']
# ['IPCam']
# ['Other']

# %%
######### creating master DF
dfListAll = [ipcamDF,shareDF, confDF, otherDF]
masterDF = pd.concat(dfListAll)
print(masterDF.shape)
# Out:
# (109695, 84)

# %%
uniqueLabels = list(masterDF['Label'].unique())
print(uniqueLabels)
# Out:
# ['IPCam', 'VShare', 'VConf', 'Other']

# %%
#discard all those columns that helps in uniquely identifying a flow
masterPruned = masterDF.iloc[:,np.arange(7,84)]
print('pruneddata size: ', masterPruned.shape)
ftList = list(masterPruned.columns)
print(ftList)
# Out:
# pruneddata size:  (109695, 77)
# ['Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow Pkts/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std', 'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt', 'CWE Flag Count', 'ECE Flag Cnt', 'Down/Up Ratio', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg', 'Fwd Byts/b Avg', 'Fwd Pkts/b Avg', 'Fwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Pkts/b Avg', 'Bwd Blk Rate Avg', 'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts', 'Subflow Bwd Byts', 'Init Fwd Win Byts', 'Init Bwd Win Byts', 'Fwd Act Data Pkts', 'Fwd Seg Size Min', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'Label']

# %%
#discard those flows that has 0 flow duration
masterSelected = masterPruned.drop(masterPruned[masterPruned['Flow Duration']==0].index)
masterSelected.shape
# Out:
# (76976, 77)

# %%
#identify those columns that has non-numeric values
typesList = masterSelected.dtypes
ftCount = len(ftList)
nonNumericFtList = list()
for fi in range(ftCount):
    if ftList[fi] != 'Label' and typesList[fi] != 'int64' and typesList[fi] != 'float64':
        print(ftList[fi], '  ', typesList[fi])
        nonNumericFtList.append(ftList[fi])
print(nonNumericFtList)
# Out:
# []

# %%
for ft in nonNumericFtList:
    masterSelected[ft] = pd.to_numeric(masterSelected[ft], errors='coerce')

# %%
print(nonNumericFtList)
for ft in nonNumericFtList:
    countNaN = masterSelected[ft].isna().sum()
    print('converted to numeric ft: ', ft, '  countNaN: ', countNaN)
# Out:
# []

# %%
number_inf = masterSelected[masterSelected == np.inf].count().sum()
print('count inf: ',number_inf)
# Out:
# count inf:  0

# %%
typesList = masterSelected.dtypes
ftCount = len(ftList)
nonNumericFtList = list()
for fi in range(ftCount):
    if ftList[fi] != 'Label' and typesList[fi] != 'int64' and typesList[fi] != 'float64':
        print(ftList[fi], '  ', typesList[fi])
        nonNumericFtList.append(ftList[fi])
print(nonNumericFtList)
# Out:
# []

# %%
#identify those columns that has 0 std
count = 0
staticFtList = list()
for ft in ftList:
    if ft == 'Label':
        continue
    #print('ft : ', ft)
    ftMin = masterSelected[ft].min()
    ftMax = masterSelected[ft].max()
    #std = masterPruned[ft].std()
    
    if ftMin == ftMax:
        count += 1
        print('count: ', count, ' ft: ', ft, ' ftmin: ', ftMin, ' ftMax: ', ftMax)
        staticFtList.append(ft)
print(staticFtList)
# Out:
# count:  1  ft:  Fwd PSH Flags  ftmin:  0  ftMax:  0
# count:  2  ft:  Fwd URG Flags  ftmin:  0  ftMax:  0
# count:  3  ft:  Bwd URG Flags  ftmin:  0  ftMax:  0
# count:  4  ft:  URG Flag Cnt  ftmin:  0  ftMax:  0
# count:  5  ft:  CWE Flag Count  ftmin:  0  ftMax:  0
# count:  6  ft:  ECE Flag Cnt  ftmin:  0  ftMax:  0
# count:  7  ft:  Fwd Byts/b Avg  ftmin:  0  ftMax:  0
# count:  8  ft:  Fwd Pkts/b Avg  ftmin:  0  ftMax:  0
# count:  9  ft:  Fwd Blk Rate Avg  ftmin:  0  ftMax:  0
# count:  10  ft:  Bwd Byts/b Avg  ftmin:  0  ftMax:  0
# count:  11  ft:  Bwd Pkts/b Avg  ftmin:  0  ftMax:  0
# count:  12  ft:  Bwd Blk Rate Avg  ftmin:  0  ftMax:  0
# count:  13  ft:  Init Fwd Win Byts  ftmin:  -1  ftMax:  -1
# count:  14  ft:  Fwd Seg Size Min  ftmin:  0  ftMax:  0
# ['Fwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'URG Flag Cnt', 'CWE Flag Count', 'ECE Flag Cnt', 'Fwd Byts/b Avg', 'Fwd Pkts/b Avg', 'Fwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Pkts/b Avg', 'Bwd Blk Rate Avg', 'Init Fwd Win Byts', 'Fwd Seg Size Min']

# %%
#remove those columns that have 0 std
print('before droping column: ', masterSelected.shape)
for ft in staticFtList:
    masterSelected.drop([ft], axis=1,inplace=True)
print('after droping column: ', masterSelected.shape)
# Out:
# before droping column:  (76976, 77)
# after droping column:  (76976, 63)

# %%
xCount = masterSelected.shape[1]
print(xCount)
finalFtList = list(masterSelected.columns)
print(finalFtList)
# Out:
# 63
# ['Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow Pkts/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Bwd PSH Flags', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std', 'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'Down/Up Ratio', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg', 'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts', 'Subflow Bwd Byts', 'Init Bwd Win Byts', 'Fwd Act Data Pkts', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'Label']

# %%
#report intermediate data frame to a csv
masterSelected.to_csv('D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/MLForUnseenEnvironment/ProcessedNPrunnedAllCombination_Others_unseenenv.csv', index = False)

# %%
#classification with all the features
masterDS = masterSelected.values
X = masterDS[:,:-1]
Y = masterDS[:,-1]
print("Xshape: ", X.shape)
print("Yshape: ", Y.shape)
# Out:
# Xshape:  (76976, 62)
# Yshape:  (76976,)

# %%
#depth = 30 # for plot depth vs meanstd
clf = DecisionTreeClassifier(random_state=15)
print('classification with all features:')
scores = cross_val_score(clf, X, Y, cv=10)
print(scores)
print('mean score: ', scores.mean(), 'min score: ', scores.min(), 'max score: ', scores.max(), ' std score: ', scores.std())
# Out:
# classification with all features:
# [0.82826708 0.87892959 0.90426085 0.91569239 0.9193297  0.91556248
#  0.8822918  0.94283487 0.89736261 0.8478628 ]
# mean score:  0.8932394174082257 min score:  0.8282670823590543 max score:  0.9428348707288554  std score:  0.03299454831698832

# %%
import time
#performance with all features using decision tree
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=1)
model = DecisionTreeClassifier(random_state=10)
clf = model.fit(X_train,Y_train)
#yhat = model.predict(X_test)

# %%
fnamesFourClass = [
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/Gmeet_only_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI_GMeet1_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI_GMeet2_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI_GMeet3_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI_GMeet4_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI_GMeet5_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI1_only_Flow.csv",
          "D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI2_only_Flow.csv",
         ]

# %%
dfList = list()
for fname in fnamesFourClass: 
    data = pd.read_csv(fname)
    print('file:', fname, ' data size: ',data.shape)
    dfList.append(data)
############## combine the data frames
fourclassDF = pd.concat(dfList)
print(fourclassDF.shape)
# Out:
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/Gmeet_only_Flow.csv  data size:  (5692, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI_GMeet1_Flow.csv  data size:  (5879, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI_GMeet2_Flow.csv  data size:  (6057, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI_GMeet3_Flow.csv  data size:  (4809, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI_GMeet4_Flow.csv  data size:  (6212, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI_GMeet5_Flow.csv  data size:  (5006, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI1_only_Flow.csv  data size:  (10304, 84)
# file: D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/4ClassValidation_ML/csv/IMOUMI2_only_Flow.csv  data size:  (3743, 84)
# (47702, 84)

# %%
#see unique labels
print(list(fourclassDF['Label'].unique()))
print(fourclassDF.shape)
# Out:
# ['No Label']
# (47702, 84)

# %%
#discard all those columns that helps in uniquely identifying a flow
masterPruned = fourclassDF.iloc[:,np.arange(7,84)]
print('pruneddata size: ', masterPruned.shape)
ftList = list(masterPruned.columns)
print(ftList)
# Out:
# pruneddata size:  (47702, 77)
# ['Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow Pkts/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Bwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std', 'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt', 'CWE Flag Count', 'ECE Flag Cnt', 'Down/Up Ratio', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg', 'Fwd Byts/b Avg', 'Fwd Pkts/b Avg', 'Fwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Pkts/b Avg', 'Bwd Blk Rate Avg', 'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts', 'Subflow Bwd Byts', 'Init Fwd Win Byts', 'Init Bwd Win Byts', 'Fwd Act Data Pkts', 'Fwd Seg Size Min', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'Label']

# %%
#discard those flows that has 0 flow duration
masterSelected = masterPruned.drop(masterPruned[masterPruned['Flow Duration']==0].index)
masterSelected.shape
# Out:
# (47671, 77)

# %%
#identify those columns that has non-numeric values
typesList = masterSelected.dtypes
ftCount = len(ftList)
nonNumericFtList = list()
for fi in range(ftCount):
    if ftList[fi] != 'Label' and typesList[fi] != 'int64' and typesList[fi] != 'float64':
        print(ftList[fi], '  ', typesList[fi])
        nonNumericFtList.append(ftList[fi])
print(nonNumericFtList)
# Out:
# []

# %%
for ft in nonNumericFtList:
    masterSelected[ft] = pd.to_numeric(masterSelected[ft], errors='coerce')

# %%
print(nonNumericFtList)
for ft in nonNumericFtList:
    countNaN = masterSelected[ft].isna().sum()
    print('converted to numeric ft: ', ft, '  countNaN: ', countNaN)
# Out:
# []

# %%
number_inf = masterSelected[masterSelected == np.inf].count().sum()
print('count inf: ',number_inf)
# Out:
# count inf:  0

# %%
typesList = masterSelected.dtypes
ftCount = len(ftList)
nonNumericFtList = list()
for fi in range(ftCount):
    if ftList[fi] != 'Label' and typesList[fi] != 'int64' and typesList[fi] != 'float64':
        print(ftList[fi], '  ', typesList[fi])
        nonNumericFtList.append(ftList[fi])
print(nonNumericFtList)
# Out:
# []

# %%
#identify those columns that has 0 std
count = 0
staticFtList = list()
for ft in ftList:
    if ft == 'Label':
        continue
    #print('ft : ', ft)
    ftMin = masterSelected[ft].min()
    ftMax = masterSelected[ft].max()
    #std = masterPruned[ft].std()
    
    if ftMin == ftMax:
        count += 1
        print('count: ', count, ' ft: ', ft, ' ftmin: ', ftMin, ' ftMax: ', ftMax)
        staticFtList.append(ft)
print(staticFtList)
# Out:
# count:  1  ft:  Fwd PSH Flags  ftmin:  0  ftMax:  0
# count:  2  ft:  Fwd URG Flags  ftmin:  0  ftMax:  0
# count:  3  ft:  Bwd URG Flags  ftmin:  0  ftMax:  0
# count:  4  ft:  URG Flag Cnt  ftmin:  0  ftMax:  0
# count:  5  ft:  CWE Flag Count  ftmin:  0  ftMax:  0
# count:  6  ft:  ECE Flag Cnt  ftmin:  0  ftMax:  0
# count:  7  ft:  Fwd Byts/b Avg  ftmin:  0  ftMax:  0
# count:  8  ft:  Fwd Pkts/b Avg  ftmin:  0  ftMax:  0
# count:  9  ft:  Fwd Blk Rate Avg  ftmin:  0  ftMax:  0
# count:  10  ft:  Bwd Byts/b Avg  ftmin:  0  ftMax:  0
# count:  11  ft:  Bwd Pkts/b Avg  ftmin:  0  ftMax:  0
# count:  12  ft:  Bwd Blk Rate Avg  ftmin:  0  ftMax:  0
# count:  13  ft:  Init Fwd Win Byts  ftmin:  -1  ftMax:  -1
# count:  14  ft:  Fwd Seg Size Min  ftmin:  0  ftMax:  0
# ['Fwd PSH Flags', 'Fwd URG Flags', 'Bwd URG Flags', 'URG Flag Cnt', 'CWE Flag Count', 'ECE Flag Cnt', 'Fwd Byts/b Avg', 'Fwd Pkts/b Avg', 'Fwd Blk Rate Avg', 'Bwd Byts/b Avg', 'Bwd Pkts/b Avg', 'Bwd Blk Rate Avg', 'Init Fwd Win Byts', 'Fwd Seg Size Min']

# %%
#remove those columns that have 0 std
print('before droping column: ', masterSelected.shape)
for ft in staticFtList:
    masterSelected.drop([ft], axis=1,inplace=True)
print('after droping column: ', masterSelected.shape)
# Out:
# before droping column:  (47671, 77)
# after droping column:  (47671, 63)

# %%
xCount = masterSelected.shape[1]
print(xCount)
finalFtList = list(masterSelected.columns)
print(finalFtList)
# Out:
# 63
# ['Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow Pkts/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Bwd PSH Flags', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std', 'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'Down/Up Ratio', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg', 'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts', 'Subflow Bwd Byts', 'Init Bwd Win Byts', 'Fwd Act Data Pkts', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min', 'Label']

# %%
#report intermediate data frame to a csv
masterSelected.to_csv('D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/MLForUnseenEnvironment/ProcessedNPrunnedAllCombination_Others_unseenenv_Newdata.csv', index = False)

# %%
#classification with all the features
masterDS = masterSelected.values
X = masterDS[:,:-1]
Y = masterDS[:,-1]
print("Xshape: ", X.shape)
print("Yshape: ", Y.shape)
# Out:
# Xshape:  (47671, 62)
# Yshape:  (47671,)

# %%
#performance with all features using decision tree
#X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=1)
#model = DecisionTreeClassifier(random_state=10)
#clf = model.fit(X_train,Y_train)
yhat = model.predict(X)
print(yhat.shape)
# Out:
# (47671,)

# %%
yhat.dtype
# Out:
# dtype('O')

# %%
from collections import Counter
counted_dict = Counter(yhat)
for key in counted_dict:
    print('key = ', key, ' val = ', counted_dict[key])
# Out:
# key =  VConf  val =  5725
# key =  VShare  val =  5653
# key =  Other  val =  16859
# key =  IPCam  val =  19434

# %%
import pickle
filename = 'D:/New pcaps_IoTSpyCamera/TDSC_WorkAfterReview/camdetector_model.sav'
# load the model from disk
camdetector = pickle.load(open(filename, 'rb'))
result = camdetector.predict(X)
print(result)
print(result.shape)
#print(X_test.shape)
#print(Y_test.shape)
# Out:
# ['IPCam_V380' 'IPCam_Canary' 'IPCam_Canary' ... 'IPCam_AlarmClock'
#  'IPCam_V380' 'IPCam_AlarmClock']
# (47671,)

# %%
#Performing IoTDetector on IPCAM flows
yhatcamList = list()
for ri in range(47671):
    if yhat[ri] == 'IPCam':
        
        yhatcam = camdetector.predict([X[ri]])
        yhatcamList.append(yhatcam[0])
        print(ri, yhatcam)
# Out:
# 24 ['IPCam_V380']
# 59 ['IPCam_Canary']
# 62 ['IPCam_Ezviz']
# 92 ['IPCam_V380']
# 93 ['IPCam_V380']
# 95 ['IPCam_V380']
# 182 ['IPCam_Netatmo']
# 190 ['IPCam_V380']
# 194 ['IPCam_Ezviz']
# 198 ['IPCam_Canary']
# 206 ['IPCam_V380']
# 212 ['IPCam_V380']
# 234 ['IPCam_Canary']
# 247 ['IPCam_V380']
# 258 ['IPCam_AlarmClock']
# 277 ['IPCam_Canary']
# 287 ['IPCam_Ezviz']
# 288 ['IPCam_V380']
# 291 ['IPCam_AlarmClock']
# 293 ['IPCam_Ezviz']
# 346 ['IPCam_Canary']
# 348 ['IPCam_V380']
# 351 ['IPCam_Canary']
# 354 ['IPCam_Canary']
# 399 ['IPCam_V380']
# 419 ['IPCam_Ezviz']
# 446 ['IPCam_AlarmClock']
# 460 ['IPCam_Canary']
# 500 ['IPCam_V380']
# 561 ['IPCam_V380']
# 580 ['IPCam_Netatmo']
# 600 ['IPCam_Ezviz']
# 603 ['IPCam_V380']
# 630 ['IPCam_Ezviz']
# 646 ['IPCam_AlarmClock']
# 663 ['IPCam_V380']
# 664 ['IPCam_V380']
# 680 ['IPCam_Ezviz']
# 682 ['IPCam_Netatmo']
# 684 ['IPCam_V380']
# 693 ['IPCam_V380']
# 743 ['IPCam_Canary']
# 761 ['IPCam_V380']
# 768 ['IPCam_V380']
# 771 ['IPCam_Netatmo']
# 773 ['IPCam_Netatmo']
# 793 ['IPCam_Ezviz']
# 801 ['IPCam_V380']
# 807 ['IPCam_Canary']
# 808 ['IPCam_Canary']
# 818 ['IPCam_V380']
# 861 ['IPCam_V380']
# 874 ['IPCam_V380']
# 889 ['IPCam_V380']
# 902 ['IPCam_Ezviz']
# 903 ['IPCam_V380']
# 910 ['IPCam_V380']
# 913 ['IPCam_Netatmo']
# 916 ['IPCam_Ezviz']
# 953 ['IPCam_V380']
# 967 ['IPCam_Netatmo']
# 970 ['IPCam_V380']
# 1036 ['IPCam_V380']
# 1066 ['IPCam_V380']
# 1081 ['IPCam_AlarmClock']
# 1087 ['IPCam_Ezviz']
# 1093 ['IPCam_Netatmo']
# 1106 ['IPCam_AlarmClock']
# 1110 ['IPCam_AlarmClock']
# 1127 ['IPCam_V380']
# 1144 ['IPCam_V380']
# 1150 ['IPCam_V380']
# 1151 ['IPCam_Ezviz']
# 1154 ['IPCam_V380']
# 1172 ['IPCam_V380']
# 1176 ['IPCam_V380']
# 1184 ['IPCam_Ezviz']
# 1192 ['IPCam_V380']
# 1195 ['IPCam_AlarmClock']
# 1244 ['IPCam_Ezviz']
# 1265 ['IPCam_AlarmClock']
# 1284 ['IPCam_V380']
# 1286 ['IPCam_V380']
# 1299 ['IPCam_AlarmClock']
# 1300 ['IPCam_Netatmo']
# 1307 ['IPCam_V380']
# 1342 ['IPCam_V380']
# 1353 ['IPCam_Ezviz']
# 1370 ['IPCam_V380']
# 1377 ['IPCam_V380']
# 1379 ['IPCam_V380']
# 1389 ['IPCam_V380']
# 1395 ['IPCam_V380']
# 1396 ['IPCam_V380']
# 1410 ['IPCam_AlarmClock']
# 1412 ['IPCam_AlarmClock']
# 1415 ['IPCam_Netatmo']
# 1417 ['IPCam_Netatmo']
# 1431 ['IPCam_AlarmClock']
# 1442 ['IPCam_V380']
# 1444 ['IPCam_V380']
# 1445 ['IPCam_V380']
# 1488 ['IPCam_Ezviz']
# 1490 ['IPCam_Ezviz']
# 1522 ['IPCam_AlarmClock']
# 1532 ['IPCam_AlarmClock']
# 1547 ['IPCam_V380']
# 1568 ['IPCam_V380']
# 1575 ['IPCam_V380']
# 1578 ['IPCam_AlarmClock']
# 1593 ['IPCam_AlarmClock']
# 1604 ['IPCam_Canary']
# 1619 ['IPCam_AlarmClock']
# 1626 ['IPCam_Ezviz']
# 1650 ['IPCam_V380']
# 1684 ['IPCam_Netatmo']
# 1695 ['IPCam_V380']
# 1723 ['IPCam_V380']
# 1734 ['IPCam_V380']
# 1754 ['IPCam_V380']
# 1784 ['IPCam_AlarmClock']
# 1797 ['IPCam_AlarmClock']
# 1828 ['IPCam_AlarmClock']
# 1830 ['IPCam_Ezviz']
# 1851 ['IPCam_Canary']
# 1895 ['IPCam_Ezviz']
# 1922 ['IPCam_AlarmClock']
# 1963 ['IPCam_V380']
# 1978 ['IPCam_Ezviz']
# 2000 ['IPCam_V380']
# 2010 ['IPCam_AlarmClock']
# 2011 ['IPCam_AlarmClock']
# 2020 ['IPCam_Canary']
# 2038 ['IPCam_V380']
# 2054 ['IPCam_AlarmClock']
# 2063 ['IPCam_AlarmClock']
# 2065 ['IPCam_AlarmClock']
# 2069 ['IPCam_AlarmClock']
# 2070 ['IPCam_V380']
# 2072 ['IPCam_AlarmClock']
# 2074 ['IPCam_AlarmClock']
# 2075 ['IPCam_AlarmClock']
# 2076 ['IPCam_AlarmClock']
# 2079 ['IPCam_AlarmClock']
# 2081 ['IPCam_AlarmClock']
# 2082 ['IPCam_AlarmClock']
# 2084 ['IPCam_AlarmClock']
# 2086 ['IPCam_AlarmClock']
# 2087 ['IPCam_AlarmClock']
# 2088 ['IPCam_AlarmClock']
# 2090 ['IPCam_AlarmClock']
# 2091 ['IPCam_AlarmClock']
# 2092 ['IPCam_V380']
# 2093 ['IPCam_AlarmClock']
# 2094 ['IPCam_V380']
# 2095 ['IPCam_AlarmClock']
# 2100 ['IPCam_AlarmClock']
# 2101 ['IPCam_AlarmClock']
# 2102 ['IPCam_AlarmClock']
# 2104 ['IPCam_AlarmClock']
# 2105 ['IPCam_V380']
# 2106 ['IPCam_AlarmClock']
# 2109 ['IPCam_AlarmClock']
# 2111 ['IPCam_AlarmClock']
# 2113 ['IPCam_AlarmClock']
# 2114 ['IPCam_AlarmClock']
# 2115 ['IPCam_AlarmClock']
# 2117 ['IPCam_AlarmClock']
# 2119 ['IPCam_AlarmClock']
# 2123 ['IPCam_AlarmClock']
# 2127 ['IPCam_AlarmClock']
# 2128 ['IPCam_AlarmClock']
# 2131 ['IPCam_V380']
# 2133 ['IPCam_AlarmClock']
# 2134 ['IPCam_V380']
# 2140 ['IPCam_AlarmClock']
# 2146 ['IPCam_AlarmClock']
# 2148 ['IPCam_AlarmClock']
# 2150 ['IPCam_AlarmClock']
# 2151 ['IPCam_AlarmClock']
# 2152 ['IPCam_AlarmClock']
# 2153 ['IPCam_AlarmClock']
# 2155 ['IPCam_AlarmClock']
# 2158 ['IPCam_AlarmClock']
# 2161 ['IPCam_AlarmClock']
# 2169 ['IPCam_AlarmClock']
# 2170 ['IPCam_AlarmClock']
# 2172 ['IPCam_AlarmClock']
# 2173 ['IPCam_AlarmClock']
# 2176 ['IPCam_Netatmo']
# 2178 ['IPCam_AlarmClock']
# 2180 ['IPCam_AlarmClock']
# 2181 ['IPCam_V380']
# 2184 ['IPCam_AlarmClock']
# 2185 ['IPCam_V380']
# 2187 ['IPCam_AlarmClock']
# 2188 ['IPCam_AlarmClock']
# 2191 ['IPCam_AlarmClock']
# 2194 ['IPCam_AlarmClock']
# 2195 ['IPCam_AlarmClock']
# 2199 ['IPCam_AlarmClock']
# 2200 ['IPCam_AlarmClock']
# 2202 ['IPCam_V380']
# 2203 ['IPCam_AlarmClock']
# 2207 ['IPCam_AlarmClock']
# 2208 ['IPCam_AlarmClock']
# 2209 ['IPCam_AlarmClock']
# 2212 ['IPCam_AlarmClock']
# 2213 ['IPCam_V380']
# 2215 ['IPCam_AlarmClock']
# 2217 ['IPCam_AlarmClock']
# 2221 ['IPCam_AlarmClock']
# 2222 ['IPCam_AlarmClock']
# 2223 ['IPCam_V380']
# 2226 ['IPCam_AlarmClock']
# 2228 ['IPCam_AlarmClock']
# 2230 ['IPCam_AlarmClock']
# 2231 ['IPCam_AlarmClock']
# 2234 ['IPCam_AlarmClock']
# 2235 ['IPCam_AlarmClock']
# 2236 ['IPCam_AlarmClock']
# 2237 ['IPCam_V380']
# 2238 ['IPCam_AlarmClock']
# 2244 ['IPCam_AlarmClock']
# 2247 ['IPCam_AlarmClock']
# 2249 ['IPCam_AlarmClock']
# 2254 ['IPCam_AlarmClock']
# 2257 ['IPCam_AlarmClock']
# 2259 ['IPCam_AlarmClock']
# 2264 ['IPCam_V380']
# 2266 ['IPCam_AlarmClock']
# 2268 ['IPCam_AlarmClock']
# 2269 ['IPCam_AlarmClock']
# 2270 ['IPCam_V380']
# 2271 ['IPCam_AlarmClock']
# 2272 ['IPCam_AlarmClock']
# 2273 ['IPCam_AlarmClock']
# 2274 ['IPCam_AlarmClock']
# 2275 ['IPCam_V380']
# 2276 ['IPCam_AlarmClock']
# 2278 ['IPCam_AlarmClock']
# 2279 ['IPCam_AlarmClock']
# 2283 ['IPCam_AlarmClock']
# 2289 ['IPCam_AlarmClock']
# 2291 ['IPCam_AlarmClock']
# 2296 ['IPCam_AlarmClock']
# 2297 ['IPCam_AlarmClock']
# 2298 ['IPCam_AlarmClock']
# 2299 ['IPCam_AlarmClock']
# 2301 ['IPCam_AlarmClock']
# 2302 ['IPCam_V380']
# 2303 ['IPCam_AlarmClock']
# 2306 ['IPCam_AlarmClock']
# 2310 ['IPCam_V380']
# 2312 ['IPCam_AlarmClock']
# 2314 ['IPCam_V380']
# 2315 ['IPCam_V380']
# 2317 ['IPCam_AlarmClock']
# 2318 ['IPCam_AlarmClock']
# 2319 ['IPCam_AlarmClock']
# 2324 ['IPCam_AlarmClock']
# 2326 ['IPCam_AlarmClock']
# 2327 ['IPCam_AlarmClock']
# 2330 ['IPCam_AlarmClock']
# 2332 ['IPCam_AlarmClock']
# 2340 ['IPCam_AlarmClock']
# 2345 ['IPCam_V380']
# 2348 ['IPCam_AlarmClock']
# 2349 ['IPCam_AlarmClock']
# 2352 ['IPCam_AlarmClock']
# 2354 ['IPCam_AlarmClock']
# 2357 ['IPCam_V380']
# 2361 ['IPCam_AlarmClock']
# 2364 ['IPCam_AlarmClock']
# 2365 ['IPCam_AlarmClock']
# 2367 ['IPCam_AlarmClock']
# 2369 ['IPCam_AlarmClock']
# 2373 ['IPCam_AlarmClock']
# 2376 ['IPCam_AlarmClock']
# 2380 ['IPCam_AlarmClock']
# 2383 ['IPCam_AlarmClock']
# 2384 ['IPCam_AlarmClock']
# 2387 ['IPCam_AlarmClock']
# 2388 ['IPCam_AlarmClock']
# 2393 ['IPCam_AlarmClock']
# 2394 ['IPCam_AlarmClock']
# 2397 ['IPCam_AlarmClock']
# 2399 ['IPCam_AlarmClock']
# 2405 ['IPCam_AlarmClock']
# 2406 ['IPCam_AlarmClock']
# 2408 ['IPCam_V380']
# 2412 ['IPCam_AlarmClock']
# 2413 ['IPCam_AlarmClock']
# 2420 ['IPCam_V380']
# 2422 ['IPCam_AlarmClock']
# 2425 ['IPCam_V380']
# 2426 ['IPCam_AlarmClock']
# 2428 ['IPCam_AlarmClock']
# 2431 ['IPCam_AlarmClock']
# 2432 ['IPCam_AlarmClock']
# 2434 ['IPCam_AlarmClock']
# 2435 ['IPCam_AlarmClock']
# 2437 ['IPCam_AlarmClock']
# 2439 ['IPCam_AlarmClock']
# 2442 ['IPCam_AlarmClock']
# 2447 ['IPCam_AlarmClock']
# 2456 ['IPCam_AlarmClock']
# 2458 ['IPCam_AlarmClock']
# 2459 ['IPCam_AlarmClock']
# 2460 ['IPCam_AlarmClock']
# 2464 ['IPCam_AlarmClock']
# 2468 ['IPCam_AlarmClock']
# 2473 ['IPCam_AlarmClock']
# 2476 ['IPCam_V380']
# 2477 ['IPCam_AlarmClock']
# 2479 ['IPCam_AlarmClock']
# 2489 ['IPCam_AlarmClock']
# 2496 ['IPCam_AlarmClock']
# 2498 ['IPCam_AlarmClock']
# 2501 ['IPCam_AlarmClock']
# 2503 ['IPCam_AlarmClock']
# 2504 ['IPCam_AlarmClock']
# 2507 ['IPCam_AlarmClock']
# 2509 ['IPCam_V380']
# 2512 ['IPCam_AlarmClock']
# 2517 ['IPCam_AlarmClock']
# 2518 ['IPCam_Ezviz']
# 2520 ['IPCam_AlarmClock']
# 2524 ['IPCam_AlarmClock']
# 2529 ['IPCam_AlarmClock']
# 2533 ['IPCam_AlarmClock']
# 2536 ['IPCam_AlarmClock']
# 2539 ['IPCam_AlarmClock']
# 2540 ['IPCam_AlarmClock']
# 2544 ['IPCam_V380']
# 2546 ['IPCam_AlarmClock']
# 2549 ['IPCam_AlarmClock']
# 2551 ['IPCam_AlarmClock']
# 2555 ['IPCam_AlarmClock']
# 2556 ['IPCam_AlarmClock']
# 2558 ['IPCam_AlarmClock']
# 2562 ['IPCam_AlarmClock']
# 2565 ['IPCam_AlarmClock']
# 2567 ['IPCam_AlarmClock']
# 2568 ['IPCam_AlarmClock']
# 2573 ['IPCam_AlarmClock']
# 2575 ['IPCam_AlarmClock']
# 2576 ['IPCam_AlarmClock']
# 2577 ['IPCam_AlarmClock']
# 2582 ['IPCam_AlarmClock']
# 2584 ['IPCam_AlarmClock']
# 2585 ['IPCam_AlarmClock']
# 2586 ['IPCam_V380']
# 2588 ['IPCam_AlarmClock']
# 2590 ['IPCam_AlarmClock']
# 2593 ['IPCam_AlarmClock']
# 2597 ['IPCam_AlarmClock']
# 2600 ['IPCam_AlarmClock']
# 2603 ['IPCam_AlarmClock']
# 2605 ['IPCam_AlarmClock']
# 2609 ['IPCam_AlarmClock']
# 2610 ['IPCam_AlarmClock']
# 2612 ['IPCam_AlarmClock']
# 2613 ['IPCam_AlarmClock']
# 2615 ['IPCam_AlarmClock']
# 2617 ['IPCam_AlarmClock']
# 2618 ['IPCam_AlarmClock']
# 2619 ['IPCam_AlarmClock']
# 2623 ['IPCam_AlarmClock']
# 2624 ['IPCam_AlarmClock']
# 2625 ['IPCam_AlarmClock']
# 2627 ['IPCam_AlarmClock']
# 2628 ['IPCam_AlarmClock']
# 2631 ['IPCam_AlarmClock']
# 2636 ['IPCam_AlarmClock']
# 2639 ['IPCam_AlarmClock']
# 2640 ['IPCam_AlarmClock']
# 2641 ['IPCam_AlarmClock']
# 2644 ['IPCam_AlarmClock']
# 2650 ['IPCam_V380']
# 2652 ['IPCam_AlarmClock']
# 2657 ['IPCam_AlarmClock']
# 2658 ['IPCam_AlarmClock']
# 2659 ['IPCam_AlarmClock']
# 2662 ['IPCam_AlarmClock']
# 2667 ['IPCam_AlarmClock']
# 2671 ['IPCam_AlarmClock']
# 2673 ['IPCam_AlarmClock']
# 2674 ['IPCam_AlarmClock']
# 2675 ['IPCam_V380']
# 2678 ['IPCam_AlarmClock']
# 2685 ['IPCam_V380']
# 2687 ['IPCam_AlarmClock']
# 2690 ['IPCam_V380']
# 2691 ['IPCam_AlarmClock']
# 2692 ['IPCam_AlarmClock']
# 2693 ['IPCam_AlarmClock']
# 2697 ['IPCam_V380']
# 2698 ['IPCam_AlarmClock']
# 2699 ['IPCam_AlarmClock']
# 2700 ['IPCam_AlarmClock']
# 2702 ['IPCam_AlarmClock']
# 2703 ['IPCam_AlarmClock']
# 2704 ['IPCam_V380']
# 2706 ['IPCam_AlarmClock']
# 2708 ['IPCam_AlarmClock']
# 2709 ['IPCam_V380']
# 2710 ['IPCam_AlarmClock']
# 2711 ['IPCam_V380']
# 2718 ['IPCam_V380']
# 2720 ['IPCam_AlarmClock']
# 2722 ['IPCam_AlarmClock']
# 2724 ['IPCam_AlarmClock']
# 2725 ['IPCam_AlarmClock']
# 2726 ['IPCam_AlarmClock']
# 2727 ['IPCam_AlarmClock']
# 2729 ['IPCam_AlarmClock']
# 2733 ['IPCam_AlarmClock']
# 2740 ['IPCam_AlarmClock']
# 2744 ['IPCam_AlarmClock']
# 2745 ['IPCam_AlarmClock']
# 2749 ['IPCam_AlarmClock']
# 2753 ['IPCam_V380']
# 2760 ['IPCam_AlarmClock']
# 2765 ['IPCam_AlarmClock']
# 2767 ['IPCam_AlarmClock']
# 2770 ['IPCam_AlarmClock']
# 2771 ['IPCam_AlarmClock']
# 2773 ['IPCam_AlarmClock']
# 2774 ['IPCam_AlarmClock']
# 2775 ['IPCam_V380']
# 2779 ['IPCam_AlarmClock']
# 2780 ['IPCam_AlarmClock']
# 2781 ['IPCam_AlarmClock']
# 2783 ['IPCam_AlarmClock']
# 2786 ['IPCam_AlarmClock']
# 2787 ['IPCam_AlarmClock']
# 2791 ['IPCam_Ezviz']
# 2798 ['IPCam_AlarmClock']
# 2799 ['IPCam_AlarmClock']
# 2801 ['IPCam_AlarmClock']
# 2803 ['IPCam_AlarmClock']
# 2804 ['IPCam_AlarmClock']
# 2805 ['IPCam_Canary']
# 2808 ['IPCam_AlarmClock']
# 2809 ['IPCam_AlarmClock']
# 2811 ['IPCam_V380']
# 2813 ['IPCam_AlarmClock']
# 2818 ['IPCam_V380']
# 2824 ['IPCam_V380']
# 2830 ['IPCam_AlarmClock']
# 2835 ['IPCam_AlarmClock']
# 2836 ['IPCam_AlarmClock']
# 2839 ['IPCam_AlarmClock']
# 2840 ['IPCam_AlarmClock']
# 2844 ['IPCam_AlarmClock']
# 2847 ['IPCam_AlarmClock']
# 2848 ['IPCam_AlarmClock']
# 2849 ['IPCam_AlarmClock']
# 2850 ['IPCam_AlarmClock']
# 2851 ['IPCam_AlarmClock']
# 2854 ['IPCam_AlarmClock']
# 2858 ['IPCam_AlarmClock']
# 2862 ['IPCam_AlarmClock']
# 2864 ['IPCam_AlarmClock']
# 2865 ['IPCam_Netatmo']
# 2866 ['IPCam_V380']
# 2867 ['IPCam_AlarmClock']
# 2869 ['IPCam_AlarmClock']
# 2870 ['IPCam_AlarmClock']
# 2872 ['IPCam_AlarmClock']
# 2873 ['IPCam_AlarmClock']
# 2876 ['IPCam_AlarmClock']
# 2880 ['IPCam_AlarmClock']
# 2881 ['IPCam_AlarmClock']
# 2884 ['IPCam_AlarmClock']
# 2885 ['IPCam_AlarmClock']
# 2887 ['IPCam_V380']
# 2888 ['IPCam_Canary']
# 2893 ['IPCam_AlarmClock']
# 2894 ['IPCam_AlarmClock']
# 2895 ['IPCam_AlarmClock']
# 2897 ['IPCam_AlarmClock']
# 2899 ['IPCam_AlarmClock']
# 2901 ['IPCam_AlarmClock']
# 2903 ['IPCam_AlarmClock']
# 2904 ['IPCam_AlarmClock']
# 2910 ['IPCam_AlarmClock']
# 2915 ['IPCam_V380']
# 2916 ['IPCam_V380']
# 2918 ['IPCam_AlarmClock']
# 2919 ['IPCam_V380']
# 2920 ['IPCam_AlarmClock']
# 2923 ['IPCam_AlarmClock']
# 2924 ['IPCam_AlarmClock']
# 2925 ['IPCam_AlarmClock']
# 2929 ['IPCam_AlarmClock']
# 2931 ['IPCam_AlarmClock']
# 2932 ['IPCam_AlarmClock']
# 2933 ['IPCam_AlarmClock']
# 2938 ['IPCam_AlarmClock']
# 2940 ['IPCam_AlarmClock']
# 2941 ['IPCam_AlarmClock']
# 2943 ['IPCam_AlarmClock']
# 2945 ['IPCam_AlarmClock']
# 2946 ['IPCam_Ezviz']
# 2948 ['IPCam_AlarmClock']
# 2951 ['IPCam_AlarmClock']
# 2952 ['IPCam_AlarmClock']
# 2955 ['IPCam_AlarmClock']
# 2959 ['IPCam_AlarmClock']
# 2960 ['IPCam_AlarmClock']
# 2961 ['IPCam_AlarmClock']
# 2965 ['IPCam_AlarmClock']
# 2967 ['IPCam_AlarmClock']
# 2969 ['IPCam_AlarmClock']
# 2970 ['IPCam_AlarmClock']
# 2971 ['IPCam_AlarmClock']
# 2972 ['IPCam_AlarmClock']
# 2973 ['IPCam_AlarmClock']
# 2975 ['IPCam_AlarmClock']
# 2976 ['IPCam_AlarmClock']
# 2979 ['IPCam_AlarmClock']
# 2981 ['IPCam_V380']
# 2985 ['IPCam_AlarmClock']
# 2986 ['IPCam_AlarmClock']
# 2987 ['IPCam_AlarmClock']
# 2989 ['IPCam_AlarmClock']
# 2990 ['IPCam_V380']
# 2994 ['IPCam_V380']
# 2996 ['IPCam_AlarmClock']
# 2999 ['IPCam_AlarmClock']
# 3002 ['IPCam_AlarmClock']
# 3007 ['IPCam_AlarmClock']
# 3009 ['IPCam_V380']
# 3014 ['IPCam_Canary']
# 3016 ['IPCam_AlarmClock']
# 3018 ['IPCam_AlarmClock']
# 3019 ['IPCam_AlarmClock']
# 3021 ['IPCam_AlarmClock']
# 3023 ['IPCam_AlarmClock']
# 3025 ['IPCam_V380']
# 3026 ['IPCam_AlarmClock']
# 3027 ['IPCam_V380']
# 3029 ['IPCam_AlarmClock']
# 3031 ['IPCam_AlarmClock']
# 3034 ['IPCam_AlarmClock']
# 3036 ['IPCam_AlarmClock']
# 3039 ['IPCam_AlarmClock']
# 3040 ['IPCam_AlarmClock']
# 3043 ['IPCam_AlarmClock']
# 3045 ['IPCam_AlarmClock']
# 3047 ['IPCam_AlarmClock']
# 3048 ['IPCam_AlarmClock']
# 3055 ['IPCam_AlarmClock']
# 3056 ['IPCam_AlarmClock']
# 3060 ['IPCam_V380']
# 3061 ['IPCam_AlarmClock']
# 3062 ['IPCam_AlarmClock']
# 3063 ['IPCam_AlarmClock']
# 3066 ['IPCam_AlarmClock']
# 3067 ['IPCam_V380']
# 3068 ['IPCam_AlarmClock']
# 3070 ['IPCam_AlarmClock']
# 3071 ['IPCam_V380']
# 3072 ['IPCam_V380']
# 3086 ['IPCam_AlarmClock']
# 3089 ['IPCam_V380']
# 3090 ['IPCam_V380']
# 3091 ['IPCam_AlarmClock']
# 3094 ['IPCam_AlarmClock']
# 3098 ['IPCam_AlarmClock']
# 3107 ['IPCam_AlarmClock']
# 3109 ['IPCam_AlarmClock']
# 3112 ['IPCam_AlarmClock']
# 3116 ['IPCam_AlarmClock']
# 3119 ['IPCam_AlarmClock']
# 3120 ['IPCam_AlarmClock']
# 3123 ['IPCam_AlarmClock']
# 3124 ['IPCam_AlarmClock']
# 3128 ['IPCam_V380']
# 3129 ['IPCam_AlarmClock']
# 3130 ['IPCam_AlarmClock']
# 3131 ['IPCam_AlarmClock']
# 3132 ['IPCam_AlarmClock']
# 3133 ['IPCam_AlarmClock']
# 3139 ['IPCam_AlarmClock']
# 3141 ['IPCam_AlarmClock']
# 3144 ['IPCam_AlarmClock']
# 3147 ['IPCam_V380']
# 3148 ['IPCam_AlarmClock']
# 3149 ['IPCam_AlarmClock']
# 3153 ['IPCam_AlarmClock']
# 3155 ['IPCam_AlarmClock']
# 3158 ['IPCam_AlarmClock']
# 3161 ['IPCam_AlarmClock']
# 3163 ['IPCam_AlarmClock']
# 3167 ['IPCam_AlarmClock']
# 3168 ['IPCam_Ezviz']
# 3169 ['IPCam_AlarmClock']
# 3172 ['IPCam_AlarmClock']
# 3181 ['IPCam_AlarmClock']
# 3184 ['IPCam_AlarmClock']
# 3189 ['IPCam_AlarmClock']
# 3196 ['IPCam_AlarmClock']
# 3200 ['IPCam_V380']
# 3202 ['IPCam_AlarmClock']
# 3205 ['IPCam_AlarmClock']
# 3207 ['IPCam_AlarmClock']
# 3208 ['IPCam_AlarmClock']
# 3209 ['IPCam_AlarmClock']
# 3210 ['IPCam_AlarmClock']
# 3211 ['IPCam_AlarmClock']
# 3212 ['IPCam_AlarmClock']
# 3222 ['IPCam_AlarmClock']
# 3230 ['IPCam_AlarmClock']
# 3235 ['IPCam_AlarmClock']
# 3236 ['IPCam_V380']
# 3239 ['IPCam_AlarmClock']
# 3241 ['IPCam_Netatmo']
# 3242 ['IPCam_V380']
# 3243 ['IPCam_AlarmClock']
# 3244 ['IPCam_AlarmClock']
# 3245 ['IPCam_AlarmClock']
# 3246 ['IPCam_V380']
# 3247 ['IPCam_AlarmClock']
# 3249 ['IPCam_AlarmClock']
# 3250 ['IPCam_AlarmClock']
# 3252 ['IPCam_AlarmClock']
# 3254 ['IPCam_AlarmClock']
# 3256 ['IPCam_AlarmClock']
# 3261 ['IPCam_AlarmClock']
# 3263 ['IPCam_AlarmClock']
# 3264 ['IPCam_AlarmClock']
# 3265 ['IPCam_AlarmClock']
# 3271 ['IPCam_V380']
# 3272 ['IPCam_V380']
# 3274 ['IPCam_AlarmClock']
# 3275 ['IPCam_AlarmClock']
# 3276 ['IPCam_AlarmClock']
# 3277 ['IPCam_AlarmClock']
# 3279 ['IPCam_AlarmClock']
# 3281 ['IPCam_AlarmClock']
# 3283 ['IPCam_AlarmClock']
# 3285 ['IPCam_AlarmClock']
# 3286 ['IPCam_AlarmClock']
# 3288 ['IPCam_AlarmClock']
# 3293 ['IPCam_AlarmClock']
# 3294 ['IPCam_AlarmClock']
# 3295 ['IPCam_V380']
# 3297 ['IPCam_AlarmClock']
# 3298 ['IPCam_Canary']
# 3300 ['IPCam_V380']
# 3302 ['IPCam_V380']
# 3311 ['IPCam_AlarmClock']
# 3313 ['IPCam_AlarmClock']
# 3314 ['IPCam_AlarmClock']
# 3315 ['IPCam_AlarmClock']
# 3317 ['IPCam_AlarmClock']
# 3318 ['IPCam_AlarmClock']
# 3319 ['IPCam_AlarmClock']
# 3322 ['IPCam_V380']
# 3324 ['IPCam_AlarmClock']
# 3327 ['IPCam_V380']
# 3332 ['IPCam_AlarmClock']
# 3335 ['IPCam_AlarmClock']
# 3336 ['IPCam_AlarmClock']
# 3337 ['IPCam_AlarmClock']
# 3339 ['IPCam_AlarmClock']
# 3340 ['IPCam_AlarmClock']
# 3341 ['IPCam_AlarmClock']
# 3342 ['IPCam_AlarmClock']
# 3343 ['IPCam_AlarmClock']
# 3344 ['IPCam_AlarmClock']
# 3347 ['IPCam_AlarmClock']
# 3349 ['IPCam_AlarmClock']
# 3350 ['IPCam_V380']
# 3351 ['IPCam_AlarmClock']
# 3354 ['IPCam_AlarmClock']
# 3358 ['IPCam_AlarmClock']
# 3359 ['IPCam_AlarmClock']
# 3360 ['IPCam_AlarmClock']
# 3363 ['IPCam_AlarmClock']
# 3365 ['IPCam_AlarmClock']
# 3372 ['IPCam_AlarmClock']
# 3377 ['IPCam_Netatmo']
# 3379 ['IPCam_V380']
# 3380 ['IPCam_AlarmClock']
# 3382 ['IPCam_AlarmClock']
# 3383 ['IPCam_AlarmClock']
# 3386 ['IPCam_V380']
# 3387 ['IPCam_AlarmClock']
# 3388 ['IPCam_AlarmClock']
# 3390 ['IPCam_AlarmClock']
# 3391 ['IPCam_AlarmClock']
# 3392 ['IPCam_V380']
# 3393 ['IPCam_AlarmClock']
# 3395 ['IPCam_AlarmClock']
# 3398 ['IPCam_Canary']
# 3399 ['IPCam_AlarmClock']
# 3400 ['IPCam_AlarmClock']
# 3401 ['IPCam_AlarmClock']
# 3402 ['IPCam_AlarmClock']
# 3404 ['IPCam_AlarmClock']
# 3405 ['IPCam_AlarmClock']
# 3408 ['IPCam_Netatmo']
# 3409 ['IPCam_AlarmClock']
# 3410 ['IPCam_V380']
# 3413 ['IPCam_AlarmClock']
# 3419 ['IPCam_AlarmClock']
# 3420 ['IPCam_AlarmClock']
# 3424 ['IPCam_AlarmClock']
# 3425 ['IPCam_V380']
# 3426 ['IPCam_AlarmClock']
# 3428 ['IPCam_AlarmClock']
# 3429 ['IPCam_AlarmClock']
# 3431 ['IPCam_AlarmClock']
# 3432 ['IPCam_AlarmClock']
# 3436 ['IPCam_AlarmClock']
# 3438 ['IPCam_AlarmClock']
# 3442 ['IPCam_AlarmClock']
# 3448 ['IPCam_AlarmClock']
# 3449 ['IPCam_V380']
# 3450 ['IPCam_AlarmClock']
# 3454 ['IPCam_AlarmClock']
# 3456 ['IPCam_AlarmClock']
# 3458 ['IPCam_V380']
# 3459 ['IPCam_AlarmClock']
# 3462 ['IPCam_V380']
# 3467 ['IPCam_AlarmClock']
# 3470 ['IPCam_AlarmClock']
# 3471 ['IPCam_AlarmClock']
# 3472 ['IPCam_AlarmClock']
# 3473 ['IPCam_AlarmClock']
# 3477 ['IPCam_AlarmClock']
# 3479 ['IPCam_AlarmClock']
# 3480 ['IPCam_AlarmClock']
# 3483 ['IPCam_AlarmClock']
# 3486 ['IPCam_AlarmClock']
# 3489 ['IPCam_AlarmClock']
# 3490 ['IPCam_AlarmClock']
# 3491 ['IPCam_AlarmClock']
# 3496 ['IPCam_AlarmClock']
# 3498 ['IPCam_AlarmClock']
# 3499 ['IPCam_AlarmClock']
# 3500 ['IPCam_AlarmClock']
# 3507 ['IPCam_AlarmClock']
# 3508 ['IPCam_AlarmClock']
# 3509 ['IPCam_AlarmClock']
# 3514 ['IPCam_AlarmClock']
# 3516 ['IPCam_AlarmClock']
# 3518 ['IPCam_AlarmClock']
# 3520 ['IPCam_V380']
# 3521 ['IPCam_AlarmClock']
# 3527 ['IPCam_AlarmClock']
# 3528 ['IPCam_AlarmClock']
# 3529 ['IPCam_AlarmClock']
# 3531 ['IPCam_AlarmClock']
# 3535 ['IPCam_AlarmClock']
# 3537 ['IPCam_AlarmClock']
# 3542 ['IPCam_AlarmClock']
# 3544 ['IPCam_V380']
# 3556 ['IPCam_V380']
# 3560 ['IPCam_AlarmClock']
# 3562 ['IPCam_AlarmClock']
# 3567 ['IPCam_V380']
# 3569 ['IPCam_AlarmClock']
# 3570 ['IPCam_AlarmClock']
# 3571 ['IPCam_V380']
# 3573 ['IPCam_AlarmClock']
# 3578 ['IPCam_AlarmClock']
# 3580 ['IPCam_AlarmClock']
# 3581 ['IPCam_AlarmClock']
# 3582 ['IPCam_AlarmClock']
# 3583 ['IPCam_AlarmClock']
# 3586 ['IPCam_AlarmClock']
# 3587 ['IPCam_AlarmClock']
# 3588 ['IPCam_AlarmClock']
# 3589 ['IPCam_AlarmClock']
# 3590 ['IPCam_AlarmClock']
# 3592 ['IPCam_AlarmClock']
# 3593 ['IPCam_V380']
# 3594 ['IPCam_AlarmClock']
# 3595 ['IPCam_AlarmClock']
# 3599 ['IPCam_AlarmClock']
# 3602 ['IPCam_AlarmClock']
# 3605 ['IPCam_AlarmClock']
# 3606 ['IPCam_AlarmClock']
# 3607 ['IPCam_AlarmClock']
# 3608 ['IPCam_AlarmClock']
# 3611 ['IPCam_AlarmClock']
# 3613 ['IPCam_AlarmClock']
# 3617 ['IPCam_V380']
# 3619 ['IPCam_AlarmClock']
# 3626 ['IPCam_AlarmClock']
# 3629 ['IPCam_AlarmClock']
# 3630 ['IPCam_AlarmClock']
# 3632 ['IPCam_AlarmClock']
# 3636 ['IPCam_AlarmClock']
# 3637 ['IPCam_AlarmClock']
# 3641 ['IPCam_AlarmClock']
# 3644 ['IPCam_AlarmClock']
# 3646 ['IPCam_AlarmClock']
# 3651 ['IPCam_V380']
# 3654 ['IPCam_AlarmClock']
# 3657 ['IPCam_AlarmClock']
# 3659 ['IPCam_V380']
# 3661 ['IPCam_AlarmClock']
# 3662 ['IPCam_AlarmClock']
# 3672 ['IPCam_V380']
# 3674 ['IPCam_AlarmClock']
# 3675 ['IPCam_V380']
# 3677 ['IPCam_V380']
# 3678 ['IPCam_AlarmClock']
# 3680 ['IPCam_V380']
# 3683 ['IPCam_AlarmClock']
# 3684 ['IPCam_AlarmClock']
# 3687 ['IPCam_AlarmClock']
# 3690 ['IPCam_AlarmClock']
# 3694 ['IPCam_AlarmClock']
# 3698 ['IPCam_V380']
# 3699 ['IPCam_AlarmClock']
# 3701 ['IPCam_AlarmClock']
# 3702 ['IPCam_AlarmClock']
# 3704 ['IPCam_AlarmClock']
# 3709 ['IPCam_AlarmClock']
# 3714 ['IPCam_AlarmClock']
# 3715 ['IPCam_V380']
# 3719 ['IPCam_AlarmClock']
# 3722 ['IPCam_AlarmClock']
# 3723 ['IPCam_AlarmClock']
# 3725 ['IPCam_AlarmClock']
# 3726 ['IPCam_AlarmClock']
# 3727 ['IPCam_AlarmClock']
# 3728 ['IPCam_V380']
# 3729 ['IPCam_AlarmClock']
# 3732 ['IPCam_AlarmClock']
# 3733 ['IPCam_AlarmClock']
# 3734 ['IPCam_AlarmClock']
# 3735 ['IPCam_AlarmClock']
# 3737 ['IPCam_AlarmClock']
# 3745 ['IPCam_AlarmClock']
# 3746 ['IPCam_V380']
# 3749 ['IPCam_AlarmClock']
# 3750 ['IPCam_AlarmClock']
# 3751 ['IPCam_AlarmClock']
# 3754 ['IPCam_AlarmClock']
# 3755 ['IPCam_AlarmClock']
# 3757 ['IPCam_V380']
# 3760 ['IPCam_V380']
# 3763 ['IPCam_V380']
# 3764 ['IPCam_AlarmClock']
# 3765 ['IPCam_AlarmClock']
# 3768 ['IPCam_AlarmClock']
# 3769 ['IPCam_AlarmClock']
# 3770 ['IPCam_AlarmClock']
# 3771 ['IPCam_AlarmClock']
# 3772 ['IPCam_AlarmClock']
# 3773 ['IPCam_AlarmClock']
# 3774 ['IPCam_AlarmClock']
# 3775 ['IPCam_AlarmClock']
# 3776 ['IPCam_AlarmClock']
# 3777 ['IPCam_AlarmClock']
# 3779 ['IPCam_AlarmClock']
# 3782 ['IPCam_AlarmClock']
# 3783 ['IPCam_V380']
# 3784 ['IPCam_AlarmClock']
# 3788 ['IPCam_AlarmClock']
# 3790 ['IPCam_AlarmClock']
# 3791 ['IPCam_AlarmClock']
# 3792 ['IPCam_AlarmClock']
# 3793 ['IPCam_AlarmClock']
# 3794 ['IPCam_V380']
# 3797 ['IPCam_AlarmClock']
# 3798 ['IPCam_AlarmClock']
# 3799 ['IPCam_AlarmClock']
# 3803 ['IPCam_V380']
# 3804 ['IPCam_Ezviz']
# 3807 ['IPCam_AlarmClock']
# 3811 ['IPCam_AlarmClock']
# 3813 ['IPCam_AlarmClock']
# 3814 ['IPCam_AlarmClock']
# 3818 ['IPCam_V380']
# 3819 ['IPCam_AlarmClock']
# 3820 ['IPCam_AlarmClock']
# 3822 ['IPCam_AlarmClock']
# 3823 ['IPCam_AlarmClock']
# 3825 ['IPCam_AlarmClock']
# 3826 ['IPCam_AlarmClock']
# 3829 ['IPCam_V380']
# 3832 ['IPCam_AlarmClock']
# 3836 ['IPCam_AlarmClock']
# 3837 ['IPCam_AlarmClock']
# 3839 ['IPCam_Ezviz']
# 3840 ['IPCam_AlarmClock']
# 3844 ['IPCam_AlarmClock']
# 3847 ['IPCam_AlarmClock']
# 3850 ['IPCam_AlarmClock']
# 3861 ['IPCam_V380']
# 3862 ['IPCam_AlarmClock']
# 3867 ['IPCam_AlarmClock']
# 3868 ['IPCam_AlarmClock']
# 3874 ['IPCam_V380']
# 3875 ['IPCam_V380']
# 3876 ['IPCam_AlarmClock']
# 3877 ['IPCam_AlarmClock']
# 3882 ['IPCam_AlarmClock']
# 3883 ['IPCam_AlarmClock']
# 3884 ['IPCam_Netatmo']
# 3885 ['IPCam_AlarmClock']
# 3886 ['IPCam_AlarmClock']
# 3887 ['IPCam_AlarmClock']
# 3891 ['IPCam_AlarmClock']
# 3894 ['IPCam_AlarmClock']
# 3896 ['IPCam_V380']
# 3898 ['IPCam_AlarmClock']
# 3899 ['IPCam_AlarmClock']
# 3902 ['IPCam_AlarmClock']
# 3903 ['IPCam_AlarmClock']
# 3908 ['IPCam_V380']
# 3913 ['IPCam_V380']
# 3918 ['IPCam_AlarmClock']
# 3923 ['IPCam_V380']
# 3926 ['IPCam_AlarmClock']
# 3930 ['IPCam_AlarmClock']
# 3931 ['IPCam_AlarmClock']
# 3933 ['IPCam_AlarmClock']
# 3936 ['IPCam_AlarmClock']
# 3937 ['IPCam_AlarmClock']
# 3938 ['IPCam_AlarmClock']
# 3939 ['IPCam_AlarmClock']
# 3942 ['IPCam_AlarmClock']
# 3944 ['IPCam_AlarmClock']
# 3945 ['IPCam_AlarmClock']
# 3947 ['IPCam_AlarmClock']
# 3949 ['IPCam_AlarmClock']
# 3951 ['IPCam_AlarmClock']
# 3953 ['IPCam_AlarmClock']
# 3954 ['IPCam_AlarmClock']
# 3958 ['IPCam_AlarmClock']
# 3961 ['IPCam_AlarmClock']
# 3962 ['IPCam_AlarmClock']
# 3963 ['IPCam_AlarmClock']
# 3964 ['IPCam_AlarmClock']
# 3966 ['IPCam_AlarmClock']
# 3968 ['IPCam_AlarmClock']
# 3969 ['IPCam_AlarmClock']
# 3975 ['IPCam_AlarmClock']
# 3976 ['IPCam_AlarmClock']
# 3977 ['IPCam_V380']
# 3985 ['IPCam_AlarmClock']
# 3987 ['IPCam_V380']
# 3989 ['IPCam_AlarmClock']
# 3990 ['IPCam_AlarmClock']
# 3995 ['IPCam_AlarmClock']
# 3997 ['IPCam_V380']
# 3999 ['IPCam_AlarmClock']
# 4001 ['IPCam_V380']
# 4002 ['IPCam_AlarmClock']
# 4003 ['IPCam_Netatmo']
# 4009 ['IPCam_AlarmClock']
# 4013 ['IPCam_V380']
# 4016 ['IPCam_AlarmClock']
# 4017 ['IPCam_AlarmClock']
# 4020 ['IPCam_AlarmClock']
# 4021 ['IPCam_AlarmClock']
# 4022 ['IPCam_AlarmClock']
# 4024 ['IPCam_AlarmClock']
# 4026 ['IPCam_AlarmClock']
# 4027 ['IPCam_AlarmClock']
# 4032 ['IPCam_AlarmClock']
# 4033 ['IPCam_AlarmClock']
# 4035 ['IPCam_V380']
# 4036 ['IPCam_AlarmClock']
# 4038 ['IPCam_AlarmClock']
# 4043 ['IPCam_AlarmClock']
# 4047 ['IPCam_AlarmClock']
# 4049 ['IPCam_V380']
# 4051 ['IPCam_AlarmClock']
# 4057 ['IPCam_AlarmClock']
# 4058 ['IPCam_AlarmClock']
# 4061 ['IPCam_AlarmClock']
# 4065 ['IPCam_V380']
# 4067 ['IPCam_AlarmClock']
# 4069 ['IPCam_AlarmClock']
# 4072 ['IPCam_AlarmClock']
# 4074 ['IPCam_V380']
# 4075 ['IPCam_AlarmClock']
# 4078 ['IPCam_V380']
# 4080 ['IPCam_V380']
# 4081 ['IPCam_AlarmClock']
# 4084 ['IPCam_AlarmClock']
# 4086 ['IPCam_AlarmClock']
# 4087 ['IPCam_AlarmClock']
# 4088 ['IPCam_AlarmClock']
# 4089 ['IPCam_AlarmClock']
# 4096 ['IPCam_AlarmClock']
# 4097 ['IPCam_Ezviz']
# 4101 ['IPCam_AlarmClock']
# 4102 ['IPCam_AlarmClock']
# 4104 ['IPCam_AlarmClock']
# 4105 ['IPCam_AlarmClock']
# 4118 ['IPCam_V380']
# 4120 ['IPCam_AlarmClock']
# 4121 ['IPCam_AlarmClock']
# 4122 ['IPCam_AlarmClock']
# 4123 ['IPCam_AlarmClock']
# 4125 ['IPCam_AlarmClock']
# 4126 ['IPCam_AlarmClock']
# 4131 ['IPCam_AlarmClock']
# 4140 ['IPCam_AlarmClock']
# 4141 ['IPCam_AlarmClock']
# 4144 ['IPCam_AlarmClock']
# 4145 ['IPCam_AlarmClock']
# 4147 ['IPCam_AlarmClock']
# 4148 ['IPCam_AlarmClock']
# 4149 ['IPCam_V380']
# 4150 ['IPCam_V380']
# 4156 ['IPCam_AlarmClock']
# 4157 ['IPCam_AlarmClock']
# 4158 ['IPCam_AlarmClock']
# 4159 ['IPCam_AlarmClock']
# 4160 ['IPCam_AlarmClock']
# 4162 ['IPCam_AlarmClock']
# 4164 ['IPCam_AlarmClock']
# 4168 ['IPCam_AlarmClock']
# 4169 ['IPCam_AlarmClock']
# 4170 ['IPCam_AlarmClock']
# 4173 ['IPCam_AlarmClock']
# 4178 ['IPCam_AlarmClock']
# 4179 ['IPCam_V380']
# 4180 ['IPCam_AlarmClock']
# 4187 ['IPCam_AlarmClock']
# 4188 ['IPCam_AlarmClock']
# 4189 ['IPCam_AlarmClock']
# 4190 ['IPCam_AlarmClock']
# 4193 ['IPCam_AlarmClock']
# 4199 ['IPCam_AlarmClock']
# 4200 ['IPCam_AlarmClock']
# 4202 ['IPCam_AlarmClock']
# 4206 ['IPCam_AlarmClock']
# 4207 ['IPCam_AlarmClock']
# 4212 ['IPCam_AlarmClock']
# 4213 ['IPCam_V380']
# 4214 ['IPCam_AlarmClock']
# 4215 ['IPCam_V380']
# 4216 ['IPCam_AlarmClock']
# 4219 ['IPCam_V380']
# 4220 ['IPCam_AlarmClock']
# 4221 ['IPCam_AlarmClock']
# 4223 ['IPCam_V380']
# 4224 ['IPCam_AlarmClock']
# 4225 ['IPCam_AlarmClock']
# 4226 ['IPCam_AlarmClock']
# 4227 ['IPCam_AlarmClock']
# 4230 ['IPCam_AlarmClock']
# 4231 ['IPCam_AlarmClock']
# 4232 ['IPCam_AlarmClock']
# 4235 ['IPCam_Ezviz']
# 4238 ['IPCam_AlarmClock']
# 4241 ['IPCam_AlarmClock']
# 4244 ['IPCam_AlarmClock']
# 4250 ['IPCam_V380']
# 4252 ['IPCam_AlarmClock']
# 4253 ['IPCam_V380']
# 4254 ['IPCam_AlarmClock']
# 4257 ['IPCam_V380']
# 4258 ['IPCam_AlarmClock']
# 4260 ['IPCam_AlarmClock']
# 4261 ['IPCam_AlarmClock']
# 4263 ['IPCam_V380']
# 4268 ['IPCam_AlarmClock']
# 4269 ['IPCam_AlarmClock']
# 4270 ['IPCam_AlarmClock']
# 4271 ['IPCam_AlarmClock']
# 4272 ['IPCam_AlarmClock']
# 4273 ['IPCam_AlarmClock']
# 4274 ['IPCam_AlarmClock']
# 4275 ['IPCam_AlarmClock']
# 4277 ['IPCam_AlarmClock']
# 4281 ['IPCam_AlarmClock']
# 4284 ['IPCam_Canary']
# 4287 ['IPCam_AlarmClock']
# 4301 ['IPCam_AlarmClock']
# 4304 ['IPCam_AlarmClock']
# 4306 ['IPCam_AlarmClock']
# 4310 ['IPCam_AlarmClock']
# 4311 ['IPCam_AlarmClock']
# 4315 ['IPCam_AlarmClock']
# 4318 ['IPCam_AlarmClock']
# 4319 ['IPCam_V380']
# 4324 ['IPCam_AlarmClock']
# 4325 ['IPCam_V380']
# 4330 ['IPCam_V380']
# 4331 ['IPCam_AlarmClock']
# 4332 ['IPCam_AlarmClock']
# 4333 ['IPCam_Netatmo']
# 4334 ['IPCam_AlarmClock']
# 4336 ['IPCam_AlarmClock']
# 4339 ['IPCam_AlarmClock']
# 4340 ['IPCam_AlarmClock']
# 4341 ['IPCam_AlarmClock']
# 4345 ['IPCam_V380']
# 4348 ['IPCam_AlarmClock']
# 4351 ['IPCam_AlarmClock']
# 4353 ['IPCam_AlarmClock']
# 4356 ['IPCam_AlarmClock']
# 4357 ['IPCam_V380']
# 4358 ['IPCam_AlarmClock']
# 4359 ['IPCam_V380']
# 4366 ['IPCam_AlarmClock']
# 4368 ['IPCam_AlarmClock']
# 4371 ['IPCam_AlarmClock']
# 4374 ['IPCam_V380']
# 4376 ['IPCam_AlarmClock']
# 4377 ['IPCam_AlarmClock']
# 4379 ['IPCam_AlarmClock']
# 4381 ['IPCam_AlarmClock']
# 4382 ['IPCam_AlarmClock']
# 4383 ['IPCam_V380']
# 4388 ['IPCam_AlarmClock']
# 4389 ['IPCam_V380']
# 4390 ['IPCam_AlarmClock']
# 4391 ['IPCam_AlarmClock']
# 4394 ['IPCam_AlarmClock']
# 4399 ['IPCam_AlarmClock']
# 4403 ['IPCam_V380']
# 4406 ['IPCam_AlarmClock']
# 4408 ['IPCam_V380']
# 4411 ['IPCam_AlarmClock']
# 4412 ['IPCam_AlarmClock']
# 4414 ['IPCam_AlarmClock']
# 4415 ['IPCam_AlarmClock']
# 4417 ['IPCam_AlarmClock']
# 4419 ['IPCam_AlarmClock']
# 4421 ['IPCam_AlarmClock']
# 4423 ['IPCam_AlarmClock']
# 4425 ['IPCam_V380']
# 4428 ['IPCam_AlarmClock']
# 4429 ['IPCam_V380']
# 4432 ['IPCam_AlarmClock']
# 4433 ['IPCam_AlarmClock']
# 4435 ['IPCam_V380']
# 4437 ['IPCam_AlarmClock']
# 4439 ['IPCam_V380']
# 4446 ['IPCam_AlarmClock']
# 4448 ['IPCam_AlarmClock']
# 4456 ['IPCam_AlarmClock']
# 4459 ['IPCam_AlarmClock']
# 4463 ['IPCam_AlarmClock']
# 4464 ['IPCam_V380']
# 4468 ['IPCam_V380']
# 4471 ['IPCam_AlarmClock']
# 4473 ['IPCam_AlarmClock']
# 4475 ['IPCam_V380']
# 4478 ['IPCam_AlarmClock']
# 4480 ['IPCam_AlarmClock']
# 4481 ['IPCam_AlarmClock']
# 4483 ['IPCam_AlarmClock']
# 4484 ['IPCam_AlarmClock']
# 4487 ['IPCam_AlarmClock']
# 4488 ['IPCam_V380']
# 4490 ['IPCam_AlarmClock']
# 4491 ['IPCam_AlarmClock']
# 4493 ['IPCam_AlarmClock']
# 4494 ['IPCam_V380']
# 4497 ['IPCam_AlarmClock']
# 4499 ['IPCam_AlarmClock']
# 4500 ['IPCam_AlarmClock']
# 4501 ['IPCam_AlarmClock']
# 4503 ['IPCam_AlarmClock']
# 4504 ['IPCam_AlarmClock']
# 4505 ['IPCam_AlarmClock']
# 4506 ['IPCam_AlarmClock']
# 4510 ['IPCam_AlarmClock']
# 4514 ['IPCam_AlarmClock']
# 4516 ['IPCam_AlarmClock']
# 4518 ['IPCam_V380']
# 4521 ['IPCam_AlarmClock']
# 4524 ['IPCam_AlarmClock']
# 4526 ['IPCam_AlarmClock']
# 4532 ['IPCam_AlarmClock']
# 4538 ['IPCam_AlarmClock']
# 4546 ['IPCam_AlarmClock']
# 4553 ['IPCam_AlarmClock']
# 4554 ['IPCam_AlarmClock']
# 4556 ['IPCam_AlarmClock']
# 4557 ['IPCam_AlarmClock']
# 4558 ['IPCam_AlarmClock']
# 4561 ['IPCam_V380']
# 4562 ['IPCam_AlarmClock']
# 4565 ['IPCam_AlarmClock']
# 4566 ['IPCam_AlarmClock']
# 4567 ['IPCam_AlarmClock']
# 4569 ['IPCam_V380']
# 4572 ['IPCam_AlarmClock']
# 4574 ['IPCam_AlarmClock']
# 4580 ['IPCam_AlarmClock']
# 4583 ['IPCam_AlarmClock']
# 4586 ['IPCam_AlarmClock']
# 4588 ['IPCam_Netatmo']
# 4590 ['IPCam_V380']
# 4592 ['IPCam_AlarmClock']
# 4604 ['IPCam_AlarmClock']
# 4607 ['IPCam_AlarmClock']
# 4611 ['IPCam_AlarmClock']
# 4614 ['IPCam_AlarmClock']
# 4615 ['IPCam_V380']
# 4618 ['IPCam_AlarmClock']
# 4619 ['IPCam_AlarmClock']
# 4623 ['IPCam_AlarmClock']
# 4624 ['IPCam_AlarmClock']
# 4627 ['IPCam_AlarmClock']
# 4628 ['IPCam_AlarmClock']
# 4630 ['IPCam_AlarmClock']
# 4631 ['IPCam_AlarmClock']
# 4632 ['IPCam_AlarmClock']
# 4634 ['IPCam_AlarmClock']
# 4637 ['IPCam_V380']
# 4640 ['IPCam_AlarmClock']
# 4641 ['IPCam_AlarmClock']
# 4642 ['IPCam_AlarmClock']
# 4644 ['IPCam_AlarmClock']
# 4645 ['IPCam_V380']
# 4649 ['IPCam_AlarmClock']
# 4650 ['IPCam_AlarmClock']
# 4651 ['IPCam_AlarmClock']
# 4654 ['IPCam_V380']
# 4655 ['IPCam_V380']
# 4659 ['IPCam_AlarmClock']
# 4660 ['IPCam_AlarmClock']
# 4662 ['IPCam_AlarmClock']
# 4663 ['IPCam_AlarmClock']
# 4666 ['IPCam_AlarmClock']
# 4667 ['IPCam_V380']
# 4676 ['IPCam_AlarmClock']
# 4679 ['IPCam_V380']
# 4680 ['IPCam_AlarmClock']
# 4682 ['IPCam_AlarmClock']
# 4685 ['IPCam_AlarmClock']
# 4686 ['IPCam_V380']
# 4688 ['IPCam_AlarmClock']
# 4691 ['IPCam_V380']
# 4693 ['IPCam_AlarmClock']
# 4694 ['IPCam_AlarmClock']
# 4696 ['IPCam_AlarmClock']
# 4698 ['IPCam_AlarmClock']
# 4706 ['IPCam_AlarmClock']
# 4707 ['IPCam_AlarmClock']
# 4708 ['IPCam_AlarmClock']
# 4709 ['IPCam_AlarmClock']
# 4710 ['IPCam_Ezviz']
# 4713 ['IPCam_AlarmClock']
# 4714 ['IPCam_V380']
# 4715 ['IPCam_AlarmClock']
# 4716 ['IPCam_V380']
# 4717 ['IPCam_V380']
# 4718 ['IPCam_AlarmClock']
# 4719 ['IPCam_V380']
# 4720 ['IPCam_V380']
# 4721 ['IPCam_AlarmClock']
# 4723 ['IPCam_AlarmClock']
# 4728 ['IPCam_Canary']
# 4730 ['IPCam_AlarmClock']
# 4731 ['IPCam_AlarmClock']
# 4733 ['IPCam_AlarmClock']
# 4736 ['IPCam_AlarmClock']
# 4739 ['IPCam_AlarmClock']
# 4741 ['IPCam_AlarmClock']
# 4742 ['IPCam_AlarmClock']
# 4743 ['IPCam_AlarmClock']
# 4744 ['IPCam_AlarmClock']
# 4745 ['IPCam_AlarmClock']
# 4746 ['IPCam_AlarmClock']
# 4750 ['IPCam_AlarmClock']
# 4752 ['IPCam_AlarmClock']
# 4755 ['IPCam_AlarmClock']
# 4756 ['IPCam_AlarmClock']
# 4758 ['IPCam_AlarmClock']
# 4759 ['IPCam_AlarmClock']
# 4764 ['IPCam_Canary']
# 4766 ['IPCam_V380']
# 4772 ['IPCam_AlarmClock']
# 4773 ['IPCam_V380']
# 4778 ['IPCam_AlarmClock']
# 4779 ['IPCam_Canary']
# 4781 ['IPCam_AlarmClock']
# 4782 ['IPCam_AlarmClock']
# 4783 ['IPCam_AlarmClock']
# 4786 ['IPCam_V380']
# 4787 ['IPCam_AlarmClock']
# 4788 ['IPCam_AlarmClock']
# 4792 ['IPCam_AlarmClock']
# 4793 ['IPCam_AlarmClock']
# 4796 ['IPCam_AlarmClock']
# 4799 ['IPCam_AlarmClock']
# 4801 ['IPCam_AlarmClock']
# 4802 ['IPCam_AlarmClock']
# 4804 ['IPCam_AlarmClock']
# 4806 ['IPCam_AlarmClock']
# 4808 ['IPCam_Ezviz']
# 4815 ['IPCam_AlarmClock']
# 4816 ['IPCam_Netatmo']
# 4817 ['IPCam_AlarmClock']
# 4818 ['IPCam_V380']
# 4820 ['IPCam_AlarmClock']
# 4824 ['IPCam_AlarmClock']
# 4830 ['IPCam_AlarmClock']
# 4836 ['IPCam_AlarmClock']
# 4838 ['IPCam_AlarmClock']
# 4840 ['IPCam_AlarmClock']
# 4844 ['IPCam_AlarmClock']
# 4845 ['IPCam_AlarmClock']
# 4848 ['IPCam_AlarmClock']
# 4852 ['IPCam_AlarmClock']
# 4853 ['IPCam_AlarmClock']
# 4854 ['IPCam_AlarmClock']
# 4857 ['IPCam_AlarmClock']
# 4859 ['IPCam_AlarmClock']
# 4860 ['IPCam_AlarmClock']
# 4863 ['IPCam_AlarmClock']
# 4867 ['IPCam_V380']
# 4868 ['IPCam_AlarmClock']
# 4869 ['IPCam_Ezviz']
# 4871 ['IPCam_AlarmClock']
# 4872 ['IPCam_AlarmClock']
# 4879 ['IPCam_AlarmClock']
# 4881 ['IPCam_Netatmo']
# 4882 ['IPCam_AlarmClock']
# 4886 ['IPCam_AlarmClock']
# 4889 ['IPCam_AlarmClock']
# 4892 ['IPCam_AlarmClock']
# 4896 ['IPCam_AlarmClock']
# 4900 ['IPCam_V380']
# 4901 ['IPCam_AlarmClock']
# 4902 ['IPCam_AlarmClock']
# 4903 ['IPCam_V380']
# 4909 ['IPCam_AlarmClock']
# 4913 ['IPCam_AlarmClock']
# 4915 ['IPCam_V380']
# 4921 ['IPCam_AlarmClock']
# 4922 ['IPCam_AlarmClock']
# 4924 ['IPCam_AlarmClock']
# 4925 ['IPCam_AlarmClock']
# 4931 ['IPCam_AlarmClock']
# 4932 ['IPCam_AlarmClock']
# 4933 ['IPCam_AlarmClock']
# 4934 ['IPCam_AlarmClock']
# 4938 ['IPCam_AlarmClock']
# 4947 ['IPCam_AlarmClock']
# 4948 ['IPCam_AlarmClock']
# 4952 ['IPCam_AlarmClock']
# 4956 ['IPCam_AlarmClock']
# 4958 ['IPCam_AlarmClock']
# 4959 ['IPCam_AlarmClock']
# 4963 ['IPCam_AlarmClock']
# 4966 ['IPCam_Netatmo']
# 4969 ['IPCam_AlarmClock']
# 4970 ['IPCam_AlarmClock']
# 4977 ['IPCam_AlarmClock']
# 4979 ['IPCam_AlarmClock']
# 4980 ['IPCam_AlarmClock']
# 4982 ['IPCam_AlarmClock']
# 4984 ['IPCam_AlarmClock']
# 4990 ['IPCam_AlarmClock']
# 4991 ['IPCam_AlarmClock']
# 4993 ['IPCam_V380']
# 4996 ['IPCam_AlarmClock']
# 4999 ['IPCam_AlarmClock']
# 5001 ['IPCam_V380']
# 5003 ['IPCam_V380']
# 5004 ['IPCam_AlarmClock']
# 5005 ['IPCam_AlarmClock']
# 5006 ['IPCam_AlarmClock']
# 5007 ['IPCam_AlarmClock']
# 5010 ['IPCam_AlarmClock']
# 5017 ['IPCam_Ezviz']
# 5021 ['IPCam_AlarmClock']
# 5022 ['IPCam_AlarmClock']
# 5023 ['IPCam_V380']
# 5024 ['IPCam_AlarmClock']
# 5025 ['IPCam_AlarmClock']
# 5026 ['IPCam_AlarmClock']
# 5030 ['IPCam_AlarmClock']
# 5031 ['IPCam_AlarmClock']
# 5033 ['IPCam_V380']
# 5035 ['IPCam_AlarmClock']
# 5036 ['IPCam_AlarmClock']
# 5037 ['IPCam_AlarmClock']
# 5039 ['IPCam_AlarmClock']
# 5044 ['IPCam_AlarmClock']
# 5047 ['IPCam_AlarmClock']
# 5048 ['IPCam_V380']
# 5049 ['IPCam_AlarmClock']
# 5050 ['IPCam_AlarmClock']
# 5052 ['IPCam_AlarmClock']
# 5055 ['IPCam_AlarmClock']
# 5056 ['IPCam_AlarmClock']
# 5058 ['IPCam_AlarmClock']
# 5059 ['IPCam_AlarmClock']
# 5065 ['IPCam_AlarmClock']
# 5069 ['IPCam_AlarmClock']
# 5072 ['IPCam_V380']
# 5073 ['IPCam_V380']
# 5075 ['IPCam_AlarmClock']
# 5078 ['IPCam_V380']
# 5079 ['IPCam_AlarmClock']
# 5081 ['IPCam_AlarmClock']
# 5084 ['IPCam_AlarmClock']
# 5088 ['IPCam_AlarmClock']
# 5089 ['IPCam_AlarmClock']
# 5095 ['IPCam_AlarmClock']
# 5097 ['IPCam_AlarmClock']
# 5098 ['IPCam_AlarmClock']
# 5099 ['IPCam_V380']
# 5100 ['IPCam_AlarmClock']
# 5104 ['IPCam_AlarmClock']
# 5106 ['IPCam_AlarmClock']
# 5107 ['IPCam_AlarmClock']
# 5116 ['IPCam_AlarmClock']
# 5118 ['IPCam_AlarmClock']
# 5122 ['IPCam_AlarmClock']
# 5125 ['IPCam_AlarmClock']
# 5126 ['IPCam_AlarmClock']
# 5127 ['IPCam_AlarmClock']
# 5135 ['IPCam_AlarmClock']
# 5137 ['IPCam_AlarmClock']
# 5139 ['IPCam_AlarmClock']
# 5141 ['IPCam_AlarmClock']
# 5142 ['IPCam_AlarmClock']
# 5145 ['IPCam_AlarmClock']
# 5146 ['IPCam_AlarmClock']
# 5147 ['IPCam_V380']
# 5148 ['IPCam_AlarmClock']
# 5150 ['IPCam_V380']
# 5151 ['IPCam_AlarmClock']
# 5153 ['IPCam_AlarmClock']
# 5155 ['IPCam_AlarmClock']
# 5157 ['IPCam_AlarmClock']
# 5158 ['IPCam_AlarmClock']
# 5159 ['IPCam_AlarmClock']
# 5161 ['IPCam_AlarmClock']
# 5162 ['IPCam_V380']
# 5164 ['IPCam_V380']
# 5166 ['IPCam_AlarmClock']
# 5167 ['IPCam_AlarmClock']
# 5172 ['IPCam_AlarmClock']
# 5174 ['IPCam_AlarmClock']
# 5178 ['IPCam_AlarmClock']
# 5179 ['IPCam_AlarmClock']
# 5188 ['IPCam_AlarmClock']
# 5189 ['IPCam_AlarmClock']
# 5193 ['IPCam_AlarmClock']
# 5195 ['IPCam_AlarmClock']
# 5197 ['IPCam_V380']
# 5199 ['IPCam_AlarmClock']
# 5201 ['IPCam_AlarmClock']
# 5202 ['IPCam_AlarmClock']
# 5203 ['IPCam_AlarmClock']
# 5208 ['IPCam_AlarmClock']
# 5213 ['IPCam_AlarmClock']
# 5215 ['IPCam_AlarmClock']
# 5217 ['IPCam_AlarmClock']
# 5221 ['IPCam_AlarmClock']
# 5226 ['IPCam_AlarmClock']
# 5229 ['IPCam_AlarmClock']
# 5230 ['IPCam_AlarmClock']
# 5231 ['IPCam_AlarmClock']
# 5235 ['IPCam_AlarmClock']
# 5236 ['IPCam_AlarmClock']
# 5240 ['IPCam_AlarmClock']
# 5243 ['IPCam_V380']
# 5244 ['IPCam_AlarmClock']
# 5245 ['IPCam_AlarmClock']
# 5247 ['IPCam_AlarmClock']
# 5252 ['IPCam_AlarmClock']
# 5256 ['IPCam_AlarmClock']
# 5257 ['IPCam_AlarmClock']
# 5263 ['IPCam_AlarmClock']
# 5264 ['IPCam_AlarmClock']
# 5266 ['IPCam_AlarmClock']
# 5268 ['IPCam_AlarmClock']
# 5274 ['IPCam_AlarmClock']
# 5275 ['IPCam_AlarmClock']
# 5276 ['IPCam_V380']
# 5278 ['IPCam_AlarmClock']
# 5281 ['IPCam_AlarmClock']
# 5283 ['IPCam_V380']
# 5289 ['IPCam_AlarmClock']
# 5290 ['IPCam_AlarmClock']
# 5291 ['IPCam_Canary']
# 5293 ['IPCam_AlarmClock']
# 5294 ['IPCam_AlarmClock']
# 5296 ['IPCam_AlarmClock']
# 5297 ['IPCam_AlarmClock']
# 5298 ['IPCam_AlarmClock']
# 5299 ['IPCam_AlarmClock']
# 5304 ['IPCam_AlarmClock']
# 5305 ['IPCam_V380']
# 5307 ['IPCam_AlarmClock']
# 5308 ['IPCam_AlarmClock']
# 5309 ['IPCam_AlarmClock']
# 5313 ['IPCam_AlarmClock']
# 5314 ['IPCam_AlarmClock']
# 5315 ['IPCam_V380']
# 5324 ['IPCam_AlarmClock']
# 5328 ['IPCam_AlarmClock']
# 5329 ['IPCam_AlarmClock']
# 5330 ['IPCam_AlarmClock']
# 5333 ['IPCam_AlarmClock']
# 5337 ['IPCam_AlarmClock']
# 5339 ['IPCam_AlarmClock']
# 5340 ['IPCam_AlarmClock']
# 5341 ['IPCam_AlarmClock']
# 5343 ['IPCam_AlarmClock']
# 5346 ['IPCam_AlarmClock']
# 5347 ['IPCam_V380']
# 5348 ['IPCam_AlarmClock']
# 5350 ['IPCam_AlarmClock']
# 5354 ['IPCam_AlarmClock']
# 5355 ['IPCam_AlarmClock']
# 5356 ['IPCam_AlarmClock']
# 5364 ['IPCam_AlarmClock']
# 5365 ['IPCam_Canary']
# 5366 ['IPCam_AlarmClock']
# 5369 ['IPCam_AlarmClock']
# 5372 ['IPCam_AlarmClock']
# 5373 ['IPCam_AlarmClock']
# 5374 ['IPCam_AlarmClock']
# 5377 ['IPCam_AlarmClock']
# 5381 ['IPCam_AlarmClock']
# 5384 ['IPCam_AlarmClock']
# 5389 ['IPCam_AlarmClock']
# 5391 ['IPCam_AlarmClock']
# 5392 ['IPCam_AlarmClock']
# 5393 ['IPCam_AlarmClock']
# 5399 ['IPCam_AlarmClock']
# 5400 ['IPCam_AlarmClock']
# 5404 ['IPCam_V380']
# 5406 ['IPCam_AlarmClock']
# 5408 ['IPCam_V380']
# 5411 ['IPCam_AlarmClock']
# 5412 ['IPCam_AlarmClock']
# 5413 ['IPCam_AlarmClock']
# 5418 ['IPCam_AlarmClock']
# 5423 ['IPCam_AlarmClock']
# 5424 ['IPCam_AlarmClock']
# 5427 ['IPCam_V380']
# 5429 ['IPCam_AlarmClock']
# 5432 ['IPCam_AlarmClock']
# 5437 ['IPCam_AlarmClock']
# 5439 ['IPCam_AlarmClock']
# 5440 ['IPCam_AlarmClock']
# 5441 ['IPCam_AlarmClock']
# 5449 ['IPCam_AlarmClock']
# 5452 ['IPCam_AlarmClock']
# 5454 ['IPCam_AlarmClock']
# 5455 ['IPCam_AlarmClock']
# 5457 ['IPCam_AlarmClock']
# 5460 ['IPCam_AlarmClock']
# 5462 ['IPCam_AlarmClock']
# 5463 ['IPCam_AlarmClock']
# 5468 ['IPCam_AlarmClock']
# 5470 ['IPCam_AlarmClock']
# 5471 ['IPCam_AlarmClock']
# 5473 ['IPCam_AlarmClock']
# 5476 ['IPCam_AlarmClock']
# 5478 ['IPCam_AlarmClock']
# 5479 ['IPCam_AlarmClock']
# 5480 ['IPCam_AlarmClock']
# 5482 ['IPCam_AlarmClock']
# 5483 ['IPCam_AlarmClock']
# 5484 ['IPCam_V380']
# 5485 ['IPCam_AlarmClock']
# 5489 ['IPCam_AlarmClock']
# 5490 ['IPCam_AlarmClock']
# 5492 ['IPCam_AlarmClock']
# 5506 ['IPCam_AlarmClock']
# 5509 ['IPCam_Netatmo']
# 5514 ['IPCam_V380']
# 5518 ['IPCam_V380']
# 5523 ['IPCam_V380']
# 5524 ['IPCam_AlarmClock']
# 5525 ['IPCam_AlarmClock']
# 5529 ['IPCam_AlarmClock']
# 5536 ['IPCam_AlarmClock']
# 5538 ['IPCam_AlarmClock']
# 5539 ['IPCam_AlarmClock']
# 5540 ['IPCam_AlarmClock']
# 5541 ['IPCam_V380']
# 5544 ['IPCam_V380']
# 5546 ['IPCam_AlarmClock']
# 5548 ['IPCam_AlarmClock']
# 5549 ['IPCam_AlarmClock']
# 5552 ['IPCam_V380']
# 5553 ['IPCam_V380']
# 5555 ['IPCam_AlarmClock']
# 5556 ['IPCam_AlarmClock']
# 5557 ['IPCam_AlarmClock']
# 5558 ['IPCam_AlarmClock']
# 5559 ['IPCam_AlarmClock']
# 5562 ['IPCam_AlarmClock']
# 5567 ['IPCam_AlarmClock']
# 5568 ['IPCam_AlarmClock']
# 5570 ['IPCam_AlarmClock']
# 5572 ['IPCam_AlarmClock']
# 5573 ['IPCam_AlarmClock']
# 5575 ['IPCam_AlarmClock']
# 5577 ['IPCam_V380']
# 5578 ['IPCam_AlarmClock']
# 5580 ['IPCam_AlarmClock']
# 5582 ['IPCam_V380']
# 5583 ['IPCam_AlarmClock']
# 5584 ['IPCam_V380']
# 5588 ['IPCam_AlarmClock']
# 5589 ['IPCam_AlarmClock']
# 5592 ['IPCam_AlarmClock']
# 5593 ['IPCam_AlarmClock']
# 5599 ['IPCam_AlarmClock']
# 5600 ['IPCam_AlarmClock']
# 5602 ['IPCam_AlarmClock']
# 5603 ['IPCam_AlarmClock']
# 5604 ['IPCam_AlarmClock']
# 5605 ['IPCam_AlarmClock']
# 5606 ['IPCam_AlarmClock']
# 5607 ['IPCam_AlarmClock']
# 5608 ['IPCam_AlarmClock']
# 5609 ['IPCam_AlarmClock']
# 5612 ['IPCam_AlarmClock']
# 5614 ['IPCam_AlarmClock']
# 5621 ['IPCam_V380']
# 5623 ['IPCam_AlarmClock']
# 5627 ['IPCam_AlarmClock']
# 5628 ['IPCam_AlarmClock']
# 5632 ['IPCam_AlarmClock']
# 5639 ['IPCam_AlarmClock']
# 5645 ['IPCam_AlarmClock']
# 5646 ['IPCam_AlarmClock']
# 5650 ['IPCam_AlarmClock']
# 5651 ['IPCam_AlarmClock']
# 5655 ['IPCam_AlarmClock']
# 5656 ['IPCam_V380']
# 5657 ['IPCam_AlarmClock']
# 5658 ['IPCam_AlarmClock']
# 5661 ['IPCam_AlarmClock']
# 5663 ['IPCam_Canary']
# 5667 ['IPCam_AlarmClock']
# 5672 ['IPCam_AlarmClock']
# 5673 ['IPCam_AlarmClock']
# 5675 ['IPCam_AlarmClock']
# 5676 ['IPCam_AlarmClock']
# 5677 ['IPCam_AlarmClock']
# 5680 ['IPCam_V380']
# 5681 ['IPCam_AlarmClock']
# 5685 ['IPCam_AlarmClock']
# 5686 ['IPCam_AlarmClock']
# 5706 ['IPCam_Canary']
# 5708 ['IPCam_Canary']
# 5732 ['IPCam_V380']
# 5769 ['IPCam_V380']
# 5777 ['IPCam_V380']
# 5795 ['IPCam_AlarmClock']
# 5812 ['IPCam_Ezviz']
# 5815 ['IPCam_Netatmo']
# 5829 ['IPCam_V380']
# 5857 ['IPCam_V380']
# 5860 ['IPCam_V380']
# 5871 ['IPCam_V380']
# 5879 ['IPCam_Ezviz']
# 5901 ['IPCam_Ezviz']
# 5916 ['IPCam_V380']
# 5933 ['IPCam_AlarmClock']
# 5939 ['IPCam_Ezviz']
# 5953 ['IPCam_V380']
# 5955 ['IPCam_V380']
# 5964 ['IPCam_V380']
# 5972 ['IPCam_Ezviz']
# 5991 ['IPCam_V380']
# 5995 ['IPCam_Ezviz']
# 5997 ['IPCam_V380']
# 6003 ['IPCam_Ezviz']
# 6016 ['IPCam_V380']
# 6032 ['IPCam_AlarmClock']
# 6037 ['IPCam_AlarmClock']
# 6038 ['IPCam_Ezviz']
# 6049 ['IPCam_AlarmClock']
# 6060 ['IPCam_AlarmClock']
# 6070 ['IPCam_AlarmClock']
# 6072 ['IPCam_Ezviz']
# 6087 ['IPCam_V380']
# 6090 ['IPCam_V380']
# 6099 ['IPCam_AlarmClock']
# 6100 ['IPCam_Ezviz']
# 6103 ['IPCam_AlarmClock']
# 6111 ['IPCam_Netatmo']
# 6121 ['IPCam_V380']
# 6126 ['IPCam_Ezviz']
# 6156 ['IPCam_Netatmo']
# 6159 ['IPCam_Ezviz']
# 6161 ['IPCam_Ezviz']
# 6166 ['IPCam_V380']
# 6169 ['IPCam_V380']
# 6186 ['IPCam_AlarmClock']
# 6187 ['IPCam_Ezviz']
# 6194 ['IPCam_AlarmClock']
# 6210 ['IPCam_AlarmClock']
# 6219 ['IPCam_Ezviz']
# 6223 ['IPCam_V380']
# 6226 ['IPCam_AlarmClock']
# 6240 ['IPCam_Ezviz']
# 6249 ['IPCam_V380']
# 6260 ['IPCam_V380']
# 6269 ['IPCam_AlarmClock']
# 6277 ['IPCam_Ezviz']
# 6297 ['IPCam_V380']
# 6299 ['IPCam_AlarmClock']
# 6320 ['IPCam_Netatmo']
# 6330 ['IPCam_AlarmClock']
# 6332 ['IPCam_Ezviz']
# 6336 ['IPCam_Ezviz']
# 6342 ['IPCam_AlarmClock']
# 6358 ['IPCam_AlarmClock']
# 6364 ['IPCam_V380']
# 6376 ['IPCam_AlarmClock']
# 6390 ['IPCam_Ezviz']
# 6393 ['IPCam_AlarmClock']
# 6404 ['IPCam_AlarmClock']
# 6409 ['IPCam_AlarmClock']
# 6419 ['IPCam_AlarmClock']
# 6432 ['IPCam_Ezviz']
# 6452 ['IPCam_AlarmClock']
# 6459 ['IPCam_AlarmClock']
# 6464 ['IPCam_AlarmClock']
# 6485 ['IPCam_Ezviz']
# 6491 ['IPCam_V380']
# 6493 ['IPCam_AlarmClock']
# 6519 ['IPCam_Ezviz']
# 6543 ['IPCam_AlarmClock']
# 6564 ['IPCam_V380']
# 6569 ['IPCam_Netatmo']
# 6574 ['IPCam_Ezviz']
# 6579 ['IPCam_Ezviz']
# 6583 ['IPCam_AlarmClock']
# 6592 ['IPCam_AlarmClock']
# 6601 ['IPCam_AlarmClock']
# 6605 ['IPCam_V380']
# 6608 ['IPCam_V380']
# 6612 ['IPCam_AlarmClock']
# 6613 ['IPCam_AlarmClock']
# 6614 ['IPCam_Ezviz']
# 6619 ['IPCam_AlarmClock']
# 6652 ['IPCam_V380']
# 6670 ['IPCam_Ezviz']
# 6681 ['IPCam_AlarmClock']
# 6682 ['IPCam_AlarmClock']
# 6686 ['IPCam_V380']
# 6692 ['IPCam_AlarmClock']
# 6697 ['IPCam_AlarmClock']
# 6698 ['IPCam_AlarmClock']
# 6703 ['IPCam_V380']
# 6709 ['IPCam_Ezviz']
# 6711 ['IPCam_V380']
# 6712 ['IPCam_AlarmClock']
# 6720 ['IPCam_V380']
# 6728 ['IPCam_Netatmo']
# 6749 ['IPCam_AlarmClock']
# 6750 ['IPCam_V380']
# 6758 ['IPCam_Ezviz']
# 6771 ['IPCam_V380']
# 6772 ['IPCam_V380']
# 6776 ['IPCam_V380']
# 6777 ['IPCam_V380']
# 6783 ['IPCam_V380']
# 6784 ['IPCam_V380']
# 6787 ['IPCam_AlarmClock']
# 6793 ['IPCam_AlarmClock']
# 6794 ['IPCam_AlarmClock']
# 6800 ['IPCam_Netatmo']
# 6803 ['IPCam_Ezviz']
# 6811 ['IPCam_Ezviz']
# 6822 ['IPCam_V380']
# 6828 ['IPCam_V380']
# 6829 ['IPCam_V380']
# 6830 ['IPCam_AlarmClock']
# 6845 ['IPCam_AlarmClock']
# 6846 ['IPCam_AlarmClock']
# 6850 ['IPCam_Ezviz']
# 6852 ['IPCam_AlarmClock']
# 6870 ['IPCam_V380']
# 6871 ['IPCam_AlarmClock']
# 6882 ['IPCam_Ezviz']
# 6886 ['IPCam_AlarmClock']
# 6896 ['IPCam_AlarmClock']
# 6902 ['IPCam_AlarmClock']
# 6908 ['IPCam_AlarmClock']
# 6910 ['IPCam_Canary']
# 6914 ['IPCam_AlarmClock']
# 6915 ['IPCam_AlarmClock']
# 6919 ['IPCam_AlarmClock']
# 6922 ['IPCam_AlarmClock']
# 6925 ['IPCam_AlarmClock']
# 6926 ['IPCam_AlarmClock']
# 6927 ['IPCam_AlarmClock']
# 6928 ['IPCam_V380']
# 6930 ['IPCam_AlarmClock']
# 6931 ['IPCam_AlarmClock']
# 6934 ['IPCam_AlarmClock']
# 6940 ['IPCam_AlarmClock']
# 6942 ['IPCam_AlarmClock']
# 6944 ['IPCam_AlarmClock']
# 6945 ['IPCam_V380']
# 6948 ['IPCam_V380']
# 6950 ['IPCam_AlarmClock']
# 6951 ['IPCam_AlarmClock']
# 6953 ['IPCam_V380']
# 6954 ['IPCam_AlarmClock']
# 6955 ['IPCam_AlarmClock']
# 6957 ['IPCam_AlarmClock']
# 6959 ['IPCam_AlarmClock']
# 6960 ['IPCam_AlarmClock']
# 6963 ['IPCam_AlarmClock']
# 6965 ['IPCam_AlarmClock']
# 6966 ['IPCam_AlarmClock']
# 6967 ['IPCam_AlarmClock']
# 6968 ['IPCam_V380']
# 6969 ['IPCam_AlarmClock']
# 6970 ['IPCam_AlarmClock']
# 6971 ['IPCam_AlarmClock']
# 6972 ['IPCam_V380']
# 6974 ['IPCam_AlarmClock']
# 6975 ['IPCam_AlarmClock']
# 6977 ['IPCam_V380']
# 6978 ['IPCam_AlarmClock']
# 6979 ['IPCam_AlarmClock']
# 6981 ['IPCam_AlarmClock']
# 6983 ['IPCam_AlarmClock']
# 6984 ['IPCam_AlarmClock']
# 6985 ['IPCam_AlarmClock']
# 6986 ['IPCam_AlarmClock']
# 6989 ['IPCam_AlarmClock']
# 6990 ['IPCam_AlarmClock']
# 6992 ['IPCam_AlarmClock']
# 6993 ['IPCam_AlarmClock']
# 6994 ['IPCam_AlarmClock']
# 6995 ['IPCam_AlarmClock']
# 6996 ['IPCam_AlarmClock']
# 6997 ['IPCam_AlarmClock']
# 6998 ['IPCam_AlarmClock']
# 6999 ['IPCam_AlarmClock']
# 7000 ['IPCam_V380']
# 7002 ['IPCam_AlarmClock']
# 7003 ['IPCam_AlarmClock']
# 7004 ['IPCam_AlarmClock']
# 7007 ['IPCam_Ezviz']
# 7008 ['IPCam_AlarmClock']
# 7012 ['IPCam_AlarmClock']
# 7013 ['IPCam_AlarmClock']
# 7016 ['IPCam_AlarmClock']
# 7018 ['IPCam_AlarmClock']
# 7020 ['IPCam_AlarmClock']
# 7021 ['IPCam_AlarmClock']
# 7024 ['IPCam_AlarmClock']
# 7027 ['IPCam_AlarmClock']
# 7029 ['IPCam_V380']
# 7031 ['IPCam_AlarmClock']
# 7033 ['IPCam_AlarmClock']
# 7035 ['IPCam_AlarmClock']
# 7037 ['IPCam_AlarmClock']
# 7038 ['IPCam_Ezviz']
# 7039 ['IPCam_AlarmClock']
# 7040 ['IPCam_AlarmClock']
# 7043 ['IPCam_AlarmClock']
# 7045 ['IPCam_AlarmClock']
# 7046 ['IPCam_AlarmClock']
# 7050 ['IPCam_AlarmClock']
# 7051 ['IPCam_AlarmClock']
# 7057 ['IPCam_AlarmClock']
# 7058 ['IPCam_AlarmClock']
# 7059 ['IPCam_AlarmClock']
# 7061 ['IPCam_AlarmClock']
# 7064 ['IPCam_AlarmClock']
# 7068 ['IPCam_V380']
# 7071 ['IPCam_AlarmClock']
# 7072 ['IPCam_AlarmClock']
# 7073 ['IPCam_AlarmClock']
# 7074 ['IPCam_AlarmClock']
# 7076 ['IPCam_AlarmClock']
# 7080 ['IPCam_AlarmClock']
# 7081 ['IPCam_AlarmClock']
# 7083 ['IPCam_AlarmClock']
# 7084 ['IPCam_AlarmClock']
# 7085 ['IPCam_AlarmClock']
# 7086 ['IPCam_AlarmClock']
# 7087 ['IPCam_AlarmClock']
# 7091 ['IPCam_AlarmClock']
# 7092 ['IPCam_AlarmClock']
# 7094 ['IPCam_AlarmClock']
# 7096 ['IPCam_AlarmClock']
# 7100 ['IPCam_AlarmClock']
# 7101 ['IPCam_V380']
# 7102 ['IPCam_AlarmClock']
# 7103 ['IPCam_AlarmClock']
# 7106 ['IPCam_AlarmClock']
# 7107 ['IPCam_AlarmClock']
# 7111 ['IPCam_AlarmClock']
# 7112 ['IPCam_AlarmClock']
# 7113 ['IPCam_AlarmClock']
# 7114 ['IPCam_AlarmClock']
# 7116 ['IPCam_V380']
# 7120 ['IPCam_AlarmClock']
# 7121 ['IPCam_AlarmClock']
# 7122 ['IPCam_AlarmClock']
# 7123 ['IPCam_AlarmClock']
# 7125 ['IPCam_AlarmClock']
# 7126 ['IPCam_AlarmClock']
# 7127 ['IPCam_AlarmClock']
# 7131 ['IPCam_AlarmClock']
# 7133 ['IPCam_AlarmClock']
# 7135 ['IPCam_AlarmClock']
# 7136 ['IPCam_AlarmClock']
# 7138 ['IPCam_AlarmClock']
# 7139 ['IPCam_AlarmClock']
# 7142 ['IPCam_AlarmClock']
# 7143 ['IPCam_AlarmClock']
# 7144 ['IPCam_AlarmClock']
# 7145 ['IPCam_AlarmClock']
# 7147 ['IPCam_AlarmClock']
# 7149 ['IPCam_AlarmClock']
# 7155 ['IPCam_AlarmClock']
# 7159 ['IPCam_AlarmClock']
# 7160 ['IPCam_AlarmClock']
# 7164 ['IPCam_AlarmClock']
# 7167 ['IPCam_AlarmClock']
# 7168 ['IPCam_AlarmClock']
# 7169 ['IPCam_AlarmClock']
# 7170 ['IPCam_AlarmClock']
# 7174 ['IPCam_Ezviz']
# 7175 ['IPCam_AlarmClock']
# 7178 ['IPCam_AlarmClock']
# 7180 ['IPCam_AlarmClock']
# 7181 ['IPCam_AlarmClock']
# 7182 ['IPCam_AlarmClock']
# 7184 ['IPCam_AlarmClock']
# 7185 ['IPCam_V380']
# 7191 ['IPCam_AlarmClock']
# 7195 ['IPCam_AlarmClock']
# 7198 ['IPCam_Ezviz']
# 7200 ['IPCam_AlarmClock']
# ...
# 46711 ['IPCam_AlarmClock']
# 46712 ['IPCam_V380']
# 46713 ['IPCam_AlarmClock']
# 46715 ['IPCam_AlarmClock']
# 46716 ['IPCam_AlarmClock']
# 46717 ['IPCam_AlarmClock']
# 46718 ['IPCam_AlarmClock']
# 46720 ['IPCam_AlarmClock']
# 46722 ['IPCam_AlarmClock']
# 46725 ['IPCam_AlarmClock']
# 46726 ['IPCam_AlarmClock']
# 46727 ['IPCam_AlarmClock']
# 46728 ['IPCam_AlarmClock']
# 46731 ['IPCam_AlarmClock']
# 46734 ['IPCam_AlarmClock']
# 46736 ['IPCam_AlarmClock']
# 46737 ['IPCam_AlarmClock']
# 46738 ['IPCam_AlarmClock']
# 46740 ['IPCam_AlarmClock']
# 46741 ['IPCam_AlarmClock']
# 46742 ['IPCam_AlarmClock']
# 46743 ['IPCam_AlarmClock']
# 46745 ['IPCam_AlarmClock']
# 46746 ['IPCam_Netatmo']
# 46748 ['IPCam_AlarmClock']
# 46751 ['IPCam_V380']
# 46752 ['IPCam_AlarmClock']
# 46753 ['IPCam_AlarmClock']
# 46754 ['IPCam_AlarmClock']
# 46757 ['IPCam_V380']
# 46758 ['IPCam_AlarmClock']
# 46759 ['IPCam_AlarmClock']
# 46761 ['IPCam_AlarmClock']
# 46762 ['IPCam_AlarmClock']
# 46763 ['IPCam_V380']
# 46764 ['IPCam_AlarmClock']
# 46765 ['IPCam_AlarmClock']
# 46766 ['IPCam_AlarmClock']
# 46767 ['IPCam_AlarmClock']
# 46768 ['IPCam_AlarmClock']
# 46769 ['IPCam_AlarmClock']
# 46771 ['IPCam_AlarmClock']
# 46776 ['IPCam_AlarmClock']
# 46777 ['IPCam_V380']
# 46779 ['IPCam_AlarmClock']
# 46781 ['IPCam_AlarmClock']
# 46785 ['IPCam_Ezviz']
# 46787 ['IPCam_AlarmClock']
# 46788 ['IPCam_AlarmClock']
# 46789 ['IPCam_AlarmClock']
# 46790 ['IPCam_AlarmClock']
# 46791 ['IPCam_AlarmClock']
# 46792 ['IPCam_V380']
# 46795 ['IPCam_AlarmClock']
# 46797 ['IPCam_AlarmClock']
# 46799 ['IPCam_AlarmClock']
# 46800 ['IPCam_AlarmClock']
# 46804 ['IPCam_AlarmClock']
# 46805 ['IPCam_AlarmClock']
# 46806 ['IPCam_AlarmClock']
# 46808 ['IPCam_AlarmClock']
# 46810 ['IPCam_AlarmClock']
# 46813 ['IPCam_AlarmClock']
# 46814 ['IPCam_AlarmClock']
# 46815 ['IPCam_Ezviz']
# 46819 ['IPCam_AlarmClock']
# 46821 ['IPCam_AlarmClock']
# 46823 ['IPCam_AlarmClock']
# 46824 ['IPCam_AlarmClock']
# 46825 ['IPCam_AlarmClock']
# 46826 ['IPCam_AlarmClock']
# 46827 ['IPCam_AlarmClock']
# 46829 ['IPCam_Ezviz']
# 46830 ['IPCam_AlarmClock']
# 46834 ['IPCam_AlarmClock']
# 46835 ['IPCam_AlarmClock']
# 46837 ['IPCam_AlarmClock']
# 46838 ['IPCam_AlarmClock']
# 46839 ['IPCam_AlarmClock']
# 46840 ['IPCam_AlarmClock']
# 46844 ['IPCam_AlarmClock']
# 46852 ['IPCam_AlarmClock']
# 46855 ['IPCam_AlarmClock']
# 46856 ['IPCam_AlarmClock']
# 46858 ['IPCam_AlarmClock']
# 46859 ['IPCam_AlarmClock']
# 46860 ['IPCam_AlarmClock']
# 46861 ['IPCam_AlarmClock']
# 46862 ['IPCam_AlarmClock']
# 46865 ['IPCam_V380']
# 46866 ['IPCam_AlarmClock']
# 46867 ['IPCam_AlarmClock']
# 46868 ['IPCam_AlarmClock']
# 46869 ['IPCam_AlarmClock']
# 46874 ['IPCam_AlarmClock']
# 46875 ['IPCam_AlarmClock']
# 46877 ['IPCam_AlarmClock']
# 46878 ['IPCam_AlarmClock']
# 46879 ['IPCam_AlarmClock']
# 46881 ['IPCam_AlarmClock']
# 46883 ['IPCam_AlarmClock']
# 46884 ['IPCam_AlarmClock']
# 46887 ['IPCam_AlarmClock']
# 46888 ['IPCam_AlarmClock']
# 46889 ['IPCam_AlarmClock']
# 46891 ['IPCam_AlarmClock']
# 46893 ['IPCam_AlarmClock']
# 46894 ['IPCam_AlarmClock']
# 46895 ['IPCam_AlarmClock']
# 46896 ['IPCam_AlarmClock']
# 46898 ['IPCam_AlarmClock']
# 46899 ['IPCam_AlarmClock']
# 46901 ['IPCam_AlarmClock']
# 46902 ['IPCam_AlarmClock']
# 46903 ['IPCam_AlarmClock']
# 46905 ['IPCam_V380']
# 46906 ['IPCam_AlarmClock']
# 46908 ['IPCam_AlarmClock']
# 46909 ['IPCam_AlarmClock']
# 46910 ['IPCam_AlarmClock']
# 46911 ['IPCam_AlarmClock']
# 46913 ['IPCam_AlarmClock']
# 46914 ['IPCam_V380']
# 46915 ['IPCam_AlarmClock']
# 46916 ['IPCam_AlarmClock']
# 46917 ['IPCam_AlarmClock']
# 46919 ['IPCam_AlarmClock']
# 46921 ['IPCam_AlarmClock']
# 46924 ['IPCam_AlarmClock']
# 46925 ['IPCam_AlarmClock']
# 46927 ['IPCam_AlarmClock']
# 46929 ['IPCam_AlarmClock']
# 46930 ['IPCam_AlarmClock']
# 46933 ['IPCam_V380']
# 46935 ['IPCam_AlarmClock']
# 46936 ['IPCam_AlarmClock']
# 46938 ['IPCam_Ezviz']
# 46939 ['IPCam_Ezviz']
# 46940 ['IPCam_AlarmClock']
# 46941 ['IPCam_AlarmClock']
# 46942 ['IPCam_AlarmClock']
# 46945 ['IPCam_AlarmClock']
# 46946 ['IPCam_AlarmClock']
# 46947 ['IPCam_AlarmClock']
# 46949 ['IPCam_AlarmClock']
# 46950 ['IPCam_AlarmClock']
# 46951 ['IPCam_Ezviz']
# 46952 ['IPCam_AlarmClock']
# 46953 ['IPCam_AlarmClock']
# 46956 ['IPCam_AlarmClock']
# 46957 ['IPCam_AlarmClock']
# 46958 ['IPCam_AlarmClock']
# 46961 ['IPCam_AlarmClock']
# 46963 ['IPCam_AlarmClock']
# 46964 ['IPCam_AlarmClock']
# 46965 ['IPCam_AlarmClock']
# 46966 ['IPCam_AlarmClock']
# 46968 ['IPCam_V380']
# 46971 ['IPCam_AlarmClock']
# 46972 ['IPCam_V380']
# 46973 ['IPCam_AlarmClock']
# 46974 ['IPCam_AlarmClock']
# 46977 ['IPCam_V380']
# 46978 ['IPCam_AlarmClock']
# 46979 ['IPCam_AlarmClock']
# 46980 ['IPCam_Ezviz']
# 46981 ['IPCam_V380']
# 46982 ['IPCam_AlarmClock']
# 46983 ['IPCam_AlarmClock']
# 46984 ['IPCam_AlarmClock']
# 46985 ['IPCam_AlarmClock']
# 46987 ['IPCam_AlarmClock']
# 46988 ['IPCam_AlarmClock']
# 46989 ['IPCam_AlarmClock']
# 46991 ['IPCam_AlarmClock']
# 46992 ['IPCam_AlarmClock']
# 46998 ['IPCam_AlarmClock']
# 46999 ['IPCam_AlarmClock']
# 47001 ['IPCam_AlarmClock']
# 47002 ['IPCam_AlarmClock']
# 47003 ['IPCam_AlarmClock']
# 47004 ['IPCam_AlarmClock']
# 47005 ['IPCam_AlarmClock']
# 47006 ['IPCam_AlarmClock']
# 47007 ['IPCam_Ezviz']
# 47011 ['IPCam_AlarmClock']
# 47012 ['IPCam_AlarmClock']
# 47013 ['IPCam_AlarmClock']
# 47014 ['IPCam_AlarmClock']
# 47015 ['IPCam_AlarmClock']
# 47016 ['IPCam_AlarmClock']
# 47017 ['IPCam_AlarmClock']
# 47018 ['IPCam_AlarmClock']
# 47020 ['IPCam_AlarmClock']
# 47022 ['IPCam_AlarmClock']
# 47023 ['IPCam_AlarmClock']
# 47024 ['IPCam_AlarmClock']
# 47025 ['IPCam_V380']
# 47026 ['IPCam_AlarmClock']
# 47029 ['IPCam_AlarmClock']
# 47031 ['IPCam_AlarmClock']
# 47035 ['IPCam_AlarmClock']
# 47036 ['IPCam_AlarmClock']
# 47038 ['IPCam_V380']
# 47039 ['IPCam_AlarmClock']
# 47041 ['IPCam_AlarmClock']
# 47042 ['IPCam_AlarmClock']
# 47043 ['IPCam_AlarmClock']
# 47044 ['IPCam_AlarmClock']
# 47045 ['IPCam_AlarmClock']
# 47046 ['IPCam_AlarmClock']
# 47047 ['IPCam_AlarmClock']
# 47048 ['IPCam_AlarmClock']
# 47049 ['IPCam_AlarmClock']
# 47050 ['IPCam_AlarmClock']
# 47051 ['IPCam_AlarmClock']
# 47053 ['IPCam_V380']
# 47058 ['IPCam_AlarmClock']
# 47060 ['IPCam_AlarmClock']
# 47065 ['IPCam_V380']
# 47066 ['IPCam_AlarmClock']
# 47068 ['IPCam_AlarmClock']
# 47069 ['IPCam_AlarmClock']
# 47070 ['IPCam_AlarmClock']
# 47072 ['IPCam_V380']
# 47073 ['IPCam_V380']
# 47078 ['IPCam_AlarmClock']
# 47079 ['IPCam_V380']
# 47080 ['IPCam_AlarmClock']
# 47081 ['IPCam_AlarmClock']
# 47084 ['IPCam_AlarmClock']
# 47085 ['IPCam_AlarmClock']
# 47087 ['IPCam_AlarmClock']
# 47088 ['IPCam_AlarmClock']
# 47089 ['IPCam_AlarmClock']
# 47090 ['IPCam_AlarmClock']
# 47093 ['IPCam_AlarmClock']
# 47094 ['IPCam_AlarmClock']
# 47095 ['IPCam_AlarmClock']
# 47096 ['IPCam_AlarmClock']
# 47097 ['IPCam_AlarmClock']
# 47098 ['IPCam_AlarmClock']
# 47102 ['IPCam_AlarmClock']
# 47103 ['IPCam_AlarmClock']
# 47104 ['IPCam_AlarmClock']
# 47105 ['IPCam_AlarmClock']
# 47107 ['IPCam_AlarmClock']
# 47109 ['IPCam_AlarmClock']
# 47110 ['IPCam_AlarmClock']
# 47113 ['IPCam_AlarmClock']
# 47114 ['IPCam_V380']
# 47115 ['IPCam_AlarmClock']
# 47117 ['IPCam_AlarmClock']
# 47118 ['IPCam_AlarmClock']
# 47120 ['IPCam_AlarmClock']
# 47121 ['IPCam_AlarmClock']
# 47122 ['IPCam_V380']
# 47123 ['IPCam_AlarmClock']
# 47124 ['IPCam_V380']
# 47126 ['IPCam_AlarmClock']
# 47128 ['IPCam_AlarmClock']
# 47129 ['IPCam_V380']
# 47130 ['IPCam_AlarmClock']
# 47131 ['IPCam_AlarmClock']
# 47132 ['IPCam_V380']
# 47134 ['IPCam_AlarmClock']
# 47135 ['IPCam_AlarmClock']
# 47137 ['IPCam_AlarmClock']
# 47139 ['IPCam_AlarmClock']
# 47141 ['IPCam_AlarmClock']
# 47143 ['IPCam_AlarmClock']
# 47145 ['IPCam_AlarmClock']
# 47146 ['IPCam_AlarmClock']
# 47147 ['IPCam_AlarmClock']
# 47149 ['IPCam_AlarmClock']
# 47150 ['IPCam_AlarmClock']
# 47151 ['IPCam_AlarmClock']
# 47152 ['IPCam_AlarmClock']
# 47154 ['IPCam_AlarmClock']
# 47155 ['IPCam_AlarmClock']
# 47156 ['IPCam_AlarmClock']
# 47158 ['IPCam_AlarmClock']
# 47159 ['IPCam_Ezviz']
# 47160 ['IPCam_AlarmClock']
# 47161 ['IPCam_AlarmClock']
# 47162 ['IPCam_AlarmClock']
# 47163 ['IPCam_AlarmClock']
# 47164 ['IPCam_AlarmClock']
# 47165 ['IPCam_AlarmClock']
# 47166 ['IPCam_AlarmClock']
# 47169 ['IPCam_AlarmClock']
# 47170 ['IPCam_AlarmClock']
# 47172 ['IPCam_AlarmClock']
# 47174 ['IPCam_AlarmClock']
# 47175 ['IPCam_V380']
# 47177 ['IPCam_AlarmClock']
# 47179 ['IPCam_AlarmClock']
# 47181 ['IPCam_AlarmClock']
# 47183 ['IPCam_AlarmClock']
# 47184 ['IPCam_V380']
# 47186 ['IPCam_AlarmClock']
# 47187 ['IPCam_AlarmClock']
# 47188 ['IPCam_AlarmClock']
# 47193 ['IPCam_AlarmClock']
# 47194 ['IPCam_AlarmClock']
# 47195 ['IPCam_AlarmClock']
# 47196 ['IPCam_V380']
# 47197 ['IPCam_AlarmClock']
# 47198 ['IPCam_AlarmClock']
# 47199 ['IPCam_AlarmClock']
# 47200 ['IPCam_AlarmClock']
# 47203 ['IPCam_AlarmClock']
# 47204 ['IPCam_AlarmClock']
# 47205 ['IPCam_AlarmClock']
# 47207 ['IPCam_AlarmClock']
# 47208 ['IPCam_V380']
# 47210 ['IPCam_AlarmClock']
# 47211 ['IPCam_AlarmClock']
# 47214 ['IPCam_V380']
# 47215 ['IPCam_AlarmClock']
# 47216 ['IPCam_AlarmClock']
# 47217 ['IPCam_AlarmClock']
# 47218 ['IPCam_AlarmClock']
# 47219 ['IPCam_AlarmClock']
# 47221 ['IPCam_AlarmClock']
# 47223 ['IPCam_AlarmClock']
# 47224 ['IPCam_AlarmClock']
# 47225 ['IPCam_AlarmClock']
# 47226 ['IPCam_AlarmClock']
# 47227 ['IPCam_V380']
# 47229 ['IPCam_AlarmClock']
# 47230 ['IPCam_AlarmClock']
# 47233 ['IPCam_AlarmClock']
# 47234 ['IPCam_AlarmClock']
# 47235 ['IPCam_AlarmClock']
# 47236 ['IPCam_AlarmClock']
# 47238 ['IPCam_AlarmClock']
# 47239 ['IPCam_AlarmClock']
# 47240 ['IPCam_V380']
# 47241 ['IPCam_AlarmClock']
# 47242 ['IPCam_AlarmClock']
# 47243 ['IPCam_AlarmClock']
# 47247 ['IPCam_AlarmClock']
# 47248 ['IPCam_AlarmClock']
# 47250 ['IPCam_AlarmClock']
# 47251 ['IPCam_AlarmClock']
# 47255 ['IPCam_V380']
# 47256 ['IPCam_AlarmClock']
# 47258 ['IPCam_AlarmClock']
# 47259 ['IPCam_V380']
# 47260 ['IPCam_AlarmClock']
# 47261 ['IPCam_AlarmClock']
# 47263 ['IPCam_AlarmClock']
# 47264 ['IPCam_AlarmClock']
# 47265 ['IPCam_AlarmClock']
# 47266 ['IPCam_AlarmClock']
# 47267 ['IPCam_AlarmClock']
# 47269 ['IPCam_V380']
# 47270 ['IPCam_AlarmClock']
# 47271 ['IPCam_AlarmClock']
# 47273 ['IPCam_AlarmClock']
# 47275 ['IPCam_AlarmClock']
# 47276 ['IPCam_AlarmClock']
# 47277 ['IPCam_AlarmClock']
# 47279 ['IPCam_AlarmClock']
# 47280 ['IPCam_AlarmClock']
# 47283 ['IPCam_AlarmClock']
# 47285 ['IPCam_AlarmClock']
# 47286 ['IPCam_AlarmClock']
# 47287 ['IPCam_AlarmClock']
# 47288 ['IPCam_AlarmClock']
# 47289 ['IPCam_Ezviz']
# 47290 ['IPCam_AlarmClock']
# 47291 ['IPCam_AlarmClock']
# 47292 ['IPCam_AlarmClock']
# 47293 ['IPCam_AlarmClock']
# 47294 ['IPCam_AlarmClock']
# 47295 ['IPCam_AlarmClock']
# 47296 ['IPCam_AlarmClock']
# 47297 ['IPCam_AlarmClock']
# 47300 ['IPCam_AlarmClock']
# 47301 ['IPCam_AlarmClock']
# 47303 ['IPCam_AlarmClock']
# 47304 ['IPCam_AlarmClock']
# 47306 ['IPCam_AlarmClock']
# 47307 ['IPCam_AlarmClock']
# 47309 ['IPCam_AlarmClock']
# 47314 ['IPCam_V380']
# 47316 ['IPCam_AlarmClock']
# 47318 ['IPCam_AlarmClock']
# 47319 ['IPCam_Ezviz']
# 47321 ['IPCam_AlarmClock']
# 47324 ['IPCam_AlarmClock']
# 47326 ['IPCam_V380']
# 47327 ['IPCam_AlarmClock']
# 47330 ['IPCam_AlarmClock']
# 47334 ['IPCam_AlarmClock']
# 47336 ['IPCam_AlarmClock']
# 47337 ['IPCam_AlarmClock']
# 47338 ['IPCam_AlarmClock']
# 47339 ['IPCam_AlarmClock']
# 47341 ['IPCam_AlarmClock']
# 47343 ['IPCam_V380']
# 47344 ['IPCam_AlarmClock']
# 47345 ['IPCam_AlarmClock']
# 47346 ['IPCam_AlarmClock']
# 47347 ['IPCam_AlarmClock']
# 47348 ['IPCam_AlarmClock']
# 47350 ['IPCam_AlarmClock']
# 47351 ['IPCam_AlarmClock']
# 47353 ['IPCam_AlarmClock']
# 47355 ['IPCam_AlarmClock']
# 47356 ['IPCam_V380']
# 47357 ['IPCam_AlarmClock']
# 47358 ['IPCam_AlarmClock']
# 47360 ['IPCam_AlarmClock']
# 47362 ['IPCam_V380']
# 47364 ['IPCam_V380']
# 47365 ['IPCam_AlarmClock']
# 47366 ['IPCam_AlarmClock']
# 47367 ['IPCam_V380']
# 47369 ['IPCam_V380']
# 47370 ['IPCam_AlarmClock']
# 47371 ['IPCam_AlarmClock']
# 47372 ['IPCam_AlarmClock']
# 47374 ['IPCam_AlarmClock']
# 47375 ['IPCam_AlarmClock']
# 47376 ['IPCam_AlarmClock']
# 47377 ['IPCam_AlarmClock']
# 47379 ['IPCam_V380']
# 47380 ['IPCam_AlarmClock']
# 47381 ['IPCam_AlarmClock']
# 47383 ['IPCam_AlarmClock']
# 47390 ['IPCam_AlarmClock']
# 47392 ['IPCam_AlarmClock']
# 47393 ['IPCam_AlarmClock']
# 47395 ['IPCam_AlarmClock']
# 47396 ['IPCam_AlarmClock']
# 47398 ['IPCam_AlarmClock']
# 47400 ['IPCam_AlarmClock']
# 47402 ['IPCam_AlarmClock']
# 47403 ['IPCam_AlarmClock']
# 47404 ['IPCam_AlarmClock']
# 47405 ['IPCam_V380']
# 47407 ['IPCam_AlarmClock']
# 47408 ['IPCam_AlarmClock']
# 47409 ['IPCam_AlarmClock']
# 47413 ['IPCam_AlarmClock']
# 47416 ['IPCam_AlarmClock']
# 47417 ['IPCam_AlarmClock']
# 47418 ['IPCam_AlarmClock']
# 47419 ['IPCam_AlarmClock']
# 47420 ['IPCam_AlarmClock']
# 47421 ['IPCam_AlarmClock']
# 47422 ['IPCam_AlarmClock']
# 47424 ['IPCam_AlarmClock']
# 47425 ['IPCam_AlarmClock']
# 47427 ['IPCam_V380']
# 47428 ['IPCam_AlarmClock']
# 47430 ['IPCam_AlarmClock']
# 47431 ['IPCam_V380']
# 47433 ['IPCam_AlarmClock']
# 47436 ['IPCam_AlarmClock']
# 47438 ['IPCam_AlarmClock']
# 47439 ['IPCam_AlarmClock']
# 47441 ['IPCam_AlarmClock']
# 47442 ['IPCam_AlarmClock']
# 47443 ['IPCam_AlarmClock']
# 47445 ['IPCam_AlarmClock']
# 47446 ['IPCam_V380']
# 47447 ['IPCam_AlarmClock']
# 47448 ['IPCam_AlarmClock']
# 47450 ['IPCam_AlarmClock']
# 47451 ['IPCam_AlarmClock']
# 47454 ['IPCam_AlarmClock']
# 47459 ['IPCam_V380']
# 47460 ['IPCam_AlarmClock']
# 47461 ['IPCam_AlarmClock']
# 47463 ['IPCam_AlarmClock']
# 47464 ['IPCam_AlarmClock']
# 47465 ['IPCam_AlarmClock']
# 47467 ['IPCam_AlarmClock']
# 47468 ['IPCam_AlarmClock']
# 47469 ['IPCam_AlarmClock']
# 47470 ['IPCam_AlarmClock']
# 47473 ['IPCam_AlarmClock']
# 47474 ['IPCam_AlarmClock']
# 47478 ['IPCam_Ezviz']
# 47481 ['IPCam_AlarmClock']
# 47482 ['IPCam_AlarmClock']
# 47483 ['IPCam_V380']
# 47484 ['IPCam_AlarmClock']
# 47485 ['IPCam_AlarmClock']
# 47488 ['IPCam_AlarmClock']
# 47489 ['IPCam_AlarmClock']
# 47490 ['IPCam_AlarmClock']
# 47492 ['IPCam_AlarmClock']
# 47496 ['IPCam_AlarmClock']
# 47499 ['IPCam_V380']
# 47500 ['IPCam_AlarmClock']
# 47501 ['IPCam_AlarmClock']
# 47503 ['IPCam_AlarmClock']
# 47504 ['IPCam_AlarmClock']
# 47505 ['IPCam_AlarmClock']
# 47506 ['IPCam_AlarmClock']
# 47508 ['IPCam_AlarmClock']
# 47509 ['IPCam_AlarmClock']
# 47510 ['IPCam_AlarmClock']
# 47513 ['IPCam_V380']
# 47514 ['IPCam_AlarmClock']
# 47515 ['IPCam_AlarmClock']
# 47518 ['IPCam_AlarmClock']
# 47519 ['IPCam_AlarmClock']
# 47521 ['IPCam_AlarmClock']
# 47522 ['IPCam_AlarmClock']
# 47523 ['IPCam_V380']
# 47524 ['IPCam_AlarmClock']
# 47526 ['IPCam_AlarmClock']
# 47527 ['IPCam_AlarmClock']
# 47528 ['IPCam_AlarmClock']
# 47531 ['IPCam_AlarmClock']
# 47532 ['IPCam_AlarmClock']
# 47533 ['IPCam_AlarmClock']
# 47534 ['IPCam_AlarmClock']
# 47535 ['IPCam_AlarmClock']
# 47536 ['IPCam_AlarmClock']
# 47538 ['IPCam_AlarmClock']
# 47539 ['IPCam_AlarmClock']
# 47540 ['IPCam_AlarmClock']
# 47541 ['IPCam_V380']
# 47542 ['IPCam_AlarmClock']
# 47544 ['IPCam_Ezviz']
# 47548 ['IPCam_V380']
# 47553 ['IPCam_AlarmClock']
# 47554 ['IPCam_AlarmClock']
# 47555 ['IPCam_V380']
# 47556 ['IPCam_AlarmClock']
# 47558 ['IPCam_AlarmClock']
# 47559 ['IPCam_AlarmClock']
# 47560 ['IPCam_AlarmClock']
# 47562 ['IPCam_AlarmClock']
# 47564 ['IPCam_AlarmClock']
# 47565 ['IPCam_AlarmClock']
# 47566 ['IPCam_AlarmClock']
# 47567 ['IPCam_AlarmClock']
# 47568 ['IPCam_AlarmClock']
# 47569 ['IPCam_AlarmClock']
# 47570 ['IPCam_AlarmClock']
# 47571 ['IPCam_V380']
# 47573 ['IPCam_V380']
# 47574 ['IPCam_AlarmClock']
# 47575 ['IPCam_AlarmClock']
# 47576 ['IPCam_AlarmClock']
# 47579 ['IPCam_AlarmClock']
# 47583 ['IPCam_AlarmClock']
# 47587 ['IPCam_AlarmClock']
# 47591 ['IPCam_AlarmClock']
# 47592 ['IPCam_AlarmClock']
# 47593 ['IPCam_AlarmClock']
# 47594 ['IPCam_AlarmClock']
# 47595 ['IPCam_AlarmClock']
# 47597 ['IPCam_V380']
# 47598 ['IPCam_AlarmClock']
# 47600 ['IPCam_AlarmClock']
# 47601 ['IPCam_AlarmClock']
# 47603 ['IPCam_AlarmClock']
# 47604 ['IPCam_AlarmClock']
# 47606 ['IPCam_AlarmClock']
# 47608 ['IPCam_AlarmClock']
# 47609 ['IPCam_Canary']
# 47610 ['IPCam_AlarmClock']
# 47612 ['IPCam_AlarmClock']
# 47613 ['IPCam_AlarmClock']
# 47614 ['IPCam_AlarmClock']
# 47615 ['IPCam_AlarmClock']
# 47617 ['IPCam_AlarmClock']
# 47618 ['IPCam_AlarmClock']
# 47619 ['IPCam_AlarmClock']
# 47620 ['IPCam_AlarmClock']
# 47621 ['IPCam_AlarmClock']
# 47622 ['IPCam_AlarmClock']
# 47623 ['IPCam_AlarmClock']
# 47624 ['IPCam_AlarmClock']
# 47625 ['IPCam_V380']
# 47628 ['IPCam_AlarmClock']
# 47629 ['IPCam_AlarmClock']
# 47630 ['IPCam_AlarmClock']
# 47631 ['IPCam_AlarmClock']
# 47632 ['IPCam_AlarmClock']
# 47633 ['IPCam_AlarmClock']
# 47634 ['IPCam_AlarmClock']
# 47635 ['IPCam_AlarmClock']
# 47636 ['IPCam_AlarmClock']
# 47638 ['IPCam_AlarmClock']
# 47639 ['IPCam_AlarmClock']
# 47642 ['IPCam_AlarmClock']
# 47643 ['IPCam_AlarmClock']
# 47645 ['IPCam_AlarmClock']
# 47646 ['IPCam_AlarmClock']
# 47647 ['IPCam_AlarmClock']
# 47651 ['IPCam_AlarmClock']
# 47652 ['IPCam_AlarmClock']
# 47656 ['IPCam_AlarmClock']
# 47658 ['IPCam_AlarmClock']
# 47662 ['IPCam_AlarmClock']
# 47663 ['IPCam_D3D']
# 47665 ['IPCam_AlarmClock']
# 47668 ['IPCam_AlarmClock']
# 47669 ['IPCam_V380']

# %%
yhatcamList
#len(yhatcamList)
# Out:
# ['IPCam_V380',
#  'IPCam_Canary',
#  'IPCam_Ezviz',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_Netatmo',
#  'IPCam_V380',
#  'IPCam_Ezviz',
#  'IPCam_Canary',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_Canary',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_Canary',
#  'IPCam_Ezviz',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_Ezviz',
#  'IPCam_Canary',
#  'IPCam_V380',
#  'IPCam_Canary',
#  'IPCam_Canary',
#  'IPCam_V380',
#  'IPCam_Ezviz',
#  'IPCam_AlarmClock',
#  'IPCam_Canary',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_Netatmo',
#  'IPCam_Ezviz',
#  'IPCam_V380',
#  'IPCam_Ezviz',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_Ezviz',
#  'IPCam_Netatmo',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_Canary',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_Netatmo',
#  'IPCam_Netatmo',
#  'IPCam_Ezviz',
#  'IPCam_V380',
#  'IPCam_Canary',
#  'IPCam_Canary',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_Ezviz',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_Netatmo',
#  'IPCam_Ezviz',
#  'IPCam_V380',
#  'IPCam_Netatmo',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_Ezviz',
#  'IPCam_Netatmo',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_Ezviz',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_Ezviz',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_Ezviz',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_Netatmo',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_Ezviz',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Netatmo',
#  'IPCam_Netatmo',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_Ezviz',
#  'IPCam_Ezviz',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Canary',
#  'IPCam_AlarmClock',
#  'IPCam_Ezviz',
#  'IPCam_V380',
#  'IPCam_Netatmo',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Ezviz',
#  'IPCam_Canary',
#  'IPCam_Ezviz',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_Ezviz',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Canary',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Netatmo',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Ezviz',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Ezviz',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Canary',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Netatmo',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_Canary',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Ezviz',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_Canary',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Ezviz',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_Netatmo',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_Canary',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Netatmo',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Canary',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Netatmo',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_Ezviz',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Ezviz',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Netatmo',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_Netatmo',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_V380',
#  'IPCam_V380',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  'IPCam_Ezviz',
#  'IPCam_AlarmClock',
#  'IPCam_AlarmClock',
#  ...]

# %%
counted_dict1 = Counter(yhatcamList)

# %%
for key in counted_dict1:
    print('key = ', key, ' val = ', counted_dict1[key])
# Out:
# key =  IPCam_V380  val =  2373
# key =  IPCam_Canary  val =  159
# key =  IPCam_Ezviz  val =  535
# key =  IPCam_Netatmo  val =  196
# key =  IPCam_AlarmClock  val =  16060
# key =  IPCam_D3D  val =  111
